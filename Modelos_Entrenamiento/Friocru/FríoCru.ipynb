# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
import category_encoders

# %%
data= pd.read_csv('Downloads/Historial_FrioCru_7.csv')
le=LabelEncoder()
ohe=OneHotEncoder(handle_unknown='ignore')

# %%
#limpieza de datos
de=['Estatus', 'FECHA_ALTA', 'IdMaterial', 'NECESIDAD_ORIGEN','NECESIDAD_DESTINO', 'PRO_ORIGEN', 'PRO_DESTINO', 'Pedido']
datac=data.drop(de,axis=1)
datac
# Out:
#       ACEROOrigen C_ACEROOrigen ACERODestino C_ACERODestino  \
# 0          UBCTIS            IF       UBCIMS             IF
# 1          UBCIMS            IF       UBCIMS             IF
# 2          UBCIMS            IF       UBCIMS             IF
# 3          UBCIMS            IF       UBCIMS             IF
# 4          UBCIMS            IF       UBCIMS             IF
# ...           ...           ...          ...            ...
# 64634        7061            CS       APM50M             HS
# 64635      ACE517            CS       APM50M             HS
# 64636      ACE523            CS       UBCIMS             IF
# 64637      C091TM            SS         6066             CS
# 64638      ACE514            CS       UBCIMS             IF
#
#       CCLASEPRODTOOrigen ACABSUPEROrigen BORDESOrigen  DIAM__INTERNOOrigen  \
# 0       M-P-FRIO-BOB-CRU            MATE   LAMINACION                  508
# 1       M-P-FRIO-BOB-CRU            MATE   LAMINACION                  508
# 2       M-P-FRIO-BOB-CRU            MATE   LAMINACION                  508
# 3       M-P-FRIO-BOB-CRU            MATE   LAMINACION                  508
# 4       M-P-FRIO-BOB-CRU            MATE   LAMINACION                  508
# ...                  ...             ...          ...                  ...
# 64634   M-P-FRIO-BOB-CRU            MATE   LAMINACION                  508
# 64635   M-P-FRIO-BOB-CRU            MATE   LAMINACION                  508
# 64636   M-P-FRIO-BOB-CRU            MATE   LAMINACION                  508
# 64637   M-P-FRIO-BOB-CRU            MATE   LAMINACION                  508
# 64638   M-P-FRIO-BOB-CRU            MATE   LAMINACION                  508
#
#                 EXTREMOSOrigen                             NORMAOrigen  ...  \
# 0      CORTADOS 98% EN ESPESOR           TER \ EDDS GAL (V 2011 REV 1)  ...
# 1      CORTADOS 98% EN ESPESOR           TER \ EDDS GAL (V 2011 REV 1)  ...
# 2      CORTADOS 98% EN ESPESOR           TER \ EDDS GAL (V 2011 REV 1)  ...
# 3      CORTADOS 98% EN ESPESOR           TER \ EDDS GAL (V 2011 REV 1)  ...
# 4      CORTADOS 98% EN ESPESOR           TER \ EDDS GAL (V 2011 REV 1)  ...
# ...                        ...                                     ...  ...
# 64634  CORTADOS 98% EN ESPESOR           TER \ 1006 GAL (V 2011 REV 1)  ...
# 64635  CORTADOS 98% EN ESPESOR           TER \ 50LCTGLV (V 2011 REV 1)  ...
# 64636  CORTADOS 98% EN ESPESOR   TER \ EDDS IFTIS \ GAL (V 2016 REV 1)  ...
# 64637  CORTADOS 98% EN ESPESOR       TER \ GA040 GAL SS (V 2011 REV 1)  ...
# 64638  CORTADOS 98% EN ESPESOR  TER \ GMW2MSTS EDDS GAL (V 2012 REV 1)  ...
#
#       DIAM__INTERNODestino          EXTREMOSDestino  \
# 0                      508  CORTADOS 98% EN ESPESOR
# 1                      508  CORTADOS 98% EN ESPESOR
# 2                      508  CORTADOS 98% EN ESPESOR
# 3                      508  CORTADOS 98% EN ESPESOR
# 4                      508  CORTADOS 98% EN ESPESOR
# ...                    ...                      ...
# 64634                  508  CORTADOS 98% EN ESPESOR
# 64635                  508  CORTADOS 98% EN ESPESOR
# 64636                  508  CORTADOS 98% EN ESPESOR
# 64637                  508  CORTADOS 98% EN ESPESOR
# 64638                  508  CORTADOS 98% EN ESPESOR
#
#                          NORMADestino NORTOLANCHODestino NORTOLESPESORDestino  \
# 0       TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568       1/2 ASTM A 568
# 1       TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568       1/2 ASTM A 568
# 2       TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568       1/2 ASTM A 568
# 3       TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568       1/2 ASTM A 568
# 4       TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568       1/2 ASTM A 568
# ...                               ...                ...                  ...
# 64634  TER \ GA050 GAL (V 2011 REV 1)         ASTM A 568       1/2 ASTM A 568
# 64635  TER \ GA050 GAL (V 2011 REV 1)         ASTM A 568       1/2 ASTM A 568
# 64636   TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568       1/2 ASTM A 568
# 64637   TER \ 1006 GAL (V 2011 REV 1)    TER \ COMERCIAL       1/2 ASTM A 568
# 64638   TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568       1/2 ASTM A 568
#
#         PLANITUDDestino SOLDADestino SUPERFICIEDestino    USOGRALDestino  \
# 0      TERNIUM ESTANDAR           NO     SEMI-EXPUESTA  GALV. INDUSTRIAL
# 1      TERNIUM ESTANDAR           NO     SEMI-EXPUESTA  GALV. INDUSTRIAL
# 2      TERNIUM ESTANDAR           NO     SEMI-EXPUESTA  GALV. INDUSTRIAL
# 3      TERNIUM ESTANDAR           NO     SEMI-EXPUESTA  GALV. INDUSTRIAL
# 4      TERNIUM ESTANDAR           NO     SEMI-EXPUESTA  GALV. INDUSTRIAL
# ...                 ...          ...               ...               ...
# 64634  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA       GALVANIZADO
# 64635  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA       GALVANIZADO
# 64636  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA  GALV. INDUSTRIAL
# 64637  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA       GALVANIZADO
# 64638  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA  GALV. INDUSTRIAL
#
#        Reasignacion
# 0                OK
# 1                OK
# 2                OK
# 3                OK
# 4                OK
# ...             ...
# 64634     Rechazado
# 64635     Rechazado
# 64636     Rechazado
# 64637     Rechazado
# 64638     Rechazado
#
# [64639 rows x 29 columns]

# %%
main_df=datac
main_df=pd.DataFrame(data=main_df)
full_df=datac
full_df=pd.DataFrame(data=full_df)
print(full_df.head(10))
# Out:
#   ACEROOrigen C_ACEROOrigen ACERODestino C_ACERODestino CCLASEPRODTOOrigen  \
# 0      UBCTIS            IF       UBCIMS             IF   M-P-FRIO-BOB-CRU
# 1      UBCIMS            IF       UBCIMS             IF   M-P-FRIO-BOB-CRU
# 2      UBCIMS            IF       UBCIMS             IF   M-P-FRIO-BOB-CRU
# 3      UBCIMS            IF       UBCIMS             IF   M-P-FRIO-BOB-CRU
# 4      UBCIMS            IF       UBCIMS             IF   M-P-FRIO-BOB-CRU
# 5      ACE523            CS       ACE523             CS   M-P-FRIO-BOB-CRU
# 6      UBCIMS            IF       UBCIMS             IF   M-P-FRIO-BOB-CRU
# 7      UBCIMS            IF       UBCIMS             IF   M-P-FRIO-BOB-CRU
# 8      UBCTIS            IF       UBCTIS             IF   M-P-FRIO-BOB-CRU
# 9      UBCTIS            IF       UBCTIS             IF   M-P-FRIO-BOB-CRU
#
#   ACABSUPEROrigen BORDESOrigen  DIAM__INTERNOOrigen           EXTREMOSOrigen  \
# 0            MATE   LAMINACION                  508  CORTADOS 98% EN ESPESOR
# 1            MATE   LAMINACION                  508  CORTADOS 98% EN ESPESOR
# 2            MATE   LAMINACION                  508  CORTADOS 98% EN ESPESOR
# 3            MATE   LAMINACION                  508  CORTADOS 98% EN ESPESOR
# 4            MATE   LAMINACION                  508  CORTADOS 98% EN ESPESOR
# 5            MATE   LAMINACION                  508  CORTADOS 98% EN ESPESOR
# 6            MATE   LAMINACION                  508  CORTADOS 98% EN ESPESOR
# 7            MATE   LAMINACION                  508  CORTADOS 98% EN ESPESOR
# 8            MATE   LAMINACION                  508  CORTADOS 98% EN ESPESOR
# 9            MATE   LAMINACION                  508  CORTADOS 98% EN ESPESOR
#
#                      NORMAOrigen  ... DIAM__INTERNODestino  \
# 0  TER \ EDDS GAL (V 2011 REV 1)  ...                  508
# 1  TER \ EDDS GAL (V 2011 REV 1)  ...                  508
# 2  TER \ EDDS GAL (V 2011 REV 1)  ...                  508
# 3  TER \ EDDS GAL (V 2011 REV 1)  ...                  508
# 4  TER \ EDDS GAL (V 2011 REV 1)  ...                  508
# 5  TER \ EDDS GAL (V 2011 REV 1)  ...                  508
# 6  TER \ EDDS GAL (V 2011 REV 1)  ...                  508
# 7  TER \ EDDS GAL (V 2011 REV 1)  ...                  508
# 8  TER \ EDDS GAL (V 2011 REV 1)  ...                  508
# 9  TER \ EDDS GAL (V 2011 REV 1)  ...                  508
#
#            EXTREMOSDestino                   NORMADestino NORTOLANCHODestino  \
# 0  CORTADOS 98% EN ESPESOR  TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568
# 1  CORTADOS 98% EN ESPESOR  TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568
# 2  CORTADOS 98% EN ESPESOR  TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568
# 3  CORTADOS 98% EN ESPESOR  TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568
# 4  CORTADOS 98% EN ESPESOR  TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568
# 5  CORTADOS 98% EN ESPESOR  TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568
# 6  CORTADOS 98% EN ESPESOR  TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568
# 7  CORTADOS 98% EN ESPESOR  TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568
# 8  CORTADOS 98% EN ESPESOR  TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568
# 9  CORTADOS 98% EN ESPESOR  TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568
#
#   NORTOLESPESORDestino   PLANITUDDestino SOLDADestino SUPERFICIEDestino  \
# 0       1/2 ASTM A 568  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA
# 1       1/2 ASTM A 568  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA
# 2       1/2 ASTM A 568  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA
# 3       1/2 ASTM A 568  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA
# 4       1/2 ASTM A 568  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA
# 5       1/2 ASTM A 568  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA
# 6       1/2 ASTM A 568  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA
# 7       1/2 ASTM A 568  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA
# 8       1/2 ASTM A 568  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA
# 9       1/2 ASTM A 568  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA
#
#      USOGRALDestino  Reasignacion
# 0  GALV. INDUSTRIAL            OK
# 1  GALV. INDUSTRIAL            OK
# 2  GALV. INDUSTRIAL            OK
# 3  GALV. INDUSTRIAL            OK
# 4  GALV. INDUSTRIAL            OK
# 5  GALV. INDUSTRIAL            OK
# 6  GALV. INDUSTRIAL            OK
# 7  GALV. INDUSTRIAL            OK
# 8  GALV. INDUSTRIAL            OK
# 9  GALV. INDUSTRIAL            OK
#
# [10 rows x 29 columns]

# %%
main_df.columns
# Out:
# Index(['ACEROOrigen', 'C_ACEROOrigen', 'ACERODestino', 'C_ACERODestino',
#        'CCLASEPRODTOOrigen', 'ACABSUPEROrigen', 'BORDESOrigen',
#        'DIAM__INTERNOOrigen', 'EXTREMOSOrigen', 'NORMAOrigen',
#        'NORTOLANCHOOrigen', 'NORTOLESPESOROrigen', 'PLANITUDOrigen',
#        'SOLDAOrigen', 'SUPERFICIEOrigen', 'USOGRALOrigen',
#        'CCLASEPRODTODestino', 'ACABSUPERDestino', 'BORDESDestino',
#        'DIAM__INTERNODestino', 'EXTREMOSDestino', 'NORMADestino',
#        'NORTOLANCHODestino', 'NORTOLESPESORDestino', 'PLANITUDDestino',
#        'SOLDADestino', 'SUPERFICIEDestino', 'USOGRALDestino', 'Reasignacion'],
#       dtype='object')

# %%
#codificación de variable objetivo usando LE
main_df.Reasignacion=le.fit_transform(main_df['Reasignacion'])
main_df
# Out:
#       ACEROOrigen C_ACEROOrigen ACERODestino C_ACERODestino  \
# 0          UBCTIS            IF       UBCIMS             IF
# 1          UBCIMS            IF       UBCIMS             IF
# 2          UBCIMS            IF       UBCIMS             IF
# 3          UBCIMS            IF       UBCIMS             IF
# 4          UBCIMS            IF       UBCIMS             IF
# ...           ...           ...          ...            ...
# 64634        7061            CS       APM50M             HS
# 64635      ACE517            CS       APM50M             HS
# 64636      ACE523            CS       UBCIMS             IF
# 64637      C091TM            SS         6066             CS
# 64638      ACE514            CS       UBCIMS             IF
#
#       CCLASEPRODTOOrigen ACABSUPEROrigen BORDESOrigen  DIAM__INTERNOOrigen  \
# 0       M-P-FRIO-BOB-CRU            MATE   LAMINACION                  508
# 1       M-P-FRIO-BOB-CRU            MATE   LAMINACION                  508
# 2       M-P-FRIO-BOB-CRU            MATE   LAMINACION                  508
# 3       M-P-FRIO-BOB-CRU            MATE   LAMINACION                  508
# 4       M-P-FRIO-BOB-CRU            MATE   LAMINACION                  508
# ...                  ...             ...          ...                  ...
# 64634   M-P-FRIO-BOB-CRU            MATE   LAMINACION                  508
# 64635   M-P-FRIO-BOB-CRU            MATE   LAMINACION                  508
# 64636   M-P-FRIO-BOB-CRU            MATE   LAMINACION                  508
# 64637   M-P-FRIO-BOB-CRU            MATE   LAMINACION                  508
# 64638   M-P-FRIO-BOB-CRU            MATE   LAMINACION                  508
#
#                 EXTREMOSOrigen                             NORMAOrigen  ...  \
# 0      CORTADOS 98% EN ESPESOR           TER \ EDDS GAL (V 2011 REV 1)  ...
# 1      CORTADOS 98% EN ESPESOR           TER \ EDDS GAL (V 2011 REV 1)  ...
# 2      CORTADOS 98% EN ESPESOR           TER \ EDDS GAL (V 2011 REV 1)  ...
# 3      CORTADOS 98% EN ESPESOR           TER \ EDDS GAL (V 2011 REV 1)  ...
# 4      CORTADOS 98% EN ESPESOR           TER \ EDDS GAL (V 2011 REV 1)  ...
# ...                        ...                                     ...  ...
# 64634  CORTADOS 98% EN ESPESOR           TER \ 1006 GAL (V 2011 REV 1)  ...
# 64635  CORTADOS 98% EN ESPESOR           TER \ 50LCTGLV (V 2011 REV 1)  ...
# 64636  CORTADOS 98% EN ESPESOR   TER \ EDDS IFTIS \ GAL (V 2016 REV 1)  ...
# 64637  CORTADOS 98% EN ESPESOR       TER \ GA040 GAL SS (V 2011 REV 1)  ...
# 64638  CORTADOS 98% EN ESPESOR  TER \ GMW2MSTS EDDS GAL (V 2012 REV 1)  ...
#
#       DIAM__INTERNODestino          EXTREMOSDestino  \
# 0                      508  CORTADOS 98% EN ESPESOR
# 1                      508  CORTADOS 98% EN ESPESOR
# 2                      508  CORTADOS 98% EN ESPESOR
# 3                      508  CORTADOS 98% EN ESPESOR
# 4                      508  CORTADOS 98% EN ESPESOR
# ...                    ...                      ...
# 64634                  508  CORTADOS 98% EN ESPESOR
# 64635                  508  CORTADOS 98% EN ESPESOR
# 64636                  508  CORTADOS 98% EN ESPESOR
# 64637                  508  CORTADOS 98% EN ESPESOR
# 64638                  508  CORTADOS 98% EN ESPESOR
#
#                          NORMADestino NORTOLANCHODestino NORTOLESPESORDestino  \
# 0       TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568       1/2 ASTM A 568
# 1       TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568       1/2 ASTM A 568
# 2       TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568       1/2 ASTM A 568
# 3       TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568       1/2 ASTM A 568
# 4       TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568       1/2 ASTM A 568
# ...                               ...                ...                  ...
# 64634  TER \ GA050 GAL (V 2011 REV 1)         ASTM A 568       1/2 ASTM A 568
# 64635  TER \ GA050 GAL (V 2011 REV 1)         ASTM A 568       1/2 ASTM A 568
# 64636   TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568       1/2 ASTM A 568
# 64637   TER \ 1006 GAL (V 2011 REV 1)    TER \ COMERCIAL       1/2 ASTM A 568
# 64638   TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568       1/2 ASTM A 568
#
#         PLANITUDDestino SOLDADestino SUPERFICIEDestino    USOGRALDestino  \
# 0      TERNIUM ESTANDAR           NO     SEMI-EXPUESTA  GALV. INDUSTRIAL
# 1      TERNIUM ESTANDAR           NO     SEMI-EXPUESTA  GALV. INDUSTRIAL
# 2      TERNIUM ESTANDAR           NO     SEMI-EXPUESTA  GALV. INDUSTRIAL
# 3      TERNIUM ESTANDAR           NO     SEMI-EXPUESTA  GALV. INDUSTRIAL
# 4      TERNIUM ESTANDAR           NO     SEMI-EXPUESTA  GALV. INDUSTRIAL
# ...                 ...          ...               ...               ...
# 64634  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA       GALVANIZADO
# 64635  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA       GALVANIZADO
# 64636  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA  GALV. INDUSTRIAL
# 64637  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA       GALVANIZADO
# 64638  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA  GALV. INDUSTRIAL
#
#        Reasignacion
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 64634             1
# 64635             1
# 64636             1
# 64637             1
# 64638             1
#
# [64639 rows x 29 columns]

# %%
##Variable objetivo
target_df = pd.DataFrame(main_df, columns=['Reasignacion'])
print(target_df.sample(10))
# Out:
#        Reasignacion
# 9520              0
# 21200             0
# 44787             0
# 28204             0
# 25640             0
# 34037             0
# 39768             0
# 32165             0
# 23544             0
# 16511             0

# %%
#encodifiación de atributos usando target
main_df.columns = main_df.columns.str.strip()
target_df.columns = target_df.columns.str.strip()
enc=category_encoders.target_encoder.TargetEncoder(verbose=0,cols=['ACEROOrigen', 'C_ACEROOrigen', 'ACERODestino', 'C_ACERODestino',
       'CCLASEPRODTOOrigen', 'ACABSUPEROrigen', 'BORDESOrigen',
       'DIAM__INTERNOOrigen', 'EXTREMOSOrigen', 'NORMAOrigen',
       'NORTOLANCHOOrigen', 'NORTOLESPESOROrigen', 'PLANITUDOrigen',
       'SOLDAOrigen', 'SUPERFICIEOrigen', 'USOGRALOrigen',
       'CCLASEPRODTODestino', 'ACABSUPERDestino', 'BORDESDestino',
       'DIAM__INTERNODestino', 'EXTREMOSDestino', 'NORMADestino',
       'NORTOLANCHODestino', 'NORTOLESPESORDestino', 'PLANITUDDestino',
       'SOLDADestino', 'SUPERFICIEDestino', 'USOGRALDestino'],drop_invariant=False, return_df=True, handle_unknown='value',min_samples_leaf=1,smoothing=1.0).fit(main_df,target_df)

# %%
codi=enc.transform(main_df)
codi
# Out:
#        ACEROOrigen  C_ACEROOrigen  ACERODestino  C_ACERODestino  \
# 0         0.099305       0.105444      0.027823        0.078587
# 1         0.110690       0.105444      0.027823        0.078587
# 2         0.110690       0.105444      0.027823        0.078587
# 3         0.110690       0.105444      0.027823        0.078587
# 4         0.110690       0.105444      0.027823        0.078587
# ...            ...            ...           ...             ...
# 64634     0.022147       0.038865      0.072250        0.060517
# 64635     0.400000       0.038865      0.072250        0.060517
# 64636     0.112871       0.038865      0.027823        0.078587
# 64637     0.531250       0.334334      0.047949        0.043012
# 64638     0.166667       0.038865      0.027823        0.078587
#
#        CCLASEPRODTOOrigen  ACABSUPEROrigen  BORDESOrigen  DIAM__INTERNOOrigen  \
# 0                0.045514         0.045514      0.045514             0.046988
# 1                0.045514         0.045514      0.045514             0.046988
# 2                0.045514         0.045514      0.045514             0.046988
# 3                0.045514         0.045514      0.045514             0.046988
# 4                0.045514         0.045514      0.045514             0.046988
# ...                   ...              ...           ...                  ...
# 64634            0.045514         0.045514      0.045514             0.046988
# 64635            0.045514         0.045514      0.045514             0.046988
# 64636            0.045514         0.045514      0.045514             0.046988
# 64637            0.045514         0.045514      0.045514             0.046988
# 64638            0.045514         0.045514      0.045514             0.046988
#
#        EXTREMOSOrigen  NORMAOrigen  ...  DIAM__INTERNODestino  \
# 0            0.045514     0.079080  ...              0.047553
# 1            0.045514     0.079080  ...              0.047553
# 2            0.045514     0.079080  ...              0.047553
# 3            0.045514     0.079080  ...              0.047553
# 4            0.045514     0.079080  ...              0.047553
# ...               ...          ...  ...                   ...
# 64634        0.045514     0.016884  ...              0.047553
# 64635        0.045514     0.095238  ...              0.047553
# 64636        0.045514     0.353933  ...              0.047553
# 64637        0.045514     0.338403  ...              0.047553
# 64638        0.045514     0.111227  ...              0.047553
#
#        EXTREMOSDestino  NORMADestino  NORTOLANCHODestino  \
# 0             0.045514      0.094495            0.048494
# 1             0.045514      0.094495            0.048494
# 2             0.045514      0.094495            0.048494
# 3             0.045514      0.094495            0.048494
# 4             0.045514      0.094495            0.048494
# ...                ...           ...                 ...
# 64634         0.045514      0.064458            0.048494
# 64635         0.045514      0.064458            0.048494
# 64636         0.045514      0.094495            0.048494
# 64637         0.045514      0.040125            0.041673
# 64638         0.045514      0.094495            0.048494
#
#        NORTOLESPESORDestino  PLANITUDDestino  SOLDADestino  SUPERFICIEDestino  \
# 0                  0.046595         0.045514      0.045514            0.04257
# 1                  0.046595         0.045514      0.045514            0.04257
# 2                  0.046595         0.045514      0.045514            0.04257
# 3                  0.046595         0.045514      0.045514            0.04257
# 4                  0.046595         0.045514      0.045514            0.04257
# ...                     ...              ...           ...                ...
# 64634              0.046595         0.045514      0.045514            0.04257
# 64635              0.046595         0.045514      0.045514            0.04257
# 64636              0.046595         0.045514      0.045514            0.04257
# 64637              0.046595         0.045514      0.045514            0.04257
# 64638              0.046595         0.045514      0.045514            0.04257
#
#        USOGRALDestino  Reasignacion
# 0            0.057276             0
# 1            0.057276             0
# 2            0.057276             0
# 3            0.057276             0
# 4            0.057276             0
# ...               ...           ...
# 64634        0.041447             1
# 64635        0.041447             1
# 64636        0.057276             1
# 64637        0.041447             1
# 64638        0.057276             1
#
# [64639 rows x 29 columns]

# %%
#creación de dataset ecnodificado
datae=codi.drop(['Reasignacion'],axis=1)
datae
# Out:
#        ACEROOrigen  C_ACEROOrigen  ACERODestino  C_ACERODestino  \
# 0         0.099305       0.105444      0.027823        0.078587
# 1         0.110690       0.105444      0.027823        0.078587
# 2         0.110690       0.105444      0.027823        0.078587
# 3         0.110690       0.105444      0.027823        0.078587
# 4         0.110690       0.105444      0.027823        0.078587
# ...            ...            ...           ...             ...
# 64634     0.022147       0.038865      0.072250        0.060517
# 64635     0.400000       0.038865      0.072250        0.060517
# 64636     0.112871       0.038865      0.027823        0.078587
# 64637     0.531250       0.334334      0.047949        0.043012
# 64638     0.166667       0.038865      0.027823        0.078587
#
#        CCLASEPRODTOOrigen  ACABSUPEROrigen  BORDESOrigen  DIAM__INTERNOOrigen  \
# 0                0.045514         0.045514      0.045514             0.046988
# 1                0.045514         0.045514      0.045514             0.046988
# 2                0.045514         0.045514      0.045514             0.046988
# 3                0.045514         0.045514      0.045514             0.046988
# 4                0.045514         0.045514      0.045514             0.046988
# ...                   ...              ...           ...                  ...
# 64634            0.045514         0.045514      0.045514             0.046988
# 64635            0.045514         0.045514      0.045514             0.046988
# 64636            0.045514         0.045514      0.045514             0.046988
# 64637            0.045514         0.045514      0.045514             0.046988
# 64638            0.045514         0.045514      0.045514             0.046988
#
#        EXTREMOSOrigen  NORMAOrigen  ...  BORDESDestino  DIAM__INTERNODestino  \
# 0            0.045514     0.079080  ...       0.045514              0.047553
# 1            0.045514     0.079080  ...       0.045514              0.047553
# 2            0.045514     0.079080  ...       0.045514              0.047553
# 3            0.045514     0.079080  ...       0.045514              0.047553
# 4            0.045514     0.079080  ...       0.045514              0.047553
# ...               ...          ...  ...            ...                   ...
# 64634        0.045514     0.016884  ...       0.045514              0.047553
# 64635        0.045514     0.095238  ...       0.045514              0.047553
# 64636        0.045514     0.353933  ...       0.045514              0.047553
# 64637        0.045514     0.338403  ...       0.045514              0.047553
# 64638        0.045514     0.111227  ...       0.045514              0.047553
#
#        EXTREMOSDestino  NORMADestino  NORTOLANCHODestino  \
# 0             0.045514      0.094495            0.048494
# 1             0.045514      0.094495            0.048494
# 2             0.045514      0.094495            0.048494
# 3             0.045514      0.094495            0.048494
# 4             0.045514      0.094495            0.048494
# ...                ...           ...                 ...
# 64634         0.045514      0.064458            0.048494
# 64635         0.045514      0.064458            0.048494
# 64636         0.045514      0.094495            0.048494
# 64637         0.045514      0.040125            0.041673
# 64638         0.045514      0.094495            0.048494
#
#        NORTOLESPESORDestino  PLANITUDDestino  SOLDADestino  SUPERFICIEDestino  \
# 0                  0.046595         0.045514      0.045514            0.04257
# 1                  0.046595         0.045514      0.045514            0.04257
# 2                  0.046595         0.045514      0.045514            0.04257
# 3                  0.046595         0.045514      0.045514            0.04257
# 4                  0.046595         0.045514      0.045514            0.04257
# ...                     ...              ...           ...                ...
# 64634              0.046595         0.045514      0.045514            0.04257
# 64635              0.046595         0.045514      0.045514            0.04257
# 64636              0.046595         0.045514      0.045514            0.04257
# 64637              0.046595         0.045514      0.045514            0.04257
# 64638              0.046595         0.045514      0.045514            0.04257
#
#        USOGRALDestino
# 0            0.057276
# 1            0.057276
# 2            0.057276
# 3            0.057276
# 4            0.057276
# ...               ...
# 64634        0.041447
# 64635        0.041447
# 64636        0.057276
# 64637        0.041447
# 64638        0.057276
#
# [64639 rows x 28 columns]

# %%
#declaración de variable x (atributos)
X=datae
X
# Out:
#        ACEROOrigen  C_ACEROOrigen  ACERODestino  C_ACERODestino  \
# 0         0.099305       0.105444      0.027823        0.078587
# 1         0.110690       0.105444      0.027823        0.078587
# 2         0.110690       0.105444      0.027823        0.078587
# 3         0.110690       0.105444      0.027823        0.078587
# 4         0.110690       0.105444      0.027823        0.078587
# ...            ...            ...           ...             ...
# 64634     0.022147       0.038865      0.072250        0.060517
# 64635     0.400000       0.038865      0.072250        0.060517
# 64636     0.112871       0.038865      0.027823        0.078587
# 64637     0.531250       0.334334      0.047949        0.043012
# 64638     0.166667       0.038865      0.027823        0.078587
#
#        CCLASEPRODTOOrigen  ACABSUPEROrigen  BORDESOrigen  DIAM__INTERNOOrigen  \
# 0                0.045514         0.045514      0.045514             0.046988
# 1                0.045514         0.045514      0.045514             0.046988
# 2                0.045514         0.045514      0.045514             0.046988
# 3                0.045514         0.045514      0.045514             0.046988
# 4                0.045514         0.045514      0.045514             0.046988
# ...                   ...              ...           ...                  ...
# 64634            0.045514         0.045514      0.045514             0.046988
# 64635            0.045514         0.045514      0.045514             0.046988
# 64636            0.045514         0.045514      0.045514             0.046988
# 64637            0.045514         0.045514      0.045514             0.046988
# 64638            0.045514         0.045514      0.045514             0.046988
#
#        EXTREMOSOrigen  NORMAOrigen  ...  BORDESDestino  DIAM__INTERNODestino  \
# 0            0.045514     0.079080  ...       0.045514              0.047553
# 1            0.045514     0.079080  ...       0.045514              0.047553
# 2            0.045514     0.079080  ...       0.045514              0.047553
# 3            0.045514     0.079080  ...       0.045514              0.047553
# 4            0.045514     0.079080  ...       0.045514              0.047553
# ...               ...          ...  ...            ...                   ...
# 64634        0.045514     0.016884  ...       0.045514              0.047553
# 64635        0.045514     0.095238  ...       0.045514              0.047553
# 64636        0.045514     0.353933  ...       0.045514              0.047553
# 64637        0.045514     0.338403  ...       0.045514              0.047553
# 64638        0.045514     0.111227  ...       0.045514              0.047553
#
#        EXTREMOSDestino  NORMADestino  NORTOLANCHODestino  \
# 0             0.045514      0.094495            0.048494
# 1             0.045514      0.094495            0.048494
# 2             0.045514      0.094495            0.048494
# 3             0.045514      0.094495            0.048494
# 4             0.045514      0.094495            0.048494
# ...                ...           ...                 ...
# 64634         0.045514      0.064458            0.048494
# 64635         0.045514      0.064458            0.048494
# 64636         0.045514      0.094495            0.048494
# 64637         0.045514      0.040125            0.041673
# 64638         0.045514      0.094495            0.048494
#
#        NORTOLESPESORDestino  PLANITUDDestino  SOLDADestino  SUPERFICIEDestino  \
# 0                  0.046595         0.045514      0.045514            0.04257
# 1                  0.046595         0.045514      0.045514            0.04257
# 2                  0.046595         0.045514      0.045514            0.04257
# 3                  0.046595         0.045514      0.045514            0.04257
# 4                  0.046595         0.045514      0.045514            0.04257
# ...                     ...              ...           ...                ...
# 64634              0.046595         0.045514      0.045514            0.04257
# 64635              0.046595         0.045514      0.045514            0.04257
# 64636              0.046595         0.045514      0.045514            0.04257
# 64637              0.046595         0.045514      0.045514            0.04257
# 64638              0.046595         0.045514      0.045514            0.04257
#
#        USOGRALDestino
# 0            0.057276
# 1            0.057276
# 2            0.057276
# 3            0.057276
# 4            0.057276
# ...               ...
# 64634        0.041447
# 64635        0.041447
# 64636        0.057276
# 64637        0.041447
# 64638        0.057276
#
# [64639 rows x 28 columns]

# %%
#declaración de y (objetivo)
y=codi.Reasignacion
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 64634    1
# 64635    1
# 64636    1
# 64637    1
# 64638    1
# Name: Reasignacion, Length: 64639, dtype: int32

# %%
#división de datos 
Xent,Xtest,yent, ytest=train_test_split(X,y)

# %%
red=MLPClassifier(max_iter=1000, hidden_layer_sizes=(10,10))

# %%
red.fit(Xent,yent)
# Out:
# MLPClassifier(hidden_layer_sizes=(10, 10), max_iter=1000)

# %%
red.score(Xtest,ytest)
# Out:
# 0.9567450495049505
