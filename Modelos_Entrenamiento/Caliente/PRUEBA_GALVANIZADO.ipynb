# %%
###importaciones
import pandas as pd
import numpy as np
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import category_encoders
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import LabelEncoder 
from sklearn.tree import DecisionTreeClassifier
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.tree import export_graphviz
import graphviz
import joblib
from sklearn.datasets import make_hastie_10_2
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
import xgboost as xgb

# graficos incrustados
# %matplotlib inline

# parametros esteticos de seaborn
sns.set_palette("deep", desat=.6)
sns.set_context(rc={"figure.figsize": (8, 4)})

# %%
datar=pd.read_excel('Cert_Caliente_19_01_21.xlsx')
dt=joblib.load('ModeloCaliente.pkl')
enc=joblib.load('TargetCaliente.pkl')
encobj=joblib.load('EncodificacionObjetivo.pkl')
dtc=DecisionTreeClassifier()
datar
# Out:
#         idMaterial ACEROOrigen CPRODTOOrigen  CCLASEPRODTOOrigen  N_ANCHO  \
# 0    2A849644GM200        7092      MP501073  M-P-CALIENTE-BOB-_      0.0
# 1    2A850796GM200        7061      MP501073  M-P-CALIENTE-BOB-_    999.0
# 2    2A851998GM200        7094      MP509656  M-P-CALIENTE-BOB-_   1206.0
# 3    2A854123GM200        7061      MP501073  M-P-CALIENTE-BOB-_    149.5
# 4    2A857872GM200        2060      MP501073  M-P-CALIENTE-BOB-_     97.4
# ..             ...         ...           ...                 ...      ...
# 122  2A879262GM200        7092      MP501073  M-P-CALIENTE-BOB-_      NaN
# 123  2A879254GM200        4092      MP501073  M-P-CALIENTE-BOB-_      NaN
# 124  2A884998GM200        2060      MP501073  M-P-CALIENTE-BOB-_      NaN
# 125  2A883720GM200        2084      MP509656  M-P-CALIENTE-BOB-_      NaN
# 126  2A882296GM200        7094      MP509656  M-P-CALIENTE-BOB-_      NaN
#
#      N_ESPESOR Clasificacion_Norma CLASIFICACION_TIPO_ACERO BORDESOrigen  \
# 0        0.000                  CS                       CS   LAMINACIÓN
# 1        0.800                  CS                       CS   LAMINACIÓN
# 2        0.770                HSLA                       HS   LAMINACIÓN
# 3        3.150                  CS                       CS   LAMINACIÓN
# 4        1.825                  CS                       CS   LAMINACIÓN
# ..         ...                 ...                      ...          ...
# 122        NaN                  CS                       CS   LAMINACIÓN
# 123        NaN                  CS                       CS   LAMINACIÓN
# 124        NaN                  CS                       CS   LAMINACIÓN
# 125        NaN                HSLA                       HS   LAMINACIÓN
# 126        NaN                HSLA                       HS   LAMINACIÓN
#
#      DIAM__INTERNOOrigen  ... BORDESDestino DIAM__INTERNODestino  \
# 0                    711  ...    LAMINACIÓN                  711
# 1                    711  ...    LAMINACIÓN                  711
# 2                    711  ...    LAMINACIÓN                  711
# 3                    711  ...    LAMINACIÓN                  711
# 4                    711  ...    LAMINACIÓN                  711
# ..                   ...  ...           ...                  ...
# 122                  711  ...    LAMINACIÓN                  711
# 123                  711  ...    LAMINACIÓN                  711
# 124                  711  ...    LAMINACIÓN                  711
# 125                  711  ...    LAMINACIÓN                  711
# 126                  711  ...    LAMINACIÓN                  711
#
#                  EXTREMOSDestino                            NORMADestino  \
# 0    NO CORTADOS 98% EN ESPESOR.             TER \ PER-GA (V 2006 REV 1)
# 1    NO CORTADOS 98% EN ESPESOR.  TER \ PER-GA \ TUBE GLV (V 2015 REV 0)
# 2    NO CORTADOS 98% EN ESPESOR.             TER \ PER-GA (V 2006 REV 1)
# 3    NO CORTADOS 98% EN ESPESOR.             TER \ PER-GA (V 2006 REV 1)
# 4    NO CORTADOS 98% EN ESPESOR.             TER \ PER-GA (V 2006 REV 1)
# ..                           ...                                     ...
# 122  NO CORTADOS 98% EN ESPESOR.             TER \ PER-GA (V 2006 REV 1)
# 123  NO CORTADOS 98% EN ESPESOR.             TER \ PER-GA (V 2006 REV 1)
# 124  NO CORTADOS 98% EN ESPESOR.             TER \ PER-GA (V 2006 REV 1)
# 125  NO CORTADOS 98% EN ESPESOR.  TER \ PER-GA \ TUBE GLV (V 2015 REV 0)
# 126  NO CORTADOS 98% EN ESPESOR.  TER \ PER-GA \ TUBE GLV (V 2015 REV 0)
#
#      NORTOLANCHODestino    NORTOLESPESORDestino   PLANITUDDestino  \
# 0    ASTM A 568 / A 635      ASTM A 568 / A 635  TERNIUM ESTANDAR
# 1    ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR
# 2    ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR
# 3    ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR
# 4    ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR
# ..                  ...                     ...               ...
# 122  ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR
# 123  ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR
# 124  ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR
# 125  ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR
# 126  ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR
#
#     SOLDADestino  SUPERFICIEDestino    USOGRALDestino
# 0             NO            INTERNA  TUBOS Y PERFILES
# 1             NO            INTERNA  TUBOS Y PERFILES
# 2             NO            INTERNA  TUBOS Y PERFILES
# 3             NO            INTERNA  TUBOS Y PERFILES
# 4             NO            INTERNA  TUBOS Y PERFILES
# ..           ...                ...               ...
# 122           NO            INTERNA  TUBOS Y PERFILES
# 123           NO            INTERNA  TUBOS Y PERFILES
# 124           NO            INTERNA  TUBOS Y PERFILES
# 125           NO            INTERNA  TUBOS Y PERFILES
# 126           NO            INTERNA  TUBOS Y PERFILES
#
# [127 rows x 32 columns]

# %%
data=pd.DataFrame(data)
data
# Out:
#         idMaterial ACEROOrigen CPRODTOOrigen  CCLASEPRODTOOrigen  N_ANCHO  \
# 0    2A849644GM200        7092      MP501073  M-P-CALIENTE-BOB-_      0.0
# 1    2A850796GM200        7061      MP501073  M-P-CALIENTE-BOB-_    999.0
# 2    2A851998GM200        7094      MP509656  M-P-CALIENTE-BOB-_   1206.0
# 3    2A854123GM200        7061      MP501073  M-P-CALIENTE-BOB-_    149.5
# 4    2A857872GM200        2060      MP501073  M-P-CALIENTE-BOB-_     97.4
# ..             ...         ...           ...                 ...      ...
# 122  2A879262GM200        7092      MP501073  M-P-CALIENTE-BOB-_      NaN
# 123  2A879254GM200        4092      MP501073  M-P-CALIENTE-BOB-_      NaN
# 124  2A884998GM200        2060      MP501073  M-P-CALIENTE-BOB-_      NaN
# 125  2A883720GM200        2084      MP509656  M-P-CALIENTE-BOB-_      NaN
# 126  2A882296GM200        7094      MP509656  M-P-CALIENTE-BOB-_      NaN
#
#      N_ESPESOR Clasificacion_Norma CLASIFICACION_TIPO_ACERO BORDESOrigen  \
# 0        0.000                  CS                       CS   LAMINACIÓN
# 1        0.800                  CS                       CS   LAMINACIÓN
# 2        0.770                HSLA                       HS   LAMINACIÓN
# 3        3.150                  CS                       CS   LAMINACIÓN
# 4        1.825                  CS                       CS   LAMINACIÓN
# ..         ...                 ...                      ...          ...
# 122        NaN                  CS                       CS   LAMINACIÓN
# 123        NaN                  CS                       CS   LAMINACIÓN
# 124        NaN                  CS                       CS   LAMINACIÓN
# 125        NaN                HSLA                       HS   LAMINACIÓN
# 126        NaN                HSLA                       HS   LAMINACIÓN
#
#      DIAM__INTERNOOrigen  ... BORDESDestino DIAM__INTERNODestino  \
# 0                    711  ...    LAMINACIÓN                  711
# 1                    711  ...    LAMINACIÓN                  711
# 2                    711  ...    LAMINACIÓN                  711
# 3                    711  ...    LAMINACIÓN                  711
# 4                    711  ...    LAMINACIÓN                  711
# ..                   ...  ...           ...                  ...
# 122                  711  ...    LAMINACIÓN                  711
# 123                  711  ...    LAMINACIÓN                  711
# 124                  711  ...    LAMINACIÓN                  711
# 125                  711  ...    LAMINACIÓN                  711
# 126                  711  ...    LAMINACIÓN                  711
#
#                  EXTREMOSDestino                            NORMADestino  \
# 0    NO CORTADOS 98% EN ESPESOR.             TER \ PER-GA (V 2006 REV 1)
# 1    NO CORTADOS 98% EN ESPESOR.  TER \ PER-GA \ TUBE GLV (V 2015 REV 0)
# 2    NO CORTADOS 98% EN ESPESOR.             TER \ PER-GA (V 2006 REV 1)
# 3    NO CORTADOS 98% EN ESPESOR.             TER \ PER-GA (V 2006 REV 1)
# 4    NO CORTADOS 98% EN ESPESOR.             TER \ PER-GA (V 2006 REV 1)
# ..                           ...                                     ...
# 122  NO CORTADOS 98% EN ESPESOR.             TER \ PER-GA (V 2006 REV 1)
# 123  NO CORTADOS 98% EN ESPESOR.             TER \ PER-GA (V 2006 REV 1)
# 124  NO CORTADOS 98% EN ESPESOR.             TER \ PER-GA (V 2006 REV 1)
# 125  NO CORTADOS 98% EN ESPESOR.  TER \ PER-GA \ TUBE GLV (V 2015 REV 0)
# 126  NO CORTADOS 98% EN ESPESOR.  TER \ PER-GA \ TUBE GLV (V 2015 REV 0)
#
#      NORTOLANCHODestino    NORTOLESPESORDestino   PLANITUDDestino  \
# 0    ASTM A 568 / A 635      ASTM A 568 / A 635  TERNIUM ESTANDAR
# 1    ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR
# 2    ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR
# 3    ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR
# 4    ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR
# ..                  ...                     ...               ...
# 122  ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR
# 123  ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR
# 124  ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR
# 125  ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR
# 126  ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR
#
#     SOLDADestino  SUPERFICIEDestino    USOGRALDestino
# 0             NO            INTERNA  TUBOS Y PERFILES
# 1             NO            INTERNA  TUBOS Y PERFILES
# 2             NO            INTERNA  TUBOS Y PERFILES
# 3             NO            INTERNA  TUBOS Y PERFILES
# 4             NO            INTERNA  TUBOS Y PERFILES
# ..           ...                ...               ...
# 122           NO            INTERNA  TUBOS Y PERFILES
# 123           NO            INTERNA  TUBOS Y PERFILES
# 124           NO            INTERNA  TUBOS Y PERFILES
# 125           NO            INTERNA  TUBOS Y PERFILES
# 126           NO            INTERNA  TUBOS Y PERFILES
#
# [127 rows x 32 columns]

# %%
databuena=data.loc[:, ['ACEROOrigen', 'ACERODestino', 
       'CCLASEPRODTOOrigen', 'BORDESOrigen', 'DIAM__INTERNOOrigen',
       'EXTREMOSOrigen', 'NORMAOrigen', 'NORTOLANCHOOrigen',
       'NORTOLESPESOROrigen', 'PLANITUDOrigen', 'SOLDAOrigen',
       'SUPERFICIEOrigen', 'USOGRALOrigen', 'CCLASEPRODTODestino',
       'BORDESDestino', 'DIAM__INTERNODestino', 'EXTREMOSDestino',
       'NORMADestino', 'NORTOLANCHODestino', 'NORTOLESPESORDestino',
       'PLANITUDDestino', 'SOLDADestino', 'SUPERFICIEDestino',
       'USOGRALDestino']]
databuena
# Out:
#     ACEROOrigen ACERODestino  CCLASEPRODTOOrigen BORDESOrigen  \
# 0          7092          NaN  M-P-CALIENTE-BOB-_   LAMINACIÓN
# 1          7061         7092  M-P-CALIENTE-BOB-_   LAMINACIÓN
# 2          7094         7092  M-P-CALIENTE-BOB-_   LAMINACIÓN
# 3          7061       C091TM  M-P-CALIENTE-BOB-_   LAMINACIÓN
# 4          2060          NaN  M-P-CALIENTE-BOB-_   LAMINACIÓN
# ..          ...          ...                 ...          ...
# 122        7092       C091TM  M-P-CALIENTE-BOB-_   LAMINACIÓN
# 123        4092       C091TM  M-P-CALIENTE-BOB-_   LAMINACIÓN
# 124        2060         7092  M-P-CALIENTE-BOB-_   LAMINACIÓN
# 125        2084         7092  M-P-CALIENTE-BOB-_   LAMINACIÓN
# 126        7094         7092  M-P-CALIENTE-BOB-_   LAMINACIÓN
#
#      DIAM__INTERNOOrigen               EXTREMOSOrigen  \
# 0                    711  NO CORTADOS 98% EN ESPESOR.
# 1                    711  NO CORTADOS 98% EN ESPESOR.
# 2                    711  NO CORTADOS 98% EN ESPESOR.
# 3                    711  NO CORTADOS 98% EN ESPESOR.
# 4                    711  NO CORTADOS 98% EN ESPESOR.
# ..                   ...                          ...
# 122                  711  NO CORTADOS 98% EN ESPESOR.
# 123                  711  NO CORTADOS 98% EN ESPESOR.
# 124                  711  NO CORTADOS 98% EN ESPESOR.
# 125                  711  NO CORTADOS 98% EN ESPESOR.
# 126                  711  NO CORTADOS 98% EN ESPESOR.
#
#                                        NORMAOrigen   NORTOLANCHOOrigen  \
# 0               ASTM A 569 \ TIPO B (V 1997 REV 1)  ASTM A 568 / A 635
# 1               ASTM A 569 \ TIPO B (V 1997 REV 1)  ASTM A 568 / A 635
# 2    ASTM A 1011 \ HSLAS 45 CLASE 2 (V 2006 REV 2)  ASTM A 568 / A 635
# 3               ASTM A 569 \ TIPO B (V 1997 REV 1)  ASTM A 568 / A 635
# 4               ASTM A 569 \ TIPO B (V 1997 REV 1)  ASTM A 568 / A 635
# ..                                             ...                 ...
# 122             ASTM A 569 \ TIPO B (V 1997 REV 1)  ASTM A 568 / A 635
# 123             ASTM A 569 \ TIPO B (V 1997 REV 1)  ASTM A 568 / A 635
# 124             ASTM A 569 \ TIPO B (V 1997 REV 1)  ASTM A 568 / A 635
# 125  ASTM A 1011 \ HSLAS 45 CLASE 2 (V 2006 REV 2)  ASTM A 568 / A 635
# 126  ASTM A 1011 \ HSLAS 45 CLASE 2 (V 2006 REV 2)  ASTM A 568 / A 635
#
#     NORTOLESPESOROrigen    PLANITUDOrigen  ... BORDESDestino  \
# 0    ASTM A 568 / A 635  TERNIUM ESTANDAR  ...    LAMINACIÓN
# 1    ASTM A 568 / A 635  TERNIUM ESTANDAR  ...    LAMINACIÓN
# 2    ASTM A 568 / A 635  TERNIUM ESTANDAR  ...    LAMINACIÓN
# 3    ASTM A 568 / A 635  TERNIUM ESTANDAR  ...    LAMINACIÓN
# 4    ASTM A 568 / A 635  TERNIUM ESTANDAR  ...    LAMINACIÓN
# ..                  ...               ...  ...           ...
# 122  ASTM A 568 / A 635  TERNIUM ESTANDAR  ...    LAMINACIÓN
# 123  ASTM A 568 / A 635  TERNIUM ESTANDAR  ...    LAMINACIÓN
# 124  ASTM A 568 / A 635  TERNIUM ESTANDAR  ...    LAMINACIÓN
# 125  ASTM A 568 / A 635  TERNIUM ESTANDAR  ...    LAMINACIÓN
# 126  ASTM A 568 / A 635  TERNIUM ESTANDAR  ...    LAMINACIÓN
#
#     DIAM__INTERNODestino              EXTREMOSDestino  \
# 0                    711  NO CORTADOS 98% EN ESPESOR.
# 1                    711  NO CORTADOS 98% EN ESPESOR.
# 2                    711  NO CORTADOS 98% EN ESPESOR.
# 3                    711  NO CORTADOS 98% EN ESPESOR.
# 4                    711  NO CORTADOS 98% EN ESPESOR.
# ..                   ...                          ...
# 122                  711  NO CORTADOS 98% EN ESPESOR.
# 123                  711  NO CORTADOS 98% EN ESPESOR.
# 124                  711  NO CORTADOS 98% EN ESPESOR.
# 125                  711  NO CORTADOS 98% EN ESPESOR.
# 126                  711  NO CORTADOS 98% EN ESPESOR.
#
#                                NORMADestino  NORTOLANCHODestino  \
# 0               TER \ PER-GA (V 2006 REV 1)  ASTM A 568 / A 635
# 1    TER \ PER-GA \ TUBE GLV (V 2015 REV 0)  ASTM A 568 / A 635
# 2               TER \ PER-GA (V 2006 REV 1)  ASTM A 568 / A 635
# 3               TER \ PER-GA (V 2006 REV 1)  ASTM A 568 / A 635
# 4               TER \ PER-GA (V 2006 REV 1)  ASTM A 568 / A 635
# ..                                      ...                 ...
# 122             TER \ PER-GA (V 2006 REV 1)  ASTM A 568 / A 635
# 123             TER \ PER-GA (V 2006 REV 1)  ASTM A 568 / A 635
# 124             TER \ PER-GA (V 2006 REV 1)  ASTM A 568 / A 635
# 125  TER \ PER-GA \ TUBE GLV (V 2015 REV 0)  ASTM A 568 / A 635
# 126  TER \ PER-GA \ TUBE GLV (V 2015 REV 0)  ASTM A 568 / A 635
#
#        NORTOLESPESORDestino   PLANITUDDestino SOLDADestino SUPERFICIEDestino  \
# 0        ASTM A 568 / A 635  TERNIUM ESTANDAR           NO           INTERNA
# 1    1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR           NO           INTERNA
# 2    1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR           NO           INTERNA
# 3    1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR           NO           INTERNA
# 4    1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR           NO           INTERNA
# ..                      ...               ...          ...               ...
# 122  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR           NO           INTERNA
# 123  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR           NO           INTERNA
# 124  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR           NO           INTERNA
# 125  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR           NO           INTERNA
# 126  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR           NO           INTERNA
#
#        USOGRALDestino
# 0    TUBOS Y PERFILES
# 1    TUBOS Y PERFILES
# 2    TUBOS Y PERFILES
# 3    TUBOS Y PERFILES
# 4    TUBOS Y PERFILES
# ..                ...
# 122  TUBOS Y PERFILES
# 123  TUBOS Y PERFILES
# 124  TUBOS Y PERFILES
# 125  TUBOS Y PERFILES
# 126  TUBOS Y PERFILES
#
# [127 rows x 24 columns]

# %%
databuena.columns
# Out:
# Index(['ACEROOrigen', 'ACERODestino', 'CCLASEPRODTOOrigen', 'BORDESOrigen',
#        'DIAM__INTERNOOrigen', 'EXTREMOSOrigen', 'NORMAOrigen',
#        'NORTOLANCHOOrigen', 'NORTOLESPESOROrigen', 'PLANITUDOrigen',
#        'SOLDAOrigen', 'SUPERFICIEOrigen', 'USOGRALOrigen',
#        'CCLASEPRODTODestino', 'BORDESDestino', 'DIAM__INTERNODestino',
#        'EXTREMOSDestino', 'NORMADestino', 'NORTOLANCHODestino',
#        'NORTOLESPESORDestino', 'PLANITUDDestino', 'SOLDADestino',
#        'SUPERFICIEDestino', 'USOGRALDestino'],
#       dtype='object')

# %%
datae=enc.transform(databuena)
datae
# Out:
#      ACEROOrigen  ACERODestino  CCLASEPRODTOOrigen  BORDESOrigen  \
# 0       0.505072      0.505072            0.505072      0.505072
# 1       0.505072      0.490260            0.505072      0.505072
# 2       0.505072      0.490260            0.505072      0.505072
# 3       0.505072      0.873698            0.505072      0.505072
# 4       0.505072      0.505072            0.505072      0.505072
# ..           ...           ...                 ...           ...
# 122     0.505072      0.873698            0.505072      0.505072
# 123     0.505072      0.873698            0.505072      0.505072
# 124     0.505072      0.490260            0.505072      0.505072
# 125     0.505072      0.490260            0.505072      0.505072
# 126     0.505072      0.490260            0.505072      0.505072
#
#      DIAM__INTERNOOrigen  EXTREMOSOrigen  NORMAOrigen  NORTOLANCHOOrigen  \
# 0               0.505072        0.505072     0.690153           0.511936
# 1               0.505072        0.505072     0.690153           0.511936
# 2               0.505072        0.505072     0.661885           0.511936
# 3               0.505072        0.505072     0.690153           0.511936
# 4               0.505072        0.505072     0.690153           0.511936
# ..                   ...             ...          ...                ...
# 122             0.505072        0.505072     0.690153           0.511936
# 123             0.505072        0.505072     0.690153           0.511936
# 124             0.505072        0.505072     0.690153           0.511936
# 125             0.505072        0.505072     0.661885           0.511936
# 126             0.505072        0.505072     0.661885           0.511936
#
#      NORTOLESPESOROrigen  PLANITUDOrigen  ...  BORDESDestino  \
# 0               0.599888        0.505072  ...       0.505072
# 1               0.599888        0.505072  ...       0.505072
# 2               0.599888        0.505072  ...       0.505072
# 3               0.599888        0.505072  ...       0.505072
# 4               0.599888        0.505072  ...       0.505072
# ..                   ...             ...  ...            ...
# 122             0.599888        0.505072  ...       0.505072
# 123             0.599888        0.505072  ...       0.505072
# 124             0.599888        0.505072  ...       0.505072
# 125             0.599888        0.505072  ...       0.505072
# 126             0.599888        0.505072  ...       0.505072
#
#      DIAM__INTERNODestino  EXTREMOSDestino  NORMADestino  NORTOLANCHODestino  \
# 0                0.505072         0.505072      0.701543            0.553336
# 1                0.505072         0.505072      0.886700            0.553336
# 2                0.505072         0.505072      0.701543            0.553336
# 3                0.505072         0.505072      0.701543            0.553336
# 4                0.505072         0.505072      0.701543            0.553336
# ..                    ...              ...           ...                 ...
# 122              0.505072         0.505072      0.701543            0.553336
# 123              0.505072         0.505072      0.701543            0.553336
# 124              0.505072         0.505072      0.701543            0.553336
# 125              0.505072         0.505072      0.886700            0.553336
# 126              0.505072         0.505072      0.886700            0.553336
#
#      NORTOLESPESORDestino  PLANITUDDestino  SOLDADestino  SUPERFICIEDestino  \
# 0                0.568254         0.505072      0.505072           0.557074
# 1                0.463054         0.505072      0.505072           0.557074
# 2                0.463054         0.505072      0.505072           0.557074
# 3                0.463054         0.505072      0.505072           0.557074
# 4                0.463054         0.505072      0.505072           0.557074
# ..                    ...              ...           ...                ...
# 122              0.463054         0.505072      0.505072           0.557074
# 123              0.463054         0.505072      0.505072           0.557074
# 124              0.463054         0.505072      0.505072           0.557074
# 125              0.463054         0.505072      0.505072           0.557074
# 126              0.463054         0.505072      0.505072           0.557074
#
#      USOGRALDestino
# 0          0.643462
# 1          0.643462
# 2          0.643462
# 3          0.643462
# 4          0.643462
# ..              ...
# 122        0.643462
# 123        0.643462
# 124        0.643462
# 125        0.643462
# 126        0.643462
#
# [127 rows x 24 columns]

# %%
predic=dt.predict(datae)

# %%
Resultados=pd.DataFrame(data=predic,columns=['Reasignacion'])
Resultados.head
# Out:
# <bound method NDFrame.head of      Reasignacion
# 0               0
# 1               1
# 2               1
# 3               1
# 4               1
# ..            ...
# 122             1
# 123             1
# 124             1
# 125             1
# 126             1
#
# [127 rows x 1 columns]>

# %%
ResultadosF=encobj.inverse_transform(Resultados)
ResultadosF=pd.DataFrame(data=ResultadosF,columns=['Reasignacion'])
ResultadosF
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
#     Reasignacion
# 0             OK
# 1      Rechazado
# 2      Rechazado
# 3      Rechazado
# 4      Rechazado
# ..           ...
# 122    Rechazado
# 123    Rechazado
# 124    Rechazado
# 125    Rechazado
# 126    Rechazado
#
# [127 rows x 1 columns]

# %%
concatenated = pd.concat([data, ResultadosF],axis=1) 
concatenated
# Out:
#         idMaterial ACEROOrigen CPRODTOOrigen  CCLASEPRODTOOrigen  N_ANCHO  \
# 0    2A849644GM200        7092      MP501073  M-P-CALIENTE-BOB-_      0.0
# 1    2A850796GM200        7061      MP501073  M-P-CALIENTE-BOB-_    999.0
# 2    2A851998GM200        7094      MP509656  M-P-CALIENTE-BOB-_   1206.0
# 3    2A854123GM200        7061      MP501073  M-P-CALIENTE-BOB-_    149.5
# 4    2A857872GM200        2060      MP501073  M-P-CALIENTE-BOB-_     97.4
# ..             ...         ...           ...                 ...      ...
# 122  2A879262GM200        7092      MP501073  M-P-CALIENTE-BOB-_      NaN
# 123  2A879254GM200        4092      MP501073  M-P-CALIENTE-BOB-_      NaN
# 124  2A884998GM200        2060      MP501073  M-P-CALIENTE-BOB-_      NaN
# 125  2A883720GM200        2084      MP509656  M-P-CALIENTE-BOB-_      NaN
# 126  2A882296GM200        7094      MP509656  M-P-CALIENTE-BOB-_      NaN
#
#      N_ESPESOR Clasificacion_Norma CLASIFICACION_TIPO_ACERO BORDESOrigen  \
# 0        0.000                  CS                       CS   LAMINACIÓN
# 1        0.800                  CS                       CS   LAMINACIÓN
# 2        0.770                HSLA                       HS   LAMINACIÓN
# 3        3.150                  CS                       CS   LAMINACIÓN
# 4        1.825                  CS                       CS   LAMINACIÓN
# ..         ...                 ...                      ...          ...
# 122        NaN                  CS                       CS   LAMINACIÓN
# 123        NaN                  CS                       CS   LAMINACIÓN
# 124        NaN                  CS                       CS   LAMINACIÓN
# 125        NaN                HSLA                       HS   LAMINACIÓN
# 126        NaN                HSLA                       HS   LAMINACIÓN
#
#      DIAM__INTERNOOrigen  ... DIAM__INTERNODestino  \
# 0                    711  ...                  711
# 1                    711  ...                  711
# 2                    711  ...                  711
# 3                    711  ...                  711
# 4                    711  ...                  711
# ..                   ...  ...                  ...
# 122                  711  ...                  711
# 123                  711  ...                  711
# 124                  711  ...                  711
# 125                  711  ...                  711
# 126                  711  ...                  711
#
#                  EXTREMOSDestino                            NORMADestino  \
# 0    NO CORTADOS 98% EN ESPESOR.             TER \ PER-GA (V 2006 REV 1)
# 1    NO CORTADOS 98% EN ESPESOR.  TER \ PER-GA \ TUBE GLV (V 2015 REV 0)
# 2    NO CORTADOS 98% EN ESPESOR.             TER \ PER-GA (V 2006 REV 1)
# 3    NO CORTADOS 98% EN ESPESOR.             TER \ PER-GA (V 2006 REV 1)
# 4    NO CORTADOS 98% EN ESPESOR.             TER \ PER-GA (V 2006 REV 1)
# ..                           ...                                     ...
# 122  NO CORTADOS 98% EN ESPESOR.             TER \ PER-GA (V 2006 REV 1)
# 123  NO CORTADOS 98% EN ESPESOR.             TER \ PER-GA (V 2006 REV 1)
# 124  NO CORTADOS 98% EN ESPESOR.             TER \ PER-GA (V 2006 REV 1)
# 125  NO CORTADOS 98% EN ESPESOR.  TER \ PER-GA \ TUBE GLV (V 2015 REV 0)
# 126  NO CORTADOS 98% EN ESPESOR.  TER \ PER-GA \ TUBE GLV (V 2015 REV 0)
#
#      NORTOLANCHODestino    NORTOLESPESORDestino   PLANITUDDestino  \
# 0    ASTM A 568 / A 635      ASTM A 568 / A 635  TERNIUM ESTANDAR
# 1    ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR
# 2    ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR
# 3    ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR
# 4    ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR
# ..                  ...                     ...               ...
# 122  ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR
# 123  ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR
# 124  ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR
# 125  ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR
# 126  ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM ESTANDAR
#
#     SOLDADestino SUPERFICIEDestino    USOGRALDestino Reasignacion
# 0             NO           INTERNA  TUBOS Y PERFILES           OK
# 1             NO           INTERNA  TUBOS Y PERFILES    Rechazado
# 2             NO           INTERNA  TUBOS Y PERFILES    Rechazado
# 3             NO           INTERNA  TUBOS Y PERFILES    Rechazado
# 4             NO           INTERNA  TUBOS Y PERFILES    Rechazado
# ..           ...               ...               ...          ...
# 122           NO           INTERNA  TUBOS Y PERFILES    Rechazado
# 123           NO           INTERNA  TUBOS Y PERFILES    Rechazado
# 124           NO           INTERNA  TUBOS Y PERFILES    Rechazado
# 125           NO           INTERNA  TUBOS Y PERFILES    Rechazado
# 126           NO           INTERNA  TUBOS Y PERFILES    Rechazado
#
# [127 rows x 33 columns]

# %%
datae_train,datae_test,Resultados_train,Resultados_test=train_test_split(datae,Resultados)

# %%
dtc.fit(datae_train,Resultados_train)
# Out:
# DecisionTreeClassifier()

# %%
dtc.score(datae_train,Resultados_train)
# Out:
# 1.0

# %%
dtc.score(datae_test,Resultados_test)
# Out:
# 1.0

# %%
# Separando los datos en sets de entrenamiento y evaluación
datae_train, datae_test, Resultados_train, Resultados_test = train_test_split(datae, 
                        Resultados, random_state=1)


tree = DecisionTreeClassifier(max_depth=2, random_state=0)
tree.fit(datae_train, Resultados_train)
print('Precisión modelo inicial train/test  {0:.3f}/{1:.3f}'
      .format(tree.score(datae_train, Resultados_train), tree.score(datae_test, Resultados_test)))
# Out:
# Precisión modelo inicial train/test  0.979/0.969

# %%
# Utilizando AdaBoost para aumentar la precisión
ada = AdaBoostClassifier(base_estimator=tree, n_estimators=500, 
                         learning_rate=1.5, random_state=1)
# Ajustando los datos
ada = ada.fit(datae_train, Resultados_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
# Imprimir la precisión.
y_train_pred = ada.predict(datae_train)
y_test_pred = ada.predict(datae_test)
ada_train = accuracy_score(Resultados_train, y_train_pred)
ada_test = accuracy_score(Resultados_test, y_test_pred)
print('Precisión modelo con AdaBoost train/test  {0:.3f}/{1:.3f}'
      .format(ada_train, ada_test))
# Out:
# Precisión modelo con AdaBoost train/test  1.000/1.000

# %%
# Armando el modelo con parametro max_depth
gbrt = GradientBoostingClassifier(random_state=0, n_estimators=500,
                                  max_depth=1, learning_rate=0.01)
# Ajustando el modelo
gbrt.fit(datae_train, Resultados_train)
print('Precisión Gradient Boosting train/test  {0:.3f}/{1:.3f}'
      .format(gbrt.score(datae_train, Resultados_train), gbrt.score(datae_test, Resultados_test)))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Precisión Gradient Boosting train/test  0.979/0.969

# %%
concatenated.to_excel("ResultadoCaliente.xlsx")

# %%
concatenated.groupby('Reasignacion').size()
# Out:
# Reasignacion
# OK             4
# Rechazado    123
# dtype: int64
