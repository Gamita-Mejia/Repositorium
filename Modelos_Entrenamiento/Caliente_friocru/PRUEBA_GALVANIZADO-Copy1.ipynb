# %%
###importaciones
import pandas as pd
import numpy as np
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import category_encoders
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import LabelEncoder 
from sklearn.tree import DecisionTreeClassifier
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.tree import export_graphviz
import graphviz
import joblib
from sklearn.datasets import make_hastie_10_2
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
import xgboost as xgb

# graficos incrustados
# %matplotlib inline

# parametros esteticos de seaborn
sns.set_palette("deep", desat=.6)
sns.set_context(rc={"figure.figsize": (8, 4)})

# %%
datar=pd.read_excel('Cert_Caliente_FrioCru_19_01_21.xlsx')
dt=joblib.load('ModeloCaliente_friocru.pkl')
enc=joblib.load('TargetCaliente_friocru.pkl')
encobj=joblib.load('EncodificacionObjetivo.pkl')
dtc=DecisionTreeClassifier()
datar
# Out:
#         IdMaterial CPRODTOOrigen  CCLASEPRODTOOrigen  N_ANCHO  N_ESPESOR  \
# 0    2A852929GM200      MP509656  M-P-CALIENTE-BOB-_    457.9      0.642
# 1    2A854649GM200      MP501073  M-P-CALIENTE-BOB-_   1259.3      3.038
# 2    2A855104GM200      MP501073  M-P-CALIENTE-BOB-_    775.7      0.359
# 3    2A854623GM200      MP501073  M-P-CALIENTE-BOB-_    103.6      1.868
# 4    2A854650GM200      MP501073  M-P-CALIENTE-BOB-_   1188.6      0.465
# ..             ...           ...                 ...      ...        ...
# 758  2A882681GM200      MP500418  M-P-CALIENTE-BOB-_      NaN        NaN
# 759  2A882386GM200      MP500418  M-P-CALIENTE-BOB-_      NaN        NaN
# 760  2A882261GM200      MP509656  M-P-CALIENTE-BOB-_      NaN        NaN
# 761  2A870417GM200      MP509657  M-P-CALIENTE-BOB-_      NaN        NaN
# 762  2A884769GM200      MP501073  M-P-CALIENTE-BOB-_      NaN        NaN
#
#      ACEROOrigen  ACABSUPEROrigen BORDESOrigen  DIAM__INTERNOOrigen  \
# 0           7095                0   LAMINACIÓN                  711
# 1           7102                0   LAMINACIÓN                  711
# 2           7061                0   LAMINACIÓN                  711
# 3           7102                0   LAMINACIÓN                  711
# 4           7102                0   LAMINACIÓN                  711
# ..           ...              ...          ...                  ...
# 758         7095                0   LAMINACIÓN                  711
# 759         7095                0   LAMINACIÓN                  711
# 760         2084                0   LAMINACIÓN                  711
# 761         7094                0   LAMINACIÓN                  711
# 762         7092                0   LAMINACIÓN                  711
#
#                   EXTREMOSOrigen  ... BORDESDestino DIAM__INTERNODestino  \
# 0    NO CORTADOS 98% EN ESPESOR.  ...    LAMINACIÓN                  508
# 1    NO CORTADOS 98% EN ESPESOR.  ...    LAMINACIÓN                  508
# 2    NO CORTADOS 98% EN ESPESOR.  ...    LAMINACIÓN                  508
# 3    NO CORTADOS 98% EN ESPESOR.  ...    LAMINACIÓN                  508
# 4    NO CORTADOS 98% EN ESPESOR.  ...    LAMINACIÓN                  508
# ..                           ...  ...           ...                  ...
# 758  NO CORTADOS 98% EN ESPESOR.  ...    LAMINACIÓN                  508
# 759  NO CORTADOS 98% EN ESPESOR.  ...    LAMINACIÓN                  508
# 760  NO CORTADOS 98% EN ESPESOR.  ...    LAMINACIÓN                  508
# 761  NO CORTADOS 98% EN ESPESOR.  ...    LAMINACIÓN                  508
# 762  NO CORTADOS 98% EN ESPESOR.  ...    LAMINACIÓN                  508
#
#              EXTREMOSDestino                       NORMADestino  \
# 0    CORTADOS 98% EN ESPESOR     TER \ GA050 GAL (V 2011 REV 1)
# 1    CORTADOS 98% EN ESPESOR      TER \ 1006 GAL (V 2011 REV 1)
# 2    CORTADOS 98% EN ESPESOR      TER \ 1006 GAL (V 2011 REV 1)
# 3    CORTADOS 98% EN ESPESOR  TER \ GA040 GAL SS (V 2011 REV 1)
# 4    CORTADOS 98% EN ESPESOR      TER \ 1006 GAL (V 2011 REV 1)
# ..                       ...                                ...
# 758  CORTADOS 98% EN ESPESOR     TER \ GA050 GAL (V 2011 REV 1)
# 759  CORTADOS 98% EN ESPESOR     TER \ GA050 GAL (V 2011 REV 1)
# 760  CORTADOS 98% EN ESPESOR     TER \ GA050 GAL (V 2011 REV 1)
# 761  CORTADOS 98% EN ESPESOR     TER \ GA050 GAL (V 2011 REV 1)
# 762  CORTADOS 98% EN ESPESOR      TER \ 1006 GAL (V 2011 REV 1)
#
#     NORTOLANCHODestino  NORTOLESPESORDestino   PLANITUDDestino  SOLDADestino  \
# 0           ASTM A 568        1/2 ASTM A 568  TERNIUM ESTANDAR            NO
# 1           ASTM A 568        1/2 ASTM A 568  TERNIUM ESTANDAR            NO
# 2           ASTM A 568        1/2 ASTM A 568  TERNIUM ESTANDAR            NO
# 3           ASTM A 568        1/2 ASTM A 568  TERNIUM ESTANDAR            NO
# 4           ASTM A 568        1/2 ASTM A 568  TERNIUM ESTANDAR            NO
# ..                 ...                   ...               ...           ...
# 758         ASTM A 568        1/2 ASTM A 568  TERNIUM ESTANDAR            NO
# 759         ASTM A 568        1/2 ASTM A 568  TERNIUM ESTANDAR            NO
# 760         ASTM A 568        1/2 ASTM A 568  TERNIUM ESTANDAR            NO
# 761         ASTM A 568        1/2 ASTM A 568  TERNIUM ESTANDAR            NO
# 762    TER \ COMERCIAL        1/2 ASTM A 568  TERNIUM ESTANDAR            NO
#
#     SUPERFICIEDestino         USOGRALDestino
# 0       SEMI-EXPUESTA            GALVANIZADO
# 1       SEMI-EXPUESTA  GALV. IND/AUT SIN MFG
# 2       SEMI-EXPUESTA       GALV. INDUSTRIAL
# 3       SEMI-EXPUESTA            GALVANIZADO
# 4       SEMI-EXPUESTA     GALVANNEAL IND/AUT
# ..                ...                    ...
# 758     SEMI-EXPUESTA            GALVANIZADO
# 759     SEMI-EXPUESTA            GALVANIZADO
# 760     SEMI-EXPUESTA            GALVANIZADO
# 761     SEMI-EXPUESTA            GALVANIZADO
# 762     SEMI-EXPUESTA            GALVANIZADO
#
# [763 rows x 34 columns]

# %%
data=pd.DataFrame(data)
data
# Out:
#         IdMaterial CPRODTOOrigen  CCLASEPRODTOOrigen  N_ANCHO  N_ESPESOR  \
# 0    2A852929GM200      MP509656  M-P-CALIENTE-BOB-_    457.9      0.642
# 1    2A854649GM200      MP501073  M-P-CALIENTE-BOB-_   1259.3      3.038
# 2    2A855104GM200      MP501073  M-P-CALIENTE-BOB-_    775.7      0.359
# 3    2A854623GM200      MP501073  M-P-CALIENTE-BOB-_    103.6      1.868
# 4    2A854650GM200      MP501073  M-P-CALIENTE-BOB-_   1188.6      0.465
# ..             ...           ...                 ...      ...        ...
# 758  2A882681GM200      MP500418  M-P-CALIENTE-BOB-_      NaN        NaN
# 759  2A882386GM200      MP500418  M-P-CALIENTE-BOB-_      NaN        NaN
# 760  2A882261GM200      MP509656  M-P-CALIENTE-BOB-_      NaN        NaN
# 761  2A870417GM200      MP509657  M-P-CALIENTE-BOB-_      NaN        NaN
# 762  2A884769GM200      MP501073  M-P-CALIENTE-BOB-_      NaN        NaN
#
#      ACEROOrigen  ACABSUPEROrigen BORDESOrigen  DIAM__INTERNOOrigen  \
# 0           7095                0   LAMINACIÓN                  711
# 1           7102                0   LAMINACIÓN                  711
# 2           7061                0   LAMINACIÓN                  711
# 3           7102                0   LAMINACIÓN                  711
# 4           7102                0   LAMINACIÓN                  711
# ..           ...              ...          ...                  ...
# 758         7095                0   LAMINACIÓN                  711
# 759         7095                0   LAMINACIÓN                  711
# 760         2084                0   LAMINACIÓN                  711
# 761         7094                0   LAMINACIÓN                  711
# 762         7092                0   LAMINACIÓN                  711
#
#                   EXTREMOSOrigen  ... BORDESDestino DIAM__INTERNODestino  \
# 0    NO CORTADOS 98% EN ESPESOR.  ...    LAMINACIÓN                  508
# 1    NO CORTADOS 98% EN ESPESOR.  ...    LAMINACIÓN                  508
# 2    NO CORTADOS 98% EN ESPESOR.  ...    LAMINACIÓN                  508
# 3    NO CORTADOS 98% EN ESPESOR.  ...    LAMINACIÓN                  508
# 4    NO CORTADOS 98% EN ESPESOR.  ...    LAMINACIÓN                  508
# ..                           ...  ...           ...                  ...
# 758  NO CORTADOS 98% EN ESPESOR.  ...    LAMINACIÓN                  508
# 759  NO CORTADOS 98% EN ESPESOR.  ...    LAMINACIÓN                  508
# 760  NO CORTADOS 98% EN ESPESOR.  ...    LAMINACIÓN                  508
# 761  NO CORTADOS 98% EN ESPESOR.  ...    LAMINACIÓN                  508
# 762  NO CORTADOS 98% EN ESPESOR.  ...    LAMINACIÓN                  508
#
#              EXTREMOSDestino                       NORMADestino  \
# 0    CORTADOS 98% EN ESPESOR     TER \ GA050 GAL (V 2011 REV 1)
# 1    CORTADOS 98% EN ESPESOR      TER \ 1006 GAL (V 2011 REV 1)
# 2    CORTADOS 98% EN ESPESOR      TER \ 1006 GAL (V 2011 REV 1)
# 3    CORTADOS 98% EN ESPESOR  TER \ GA040 GAL SS (V 2011 REV 1)
# 4    CORTADOS 98% EN ESPESOR      TER \ 1006 GAL (V 2011 REV 1)
# ..                       ...                                ...
# 758  CORTADOS 98% EN ESPESOR     TER \ GA050 GAL (V 2011 REV 1)
# 759  CORTADOS 98% EN ESPESOR     TER \ GA050 GAL (V 2011 REV 1)
# 760  CORTADOS 98% EN ESPESOR     TER \ GA050 GAL (V 2011 REV 1)
# 761  CORTADOS 98% EN ESPESOR     TER \ GA050 GAL (V 2011 REV 1)
# 762  CORTADOS 98% EN ESPESOR      TER \ 1006 GAL (V 2011 REV 1)
#
#     NORTOLANCHODestino  NORTOLESPESORDestino   PLANITUDDestino  SOLDADestino  \
# 0           ASTM A 568        1/2 ASTM A 568  TERNIUM ESTANDAR            NO
# 1           ASTM A 568        1/2 ASTM A 568  TERNIUM ESTANDAR            NO
# 2           ASTM A 568        1/2 ASTM A 568  TERNIUM ESTANDAR            NO
# 3           ASTM A 568        1/2 ASTM A 568  TERNIUM ESTANDAR            NO
# 4           ASTM A 568        1/2 ASTM A 568  TERNIUM ESTANDAR            NO
# ..                 ...                   ...               ...           ...
# 758         ASTM A 568        1/2 ASTM A 568  TERNIUM ESTANDAR            NO
# 759         ASTM A 568        1/2 ASTM A 568  TERNIUM ESTANDAR            NO
# 760         ASTM A 568        1/2 ASTM A 568  TERNIUM ESTANDAR            NO
# 761         ASTM A 568        1/2 ASTM A 568  TERNIUM ESTANDAR            NO
# 762    TER \ COMERCIAL        1/2 ASTM A 568  TERNIUM ESTANDAR            NO
#
#     SUPERFICIEDestino         USOGRALDestino
# 0       SEMI-EXPUESTA            GALVANIZADO
# 1       SEMI-EXPUESTA  GALV. IND/AUT SIN MFG
# 2       SEMI-EXPUESTA       GALV. INDUSTRIAL
# 3       SEMI-EXPUESTA            GALVANIZADO
# 4       SEMI-EXPUESTA     GALVANNEAL IND/AUT
# ..                ...                    ...
# 758     SEMI-EXPUESTA            GALVANIZADO
# 759     SEMI-EXPUESTA            GALVANIZADO
# 760     SEMI-EXPUESTA            GALVANIZADO
# 761     SEMI-EXPUESTA            GALVANIZADO
# 762     SEMI-EXPUESTA            GALVANIZADO
#
# [763 rows x 34 columns]

# %%
databuena=data.loc[:, ['CCLASEPRODTOOrigen', 'ACEROOrigen', 'BORDESOrigen',
       'DIAM__INTERNOOrigen', 'EXTREMOSOrigen', 'NORMAOrigen',
       'NORTOLANCHOOrigen', 'NORTOLESPESOROrigen', 'PLANITUDOrigen',
       'SOLDAOrigen', 'SUPERFICIEOrigen', 'USOGRALOrigen', 'CPRODTODestino',
       'CCLASEPRODTODestino', 'ACERODestino', 
       'BORDESDestino', 'DIAM__INTERNODestino', 'EXTREMOSDestino',
       'NORMADestino', 'NORTOLANCHODestino', 'NORTOLESPESORDestino',
       'PLANITUDDestino', 'SOLDADestino', 'SUPERFICIEDestino',
       'USOGRALDestino']]
databuena
# Out:
#      CCLASEPRODTOOrigen  ACEROOrigen BORDESOrigen  DIAM__INTERNOOrigen  \
# 0    M-P-CALIENTE-BOB-_         7095   LAMINACIÓN                  711
# 1    M-P-CALIENTE-BOB-_         7102   LAMINACIÓN                  711
# 2    M-P-CALIENTE-BOB-_         7061   LAMINACIÓN                  711
# 3    M-P-CALIENTE-BOB-_         7102   LAMINACIÓN                  711
# 4    M-P-CALIENTE-BOB-_         7102   LAMINACIÓN                  711
# ..                  ...          ...          ...                  ...
# 758  M-P-CALIENTE-BOB-_         7095   LAMINACIÓN                  711
# 759  M-P-CALIENTE-BOB-_         7095   LAMINACIÓN                  711
# 760  M-P-CALIENTE-BOB-_         2084   LAMINACIÓN                  711
# 761  M-P-CALIENTE-BOB-_         7094   LAMINACIÓN                  711
# 762  M-P-CALIENTE-BOB-_         7092   LAMINACIÓN                  711
#
#                   EXTREMOSOrigen  \
# 0    NO CORTADOS 98% EN ESPESOR.
# 1    NO CORTADOS 98% EN ESPESOR.
# 2    NO CORTADOS 98% EN ESPESOR.
# 3    NO CORTADOS 98% EN ESPESOR.
# 4    NO CORTADOS 98% EN ESPESOR.
# ..                           ...
# 758  NO CORTADOS 98% EN ESPESOR.
# 759  NO CORTADOS 98% EN ESPESOR.
# 760  NO CORTADOS 98% EN ESPESOR.
# 761  NO CORTADOS 98% EN ESPESOR.
# 762  NO CORTADOS 98% EN ESPESOR.
#
#                                        NORMAOrigen   NORTOLANCHOOrigen  \
# 0    ASTM A 1011 \ HSLAS 45 CLASE 2 (V 2006 REV 2)  ASTM A 568 / A 635
# 1               ASTM A 569 \ TIPO B (V 1997 REV 1)  ASTM A 568 / A 635
# 2               ASTM A 569 \ TIPO B (V 1997 REV 1)  ASTM A 568 / A 635
# 3               ASTM A 569 \ TIPO B (V 1997 REV 1)  ASTM A 568 / A 635
# 4               ASTM A 569 \ TIPO B (V 1997 REV 1)  ASTM A 568 / A 635
# ..                                             ...                 ...
# 758                       ASTM A 36 (V 2005 REV 1)  ASTM A 568 / A 635
# 759                       ASTM A 36 (V 2005 REV 1)  ASTM A 568 / A 635
# 760  ASTM A 1011 \ HSLAS 45 CLASE 2 (V 2006 REV 2)  ASTM A 568 / A 635
# 761  ASTM A 1011 \ HSLAS 60 CLASE 2 (V 2006 REV 2)  ASTM A 568 / A 635
# 762             ASTM A 569 \ TIPO B (V 1997 REV 1)  ASTM A 568 / A 635
#
#     NORTOLESPESOROrigen    PLANITUDOrigen SOLDAOrigen  ...  BORDESDestino  \
# 0    ASTM A 568 / A 635  TERNIUM ESTANDAR          NO  ...     LAMINACIÓN
# 1    ASTM A 568 / A 635  TERNIUM ESTANDAR          NO  ...     LAMINACIÓN
# 2    ASTM A 568 / A 635  TERNIUM ESTANDAR          NO  ...     LAMINACIÓN
# 3    ASTM A 568 / A 635  TERNIUM ESTANDAR          NO  ...     LAMINACIÓN
# 4    ASTM A 568 / A 635  TERNIUM ESTANDAR          NO  ...     LAMINACIÓN
# ..                  ...               ...         ...  ...            ...
# 758  ASTM A 568 / A 635  TERNIUM ESTANDAR          NO  ...     LAMINACIÓN
# 759  ASTM A 568 / A 635  TERNIUM ESTANDAR          NO  ...     LAMINACIÓN
# 760  ASTM A 568 / A 635  TERNIUM ESTANDAR          NO  ...     LAMINACIÓN
# 761  ASTM A 568 / A 635  TERNIUM ESTANDAR          NO  ...     LAMINACIÓN
# 762  ASTM A 568 / A 635  TERNIUM ESTANDAR          NO  ...     LAMINACIÓN
#
#     DIAM__INTERNODestino          EXTREMOSDestino  \
# 0                    508  CORTADOS 98% EN ESPESOR
# 1                    508  CORTADOS 98% EN ESPESOR
# 2                    508  CORTADOS 98% EN ESPESOR
# 3                    508  CORTADOS 98% EN ESPESOR
# 4                    508  CORTADOS 98% EN ESPESOR
# ..                   ...                      ...
# 758                  508  CORTADOS 98% EN ESPESOR
# 759                  508  CORTADOS 98% EN ESPESOR
# 760                  508  CORTADOS 98% EN ESPESOR
# 761                  508  CORTADOS 98% EN ESPESOR
# 762                  508  CORTADOS 98% EN ESPESOR
#
#                           NORMADestino NORTOLANCHODestino  \
# 0       TER \ GA050 GAL (V 2011 REV 1)         ASTM A 568
# 1        TER \ 1006 GAL (V 2011 REV 1)         ASTM A 568
# 2        TER \ 1006 GAL (V 2011 REV 1)         ASTM A 568
# 3    TER \ GA040 GAL SS (V 2011 REV 1)         ASTM A 568
# 4        TER \ 1006 GAL (V 2011 REV 1)         ASTM A 568
# ..                                 ...                ...
# 758     TER \ GA050 GAL (V 2011 REV 1)         ASTM A 568
# 759     TER \ GA050 GAL (V 2011 REV 1)         ASTM A 568
# 760     TER \ GA050 GAL (V 2011 REV 1)         ASTM A 568
# 761     TER \ GA050 GAL (V 2011 REV 1)         ASTM A 568
# 762      TER \ 1006 GAL (V 2011 REV 1)    TER \ COMERCIAL
#
#     NORTOLESPESORDestino   PLANITUDDestino SOLDADestino SUPERFICIEDestino  \
# 0         1/2 ASTM A 568  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA
# 1         1/2 ASTM A 568  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA
# 2         1/2 ASTM A 568  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA
# 3         1/2 ASTM A 568  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA
# 4         1/2 ASTM A 568  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA
# ..                   ...               ...          ...               ...
# 758       1/2 ASTM A 568  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA
# 759       1/2 ASTM A 568  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA
# 760       1/2 ASTM A 568  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA
# 761       1/2 ASTM A 568  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA
# 762       1/2 ASTM A 568  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA
#
#             USOGRALDestino
# 0              GALVANIZADO
# 1    GALV. IND/AUT SIN MFG
# 2         GALV. INDUSTRIAL
# 3              GALVANIZADO
# 4       GALVANNEAL IND/AUT
# ..                     ...
# 758            GALVANIZADO
# 759            GALVANIZADO
# 760            GALVANIZADO
# 761            GALVANIZADO
# 762            GALVANIZADO
#
# [763 rows x 25 columns]

# %%
databuena.columns
# Out:
# Index(['CCLASEPRODTOOrigen', 'ACEROOrigen', 'BORDESOrigen',
#        'DIAM__INTERNOOrigen', 'EXTREMOSOrigen', 'NORMAOrigen',
#        'NORTOLANCHOOrigen', 'NORTOLESPESOROrigen', 'PLANITUDOrigen',
#        'SOLDAOrigen', 'SUPERFICIEOrigen', 'USOGRALOrigen', 'CPRODTODestino',
#        'CCLASEPRODTODestino', 'ACERODestino', 'BORDESDestino',
#        'DIAM__INTERNODestino', 'EXTREMOSDestino', 'NORMADestino',
#        'NORTOLANCHODestino', 'NORTOLESPESORDestino', 'PLANITUDDestino',
#        'SOLDADestino', 'SUPERFICIEDestino', 'USOGRALDestino'],
#       dtype='object')

# %%
datae=enc.transform(databuena)
datae
# Out:
#      CCLASEPRODTOOrigen  ACEROOrigen  BORDESOrigen  DIAM__INTERNOOrigen  \
# 0              0.041783     0.041783      0.041783             0.041826
# 1              0.041783     0.041783      0.041783             0.041826
# 2              0.041783     0.041783      0.041783             0.041826
# 3              0.041783     0.041783      0.041783             0.041826
# 4              0.041783     0.041783      0.041783             0.041826
# ..                  ...          ...           ...                  ...
# 758            0.041783     0.041783      0.041783             0.041826
# 759            0.041783     0.041783      0.041783             0.041826
# 760            0.041783     0.041783      0.041783             0.041826
# 761            0.041783     0.041783      0.041783             0.041826
# 762            0.041783     0.041783      0.041783             0.041826
#
#      EXTREMOSOrigen  NORMAOrigen  NORTOLANCHOOrigen  NORTOLESPESOROrigen  \
# 0          0.041473     0.026219            0.04318              0.04172
# 1          0.041473     0.059358            0.04318              0.04172
# 2          0.041473     0.059358            0.04318              0.04172
# 3          0.041473     0.059358            0.04318              0.04172
# 4          0.041473     0.059358            0.04318              0.04172
# ..              ...          ...                ...                  ...
# 758        0.041473     0.045714            0.04318              0.04172
# 759        0.041473     0.045714            0.04318              0.04172
# 760        0.041473     0.026219            0.04318              0.04172
# 761        0.041473     0.099993            0.04318              0.04172
# 762        0.041473     0.059358            0.04318              0.04172
#
#      PLANITUDOrigen  SOLDAOrigen  ...  BORDESDestino  DIAM__INTERNODestino  \
# 0          0.041473     0.041783  ...       0.041783              0.041783
# 1          0.041473     0.041783  ...       0.041783              0.041783
# 2          0.041473     0.041783  ...       0.041783              0.041783
# 3          0.041473     0.041783  ...       0.041783              0.041783
# 4          0.041473     0.041783  ...       0.041783              0.041783
# ..              ...          ...  ...            ...                   ...
# 758        0.041473     0.041783  ...       0.041783              0.041783
# 759        0.041473     0.041783  ...       0.041783              0.041783
# 760        0.041473     0.041783  ...       0.041783              0.041783
# 761        0.041473     0.041783  ...       0.041783              0.041783
# 762        0.041473     0.041783  ...       0.041783              0.041783
#
#      EXTREMOSDestino  NORMADestino  NORTOLANCHODestino  NORTOLESPESORDestino  \
# 0           0.041783      0.007804            0.043764              0.041783
# 1           0.041783      0.005961            0.043764              0.041783
# 2           0.041783      0.005961            0.043764              0.041783
# 3           0.041783      0.231884            0.043764              0.041783
# 4           0.041783      0.005961            0.043764              0.041783
# ..               ...           ...                 ...                   ...
# 758         0.041783      0.007804            0.043764              0.041783
# 759         0.041783      0.007804            0.043764              0.041783
# 760         0.041783      0.007804            0.043764              0.041783
# 761         0.041783      0.007804            0.043764              0.041783
# 762         0.041783      0.005961            0.022047              0.041783
#
#      PLANITUDDestino  SOLDADestino  SUPERFICIEDestino  USOGRALDestino
# 0           0.041783      0.041783           0.032812        0.017583
# 1           0.041783      0.041783           0.032812        0.034146
# 2           0.041783      0.041783           0.032812        0.014790
# 3           0.041783      0.041783           0.032812        0.017583
# 4           0.041783      0.041783           0.032812        0.000000
# ..               ...           ...                ...             ...
# 758         0.041783      0.041783           0.032812        0.017583
# 759         0.041783      0.041783           0.032812        0.017583
# 760         0.041783      0.041783           0.032812        0.017583
# 761         0.041783      0.041783           0.032812        0.017583
# 762         0.041783      0.041783           0.032812        0.017583
#
# [763 rows x 25 columns]

# %%
predic=dt.predict(datae)

# %%
Resultados=pd.DataFrame(data=predic,columns=['Reasignacion'])
Resultados.head
# Out:
# <bound method NDFrame.head of      Reasignacion
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ..            ...
# 758             0
# 759             0
# 760             0
# 761             0
# 762             0
#
# [763 rows x 1 columns]>

# %%
ResultadosF=encobj.inverse_transform(Resultados)
ResultadosF=pd.DataFrame(data=ResultadosF,columns=['Reasignacion'])
ResultadosF
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
#     Reasignacion
# 0             OK
# 1             OK
# 2             OK
# 3             OK
# 4             OK
# ..           ...
# 758           OK
# 759           OK
# 760           OK
# 761           OK
# 762           OK
#
# [763 rows x 1 columns]

# %%
concatenated = pd.concat([data, ResultadosF],axis=1) 
concatenated
# Out:
#         IdMaterial CPRODTOOrigen  CCLASEPRODTOOrigen  N_ANCHO  N_ESPESOR  \
# 0    2A852929GM200      MP509656  M-P-CALIENTE-BOB-_    457.9      0.642
# 1    2A854649GM200      MP501073  M-P-CALIENTE-BOB-_   1259.3      3.038
# 2    2A855104GM200      MP501073  M-P-CALIENTE-BOB-_    775.7      0.359
# 3    2A854623GM200      MP501073  M-P-CALIENTE-BOB-_    103.6      1.868
# 4    2A854650GM200      MP501073  M-P-CALIENTE-BOB-_   1188.6      0.465
# ..             ...           ...                 ...      ...        ...
# 758  2A882681GM200      MP500418  M-P-CALIENTE-BOB-_      NaN        NaN
# 759  2A882386GM200      MP500418  M-P-CALIENTE-BOB-_      NaN        NaN
# 760  2A882261GM200      MP509656  M-P-CALIENTE-BOB-_      NaN        NaN
# 761  2A870417GM200      MP509657  M-P-CALIENTE-BOB-_      NaN        NaN
# 762  2A884769GM200      MP501073  M-P-CALIENTE-BOB-_      NaN        NaN
#
#      ACEROOrigen  ACABSUPEROrigen BORDESOrigen  DIAM__INTERNOOrigen  \
# 0           7095                0   LAMINACIÓN                  711
# 1           7102                0   LAMINACIÓN                  711
# 2           7061                0   LAMINACIÓN                  711
# 3           7102                0   LAMINACIÓN                  711
# 4           7102                0   LAMINACIÓN                  711
# ..           ...              ...          ...                  ...
# 758         7095                0   LAMINACIÓN                  711
# 759         7095                0   LAMINACIÓN                  711
# 760         2084                0   LAMINACIÓN                  711
# 761         7094                0   LAMINACIÓN                  711
# 762         7092                0   LAMINACIÓN                  711
#
#                   EXTREMOSOrigen  ... DIAM__INTERNODestino  \
# 0    NO CORTADOS 98% EN ESPESOR.  ...                  508
# 1    NO CORTADOS 98% EN ESPESOR.  ...                  508
# 2    NO CORTADOS 98% EN ESPESOR.  ...                  508
# 3    NO CORTADOS 98% EN ESPESOR.  ...                  508
# 4    NO CORTADOS 98% EN ESPESOR.  ...                  508
# ..                           ...  ...                  ...
# 758  NO CORTADOS 98% EN ESPESOR.  ...                  508
# 759  NO CORTADOS 98% EN ESPESOR.  ...                  508
# 760  NO CORTADOS 98% EN ESPESOR.  ...                  508
# 761  NO CORTADOS 98% EN ESPESOR.  ...                  508
# 762  NO CORTADOS 98% EN ESPESOR.  ...                  508
#
#              EXTREMOSDestino                       NORMADestino  \
# 0    CORTADOS 98% EN ESPESOR     TER \ GA050 GAL (V 2011 REV 1)
# 1    CORTADOS 98% EN ESPESOR      TER \ 1006 GAL (V 2011 REV 1)
# 2    CORTADOS 98% EN ESPESOR      TER \ 1006 GAL (V 2011 REV 1)
# 3    CORTADOS 98% EN ESPESOR  TER \ GA040 GAL SS (V 2011 REV 1)
# 4    CORTADOS 98% EN ESPESOR      TER \ 1006 GAL (V 2011 REV 1)
# ..                       ...                                ...
# 758  CORTADOS 98% EN ESPESOR     TER \ GA050 GAL (V 2011 REV 1)
# 759  CORTADOS 98% EN ESPESOR     TER \ GA050 GAL (V 2011 REV 1)
# 760  CORTADOS 98% EN ESPESOR     TER \ GA050 GAL (V 2011 REV 1)
# 761  CORTADOS 98% EN ESPESOR     TER \ GA050 GAL (V 2011 REV 1)
# 762  CORTADOS 98% EN ESPESOR      TER \ 1006 GAL (V 2011 REV 1)
#
#     NORTOLANCHODestino NORTOLESPESORDestino   PLANITUDDestino SOLDADestino  \
# 0           ASTM A 568       1/2 ASTM A 568  TERNIUM ESTANDAR           NO
# 1           ASTM A 568       1/2 ASTM A 568  TERNIUM ESTANDAR           NO
# 2           ASTM A 568       1/2 ASTM A 568  TERNIUM ESTANDAR           NO
# 3           ASTM A 568       1/2 ASTM A 568  TERNIUM ESTANDAR           NO
# 4           ASTM A 568       1/2 ASTM A 568  TERNIUM ESTANDAR           NO
# ..                 ...                  ...               ...          ...
# 758         ASTM A 568       1/2 ASTM A 568  TERNIUM ESTANDAR           NO
# 759         ASTM A 568       1/2 ASTM A 568  TERNIUM ESTANDAR           NO
# 760         ASTM A 568       1/2 ASTM A 568  TERNIUM ESTANDAR           NO
# 761         ASTM A 568       1/2 ASTM A 568  TERNIUM ESTANDAR           NO
# 762    TER \ COMERCIAL       1/2 ASTM A 568  TERNIUM ESTANDAR           NO
#
#      SUPERFICIEDestino         USOGRALDestino Reasignacion
# 0        SEMI-EXPUESTA            GALVANIZADO           OK
# 1        SEMI-EXPUESTA  GALV. IND/AUT SIN MFG           OK
# 2        SEMI-EXPUESTA       GALV. INDUSTRIAL           OK
# 3        SEMI-EXPUESTA            GALVANIZADO           OK
# 4        SEMI-EXPUESTA     GALVANNEAL IND/AUT           OK
# ..                 ...                    ...          ...
# 758      SEMI-EXPUESTA            GALVANIZADO           OK
# 759      SEMI-EXPUESTA            GALVANIZADO           OK
# 760      SEMI-EXPUESTA            GALVANIZADO           OK
# 761      SEMI-EXPUESTA            GALVANIZADO           OK
# 762      SEMI-EXPUESTA            GALVANIZADO           OK
#
# [763 rows x 35 columns]

# %%
datae_train,datae_test,Resultados_train,Resultados_test=train_test_split(datae,Resultados)

# %%
dtc.fit(datae_train,Resultados_train)
# Out:
# DecisionTreeClassifier()

# %%
dtc.score(datae_train,Resultados_train)
# Out:
# 1.0

# %%
dtc.score(datae_test,Resultados_test)
# Out:
# 0.9947643979057592

# %%
# Separando los datos en sets de entrenamiento y evaluación
datae_train, datae_test, Resultados_train, Resultados_test = train_test_split(datae, 
                        Resultados, random_state=1)


tree = DecisionTreeClassifier(max_depth=2, random_state=0)
tree.fit(datae_train, Resultados_train)
print('Precisión modelo inicial train/test  {0:.3f}/{1:.3f}'
      .format(tree.score(datae_train, Resultados_train), tree.score(datae_test, Resultados_test)))
# Out:
# Precisión modelo inicial train/test  0.995/0.990

# %%
# Utilizando AdaBoost para aumentar la precisión
ada = AdaBoostClassifier(base_estimator=tree, n_estimators=500, 
                         learning_rate=1.5, random_state=1)
# Ajustando los datos
ada = ada.fit(datae_train, Resultados_train)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %%
# Imprimir la precisión.
y_train_pred = ada.predict(datae_train)
y_test_pred = ada.predict(datae_test)
ada_train = accuracy_score(Resultados_train, y_train_pred)
ada_test = accuracy_score(Resultados_test, y_test_pred)
print('Precisión modelo con AdaBoost train/test  {0:.3f}/{1:.3f}'
      .format(ada_train, ada_test))
# Out:
# Precisión modelo con AdaBoost train/test  1.000/1.000

# %%
# Armando el modelo con parametro max_depth
gbrt = GradientBoostingClassifier(random_state=0, n_estimators=500,
                                  max_depth=1, learning_rate=0.01)
# Ajustando el modelo
gbrt.fit(datae_train, Resultados_train)
print('Precisión Gradient Boosting train/test  {0:.3f}/{1:.3f}'
      .format(gbrt.score(datae_train, Resultados_train), gbrt.score(datae_test, Resultados_test)))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# Precisión Gradient Boosting train/test  0.998/1.000

# %%
concatenated.to_excel("ResultadoGalvanizado.xlsx")

# %%
concatenated.groupby('Reasignacion').size()
# Out:
# Reasignacion
# OK           750
# Rechazado     13
# dtype: int64
