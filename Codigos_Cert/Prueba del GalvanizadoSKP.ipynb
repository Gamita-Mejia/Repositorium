# %%
###importaciones
import pandas as pd
import numpy as np
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import category_encoders
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import LabelEncoder 
from sklearn.tree import DecisionTreeClassifier
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.tree import export_graphviz
import graphviz
import joblib

# %%
data=pd.read_csv('CertGalvanizadoSkp.csv')
dt=joblib.load('ModeloGalvanizadoSKP.pkl')
enc=joblib.load('TargetGalvanizado_SKP.pkl')
encobj=joblib.load('EncodificacionObjetivo.pkl')
data
# Out:
#     ACABSUPERFRECDestino ACABSUPERFRECOrigen  \
# 0                   MATE                MATE
# 1                   MATE                MATE
# 2                   MATE                MATE
# 3                   MATE                MATE
# 4                   MATE                MATE
# ..                   ...                 ...
# 610                 MATE                MATE
# 611                 MATE                MATE
# 612                 MATE                MATE
# 613                 MATE                MATE
# 614                 MATE                MATE
#
#                           ACEITADODestino  \
# 0                                      NO
# 1                                      NO
# 2                                      NO
# 3                                      NO
# 4                                      NO
# ..                                    ...
# 610  SI / ANTICORROSIVO / ACEITADO LIGERO
# 611  SI / ANTICORROSIVO / ACEITADO LIGERO
# 612                                    NO
# 613                                    NO
# 614                                    NO
#
#                            ACEITADOOrigen BORDESDestino BORDESOrigen  \
# 0                                      NO    LAMINACION          NaN
# 1                                      NO    LAMINACION          NaN
# 2                                      NO    LAMINACION          NaN
# 3                                      NO    LAMINACION          NaN
# 4                                      NO    LAMINACION   LAMINACION
# ..                                    ...           ...          ...
# 610  SI / ANTICORROSIVO / ACEITADO LIGERO    LAMINACION   LAMINACION
# 611  SI / ANTICORROSIVO / ACEITADO LIGERO    LAMINACION   LAMINACION
# 612                                    NO      CORTADOS     CORTADOS
# 613                                    NO      CORTADOS   LAMINACION
# 614                                    NO    LAMINACION   LAMINACION
#
#     CARAINSPECCIONDestino CARAINSPECCIONOrigen     CCLASEPRODTODestino  \
# 0                SUPERIOR             SUPERIOR  M-P-GALVANIZAD-BOB-SKP
# 1                SUPERIOR             SUPERIOR  M-P-GALVANIZAD-BOB-SKP
# 2                SUPERIOR             SUPERIOR  M-P-GALVANIZAD-BOB-SKP
# 3                SUPERIOR             SUPERIOR  M-P-GALVANIZAD-BOB-SKP
# 4                SUPERIOR             SUPERIOR  M-P-GALVANIZAD-BOB-SKP
# ..                    ...                  ...                     ...
# 610              SUPERIOR             SUPERIOR  M-P-GALVANIZAD-BOB-SKP
# 611              SUPERIOR             SUPERIOR  M-P-GALVANIZAD-BOB-SKP
# 612              SUPERIOR             SUPERIOR  M-P-GALVANIZAD-BOB-SKP
# 613              SUPERIOR             SUPERIOR  M-P-GALVANIZAD-BOB-SKP
# 614              SUPERIOR             SUPERIOR  M-P-GALVANIZAD-BOB-SKP
#
#          CCLASEPRODTOOrigen  ... SELLODestino SELLOOrigen  SUPERFICIEDestino  \
# 0    M-P-GALVANIZAD-FLE-SKP  ...           NO          NO           EXPUESTA
# 1    M-P-GALVANIZAD-FLE-SKP  ...           NO          NO           EXPUESTA
# 2    M-P-GALVANIZAD-FLE-SKP  ...           NO          NO           EXPUESTA
# 3    M-P-GALVANIZAD-FLE-SKP  ...           NO          NO           EXPUESTA
# 4    M-P-GALVANIZAD-BOB-SKP  ...           NO          NO           EXPUESTA
# ..                      ...  ...          ...         ...                ...
# 610  M-P-GALVANIZAD-BOB-SKP  ...           NO          NO           EXPUESTA
# 611  M-P-GALVANIZAD-BOB-SKP  ...           NO          NO           EXPUESTA
# 612  M-P-GALVANIZAD-BOB-SKP  ...           NO          NO            INTERNA
# 613  M-P-GALVANIZAD-BOB-SKP  ...           NO          NO            INTERNA
# 614    M-P-GALVANIZAD-BOB-_  ...           NO          NO      SEMI-EXPUESTA
#
#     SUPERFICIEOrigen TAMFLORDestino TAMFLOROrigen TRATSUPERFDestino  \
# 0           EXPUESTA         MINIMA        MINIMA          PASIVADO
# 1      SEMI-EXPUESTA         MINIMA        MINIMA          PASIVADO
# 2      SEMI-EXPUESTA         MINIMA        MINIMA          PASIVADO
# 3      SEMI-EXPUESTA         MINIMA        MINIMA          PASIVADO
# 4      SEMI-EXPUESTA         MINIMA        MINIMA          PASIVADO
# ..               ...            ...           ...               ...
# 610         EXPUESTA         MINIMA        MINIMA   SIN TRATAMIENTO
# 611         EXPUESTA         MINIMA        MINIMA   SIN TRATAMIENTO
# 612          INTERNA         MINIMA        MINIMA          PASIVADO
# 613          INTERNA         MINIMA        MINIMA          PASIVADO
# 614    SEMI-EXPUESTA        REGULAR       REGULAR          PASIVADO
#
#       TRATSUPERFOrigen            USOGRALDestino             USOGRALOrigen
# 0             PASIVADO              LINEA BLANCA              LINEA BLANCA
# 1    PASIVADO ACRILICO              LINEA BLANCA                INDUSTRIAL
# 2    PASIVADO ACRILICO              LINEA BLANCA                INDUSTRIAL
# 3    PASIVADO ACRILICO              LINEA BLANCA                INDUSTRIAL
# 4             PASIVADO              LINEA BLANCA                INDUSTRIAL
# ..                 ...                       ...                       ...
# 610    SIN TRATAMIENTO              LINEA BLANCA              LINEA BLANCA
# 611    SIN TRATAMIENTO              LINEA BLANCA              LINEA BLANCA
# 612           PASIVADO  COMERCIAL Y CONSTRUCCION  COMERCIAL Y CONSTRUCCION
# 613           PASIVADO  COMERCIAL Y CONSTRUCCION  COMERCIAL Y CONSTRUCCION
# 614           PASIVADO              LINEA BLANCA              LINEA BLANCA
#
# [615 rows x 40 columns]

# %%
data=pd.DataFrame(data)
data
# Out:
#     ACABSUPERFRECDestino ACABSUPERFRECOrigen  \
# 0                   MATE                MATE
# 1                   MATE                MATE
# 2                   MATE                MATE
# 3                   MATE                MATE
# 4                   MATE                MATE
# ..                   ...                 ...
# 610                 MATE                MATE
# 611                 MATE                MATE
# 612                 MATE                MATE
# 613                 MATE                MATE
# 614                 MATE                MATE
#
#                           ACEITADODestino  \
# 0                                      NO
# 1                                      NO
# 2                                      NO
# 3                                      NO
# 4                                      NO
# ..                                    ...
# 610  SI / ANTICORROSIVO / ACEITADO LIGERO
# 611  SI / ANTICORROSIVO / ACEITADO LIGERO
# 612                                    NO
# 613                                    NO
# 614                                    NO
#
#                            ACEITADOOrigen BORDESDestino BORDESOrigen  \
# 0                                      NO    LAMINACION          NaN
# 1                                      NO    LAMINACION          NaN
# 2                                      NO    LAMINACION          NaN
# 3                                      NO    LAMINACION          NaN
# 4                                      NO    LAMINACION   LAMINACION
# ..                                    ...           ...          ...
# 610  SI / ANTICORROSIVO / ACEITADO LIGERO    LAMINACION   LAMINACION
# 611  SI / ANTICORROSIVO / ACEITADO LIGERO    LAMINACION   LAMINACION
# 612                                    NO      CORTADOS     CORTADOS
# 613                                    NO      CORTADOS   LAMINACION
# 614                                    NO    LAMINACION   LAMINACION
#
#     CARAINSPECCIONDestino CARAINSPECCIONOrigen     CCLASEPRODTODestino  \
# 0                SUPERIOR             SUPERIOR  M-P-GALVANIZAD-BOB-SKP
# 1                SUPERIOR             SUPERIOR  M-P-GALVANIZAD-BOB-SKP
# 2                SUPERIOR             SUPERIOR  M-P-GALVANIZAD-BOB-SKP
# 3                SUPERIOR             SUPERIOR  M-P-GALVANIZAD-BOB-SKP
# 4                SUPERIOR             SUPERIOR  M-P-GALVANIZAD-BOB-SKP
# ..                    ...                  ...                     ...
# 610              SUPERIOR             SUPERIOR  M-P-GALVANIZAD-BOB-SKP
# 611              SUPERIOR             SUPERIOR  M-P-GALVANIZAD-BOB-SKP
# 612              SUPERIOR             SUPERIOR  M-P-GALVANIZAD-BOB-SKP
# 613              SUPERIOR             SUPERIOR  M-P-GALVANIZAD-BOB-SKP
# 614              SUPERIOR             SUPERIOR  M-P-GALVANIZAD-BOB-SKP
#
#          CCLASEPRODTOOrigen  ... SELLODestino SELLOOrigen  SUPERFICIEDestino  \
# 0    M-P-GALVANIZAD-FLE-SKP  ...           NO          NO           EXPUESTA
# 1    M-P-GALVANIZAD-FLE-SKP  ...           NO          NO           EXPUESTA
# 2    M-P-GALVANIZAD-FLE-SKP  ...           NO          NO           EXPUESTA
# 3    M-P-GALVANIZAD-FLE-SKP  ...           NO          NO           EXPUESTA
# 4    M-P-GALVANIZAD-BOB-SKP  ...           NO          NO           EXPUESTA
# ..                      ...  ...          ...         ...                ...
# 610  M-P-GALVANIZAD-BOB-SKP  ...           NO          NO           EXPUESTA
# 611  M-P-GALVANIZAD-BOB-SKP  ...           NO          NO           EXPUESTA
# 612  M-P-GALVANIZAD-BOB-SKP  ...           NO          NO            INTERNA
# 613  M-P-GALVANIZAD-BOB-SKP  ...           NO          NO            INTERNA
# 614    M-P-GALVANIZAD-BOB-_  ...           NO          NO      SEMI-EXPUESTA
#
#     SUPERFICIEOrigen TAMFLORDestino TAMFLOROrigen TRATSUPERFDestino  \
# 0           EXPUESTA         MINIMA        MINIMA          PASIVADO
# 1      SEMI-EXPUESTA         MINIMA        MINIMA          PASIVADO
# 2      SEMI-EXPUESTA         MINIMA        MINIMA          PASIVADO
# 3      SEMI-EXPUESTA         MINIMA        MINIMA          PASIVADO
# 4      SEMI-EXPUESTA         MINIMA        MINIMA          PASIVADO
# ..               ...            ...           ...               ...
# 610         EXPUESTA         MINIMA        MINIMA   SIN TRATAMIENTO
# 611         EXPUESTA         MINIMA        MINIMA   SIN TRATAMIENTO
# 612          INTERNA         MINIMA        MINIMA          PASIVADO
# 613          INTERNA         MINIMA        MINIMA          PASIVADO
# 614    SEMI-EXPUESTA        REGULAR       REGULAR          PASIVADO
#
#       TRATSUPERFOrigen            USOGRALDestino             USOGRALOrigen
# 0             PASIVADO              LINEA BLANCA              LINEA BLANCA
# 1    PASIVADO ACRILICO              LINEA BLANCA                INDUSTRIAL
# 2    PASIVADO ACRILICO              LINEA BLANCA                INDUSTRIAL
# 3    PASIVADO ACRILICO              LINEA BLANCA                INDUSTRIAL
# 4             PASIVADO              LINEA BLANCA                INDUSTRIAL
# ..                 ...                       ...                       ...
# 610    SIN TRATAMIENTO              LINEA BLANCA              LINEA BLANCA
# 611    SIN TRATAMIENTO              LINEA BLANCA              LINEA BLANCA
# 612           PASIVADO  COMERCIAL Y CONSTRUCCION  COMERCIAL Y CONSTRUCCION
# 613           PASIVADO  COMERCIAL Y CONSTRUCCION  COMERCIAL Y CONSTRUCCION
# 614           PASIVADO              LINEA BLANCA              LINEA BLANCA
#
# [615 rows x 40 columns]

# %%
databuena=data.loc[:, ['CCLASEPRODTOOrigen', 'ACABSUPERFRECOrigen', 'ACEITADOOrigen',
       'BORDESOrigen', 'CARAINSPECCIONOrigen', 'DIAM__INTERNOOrigen',
       'EXTREMOSOrigen', 'NORMAOrigen', 'NORRECUBRIMIENOrigen',
       'NORTOLANCHOOrigen', 'NORTOLESPESOROrigen', 'PLANITUDOrigen',
       'RECUBRIMIENTOOrigen', 'SELLOOrigen', 'SUPERFICIEOrigen',
       'TAMFLOROrigen', 'TRATSUPERFOrigen', 'USOGRALOrigen',
       'CCLASEPRODTODestino', 'ACABSUPERFRECDestino', 'ACEITADODestino',
       'BORDESDestino', 'CARAINSPECCIONDestino', 'DIAM__INTERNODestino',
       'EXTREMOSDestino', 'NORMADestino', 'NORRECUBRIMIENDestino',
       'NORTOLANCHODestino', 'NORTOLESPESORDestino', 'PLANITUDDestino',
       'RECUBRIMIENTODestino', 'SELLODestino', 'SUPERFICIEDestino',
       'TAMFLORDestino', 'TRATSUPERFDestino', 'USOGRALDestino']] 
databuena
# Out:
#          CCLASEPRODTOOrigen ACABSUPERFRECOrigen  \
# 0    M-P-GALVANIZAD-FLE-SKP                MATE
# 1    M-P-GALVANIZAD-FLE-SKP                MATE
# 2    M-P-GALVANIZAD-FLE-SKP                MATE
# 3    M-P-GALVANIZAD-FLE-SKP                MATE
# 4    M-P-GALVANIZAD-BOB-SKP                MATE
# ..                      ...                 ...
# 610  M-P-GALVANIZAD-BOB-SKP                MATE
# 611  M-P-GALVANIZAD-BOB-SKP                MATE
# 612  M-P-GALVANIZAD-BOB-SKP                MATE
# 613  M-P-GALVANIZAD-BOB-SKP                MATE
# 614    M-P-GALVANIZAD-BOB-_                MATE
#
#                            ACEITADOOrigen BORDESOrigen CARAINSPECCIONOrigen  \
# 0                                      NO          NaN             SUPERIOR
# 1                                      NO          NaN             SUPERIOR
# 2                                      NO          NaN             SUPERIOR
# 3                                      NO          NaN             SUPERIOR
# 4                                      NO   LAMINACION             SUPERIOR
# ..                                    ...          ...                  ...
# 610  SI / ANTICORROSIVO / ACEITADO LIGERO   LAMINACION             SUPERIOR
# 611  SI / ANTICORROSIVO / ACEITADO LIGERO   LAMINACION             SUPERIOR
# 612                                    NO     CORTADOS             SUPERIOR
# 613                                    NO   LAMINACION             SUPERIOR
# 614                                    NO   LAMINACION             SUPERIOR
#
#     DIAM__INTERNOOrigen           EXTREMOSOrigen  \
# 0                   610  CORTADOS 98% EN ESPESOR
# 1                   508  CORTADOS 98% EN ESPESOR
# 2                   508  CORTADOS 98% EN ESPESOR
# 3                   508  CORTADOS 98% EN ESPESOR
# 4                   508  CORTADOS 98% EN ESPESOR
# ..                  ...                      ...
# 610                 508  CORTADOS 98% EN ESPESOR
# 611                 508  CORTADOS 98% EN ESPESOR
# 612                 508  CORTADOS 98% EN ESPESOR
# 613                 508  CORTADOS 98% EN ESPESOR
# 614                 508  CORTADOS 98% EN ESPESOR
#
#                                NORMAOrigen NORRECUBRIMIENOrigen  \
# 0    ASTM A 653 \ CS TIPO B (V 2008 REV 0)           ASTM A 653
# 1    ASTM A 653 \ FS TIPO B (V 2008 REV 0)           ASTM A 653
# 2    ASTM A 653 \ FS TIPO B (V 2008 REV 0)           ASTM A 653
# 3    ASTM A 653 \ FS TIPO B (V 2008 REV 0)           ASTM A 653
# 4    ASTM A 653 \ FS TIPO B (V 2008 REV 0)           ASTM A 653
# ..                                     ...                  ...
# 610  ASTM A 653 \ FS TIPO B (V 2008 REV 0)           ASTM A 653
# 611  ASTM A 653 \ FS TIPO B (V 2008 REV 0)           ASTM A 653
# 612  ASTM A 653 \ CS TIPO B (V 2008 REV 0)           ASTM A 653
# 613      ASTM A 653 \ SS 33 (V 2008 REV 0)           ASTM A 653
# 614     TER \ GLV EDDS \ LB (V 2012 REV 1)                  TER
#
#           NORTOLANCHOOrigen  ... NORRECUBRIMIENDestino NORTOLANCHODestino  \
# 0    TERNIUM -0.13/+0.13 MM  ...            ASTM A 653         ASTM A 924
# 1    TERNIUM -0.13/+0.13 MM  ...            ASTM A 653         ASTM A 924
# 2    TERNIUM -0.13/+0.13 MM  ...            ASTM A 653         ASTM A 924
# 3    TERNIUM -0.13/+0.13 MM  ...            ASTM A 653         ASTM A 924
# 4                ASTM A 924  ...            ASTM A 653         ASTM A 924
# ..                      ...  ...                   ...                ...
# 610              ASTM A 924  ...            ASTM A 653         ASTM A 924
# 611              ASTM A 924  ...            ASTM A 653         ASTM A 924
# 612              ASTM A 924  ...            ASTM A 653         ASTM A 924
# 613              ASTM A 924  ...            ASTM A 653         ASTM A 924
# 614              ASTM A 924  ...                   TER         ASTM A 924
#
#     NORTOLESPESORDestino        PLANITUDDestino RECUBRIMIENTODestino  \
# 0         1/2 ASTM A 924  NIVEL 1 / 15 UI / 3MM                  G40
# 1         1/2 ASTM A 924  NIVEL 1 / 15 UI / 3MM                  G40
# 2         1/2 ASTM A 924  NIVEL 1 / 15 UI / 3MM                  G40
# 3         1/2 ASTM A 924  NIVEL 1 / 15 UI / 3MM                  G40
# 4         1/2 ASTM A 924  NIVEL 1 / 15 UI / 3MM                  G40
# ..                   ...                    ...                  ...
# 610       1/2 ASTM A 924  NIVEL 3 / 29 UI / 4MM                  G60
# 611       1/2 ASTM A 924  NIVEL 3 / 29 UI / 4MM                  G60
# 612           ASTM A 924  NIVEL 3 / 29 UI / 4MM                  G90
# 613           ASTM A 924  NIVEL 3 / 29 UI / 4MM                  G90
# 614       1/2 ASTM A 924  NIVEL 1 / 15 UI / 3MM                  G90
#
#     SELLODestino SUPERFICIEDestino TAMFLORDestino TRATSUPERFDestino  \
# 0             NO          EXPUESTA         MINIMA          PASIVADO
# 1             NO          EXPUESTA         MINIMA          PASIVADO
# 2             NO          EXPUESTA         MINIMA          PASIVADO
# 3             NO          EXPUESTA         MINIMA          PASIVADO
# 4             NO          EXPUESTA         MINIMA          PASIVADO
# ..           ...               ...            ...               ...
# 610           NO          EXPUESTA         MINIMA   SIN TRATAMIENTO
# 611           NO          EXPUESTA         MINIMA   SIN TRATAMIENTO
# 612           NO           INTERNA         MINIMA          PASIVADO
# 613           NO           INTERNA         MINIMA          PASIVADO
# 614           NO     SEMI-EXPUESTA        REGULAR          PASIVADO
#
#                USOGRALDestino
# 0                LINEA BLANCA
# 1                LINEA BLANCA
# 2                LINEA BLANCA
# 3                LINEA BLANCA
# 4                LINEA BLANCA
# ..                        ...
# 610              LINEA BLANCA
# 611              LINEA BLANCA
# 612  COMERCIAL Y CONSTRUCCION
# 613  COMERCIAL Y CONSTRUCCION
# 614              LINEA BLANCA
#
# [615 rows x 36 columns]

# %%
databuena.columns
# Out:
# Index(['CCLASEPRODTOOrigen', 'ACABSUPERFRECOrigen', 'ACEITADOOrigen',
#        'BORDESOrigen', 'CARAINSPECCIONOrigen', 'DIAM__INTERNOOrigen',
#        'EXTREMOSOrigen', 'NORMAOrigen', 'NORRECUBRIMIENOrigen',
#        'NORTOLANCHOOrigen', 'NORTOLESPESOROrigen', 'PLANITUDOrigen',
#        'RECUBRIMIENTOOrigen', 'SELLOOrigen', 'SUPERFICIEOrigen',
#        'TAMFLOROrigen', 'TRATSUPERFOrigen', 'USOGRALOrigen',
#        'CCLASEPRODTODestino', 'ACABSUPERFRECDestino', 'ACEITADODestino',
#        'BORDESDestino', 'CARAINSPECCIONDestino', 'DIAM__INTERNODestino',
#        'EXTREMOSDestino', 'NORMADestino', 'NORRECUBRIMIENDestino',
#        'NORTOLANCHODestino', 'NORTOLESPESORDestino', 'PLANITUDDestino',
#        'RECUBRIMIENTODestino', 'SELLODestino', 'SUPERFICIEDestino',
#        'TAMFLORDestino', 'TRATSUPERFDestino', 'USOGRALDestino'],
#       dtype='object')

# %%
datae=enc.transform(databuena)
datae
# Out:
#      CCLASEPRODTOOrigen  ACABSUPERFRECOrigen  ACEITADOOrigen  BORDESOrigen  \
# 0              0.084599              0.08558        0.049689      0.084599
# 1              0.084599              0.08558        0.049689      0.084599
# 2              0.084599              0.08558        0.049689      0.084599
# 3              0.084599              0.08558        0.049689      0.084599
# 4              0.084599              0.08558        0.049689      0.084599
# ..                  ...                  ...             ...           ...
# 610            0.084599              0.08558        0.097279      0.084599
# 611            0.084599              0.08558        0.097279      0.084599
# 612            0.084599              0.08558        0.049689      0.085161
# 613            0.084599              0.08558        0.049689      0.084599
# 614            0.084599              0.08558        0.049689      0.084599
#
#      CARAINSPECCIONOrigen  DIAM__INTERNOOrigen  EXTREMOSOrigen  NORMAOrigen  \
# 0                0.084599             0.084599        0.080238     0.098340
# 1                0.084599             0.084599        0.080238     0.037773
# 2                0.084599             0.084599        0.080238     0.037773
# 3                0.084599             0.084599        0.080238     0.037773
# 4                0.084599             0.084599        0.080238     0.037773
# ..                    ...                  ...             ...          ...
# 610              0.084599             0.084599        0.080238     0.037773
# 611              0.084599             0.084599        0.080238     0.037773
# 612              0.084599             0.084599        0.080238     0.098340
# 613              0.084599             0.084599        0.080238     0.000077
# 614              0.084599             0.084599        0.080238     0.118943
#
#      NORRECUBRIMIENOrigen  NORTOLANCHOOrigen  ...  NORRECUBRIMIENDestino  \
# 0                0.072243           0.084599  ...               0.073881
# 1                0.072243           0.084599  ...               0.073881
# 2                0.072243           0.084599  ...               0.073881
# 3                0.072243           0.084599  ...               0.073881
# 4                0.072243           0.079656  ...               0.073881
# ..                    ...                ...  ...                    ...
# 610              0.072243           0.079656  ...               0.073881
# 611              0.072243           0.079656  ...               0.073881
# 612              0.072243           0.079656  ...               0.073881
# 613              0.072243           0.079656  ...               0.073881
# 614              0.106814           0.079656  ...               0.110569
#
#      NORTOLANCHODestino  NORTOLESPESORDestino  PLANITUDDestino  \
# 0              0.084446              0.085366         0.107365
# 1              0.084446              0.085366         0.107365
# 2              0.084446              0.085366         0.107365
# 3              0.084446              0.085366         0.107365
# 4              0.084446              0.085366         0.107365
# ..                  ...                   ...              ...
# 610            0.084446              0.085366         0.063653
# 611            0.084446              0.085366         0.063653
# 612            0.084446              0.240000         0.063653
# 613            0.084446              0.240000         0.063653
# 614            0.084446              0.085366         0.107365
#
#      RECUBRIMIENTODestino  SELLODestino  SUPERFICIEDestino  TAMFLORDestino  \
# 0                0.090737      0.084599           0.086580        0.083556
# 1                0.090737      0.084599           0.086580        0.083556
# 2                0.090737      0.084599           0.086580        0.083556
# 3                0.090737      0.084599           0.086580        0.083556
# 4                0.090737      0.084599           0.086580        0.083556
# ..                    ...           ...                ...             ...
# 610              0.163743      0.084599           0.086580        0.083556
# 611              0.163743      0.084599           0.086580        0.083556
# 612              0.051515      0.084599           0.091837        0.083556
# 613              0.051515      0.084599           0.091837        0.083556
# 614              0.051515      0.084599           0.078136        0.304348
#
#      TRATSUPERFDestino  USOGRALDestino
# 0             0.066547        0.081121
# 1             0.066547        0.081121
# 2             0.066547        0.081121
# 3             0.066547        0.081121
# 4             0.066547        0.081121
# ..                 ...             ...
# 610           0.108017        0.081121
# 611           0.108017        0.081121
# 612           0.066547        0.051724
# 613           0.066547        0.051724
# 614           0.066547        0.081121
#
# [615 rows x 36 columns]

# %%
predicprob=dt.predict_proba(datae)
predic=dt.predict(datae)

# %%
ResultadosProb=pd.DataFrame(data=predicprob,columns=['Prob. Ok','Prob. Rechazado'])
ResultadosNormal=pd.DataFrame(data=predic,columns=['Reasignación'])
ResultadosNormal=pd.DataFrame(data=encobj.inverse_transform(ResultadosNormal),columns=['Reasignacion'])
ResultadosNormal
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
#     Reasignacion
# 0             OK
# 1             OK
# 2             OK
# 3             OK
# 4             OK
# ..           ...
# 610           OK
# 611           OK
# 612           OK
# 613           OK
# 614           OK
#
# [615 rows x 1 columns]

# %%
concatenated = pd.concat([data, ResultadosNormal,ResultadosProb],axis=1) 
concatenated
# Out:
#     ACABSUPERFRECDestino ACABSUPERFRECOrigen  \
# 0                   MATE                MATE
# 1                   MATE                MATE
# 2                   MATE                MATE
# 3                   MATE                MATE
# 4                   MATE                MATE
# ..                   ...                 ...
# 610                 MATE                MATE
# 611                 MATE                MATE
# 612                 MATE                MATE
# 613                 MATE                MATE
# 614                 MATE                MATE
#
#                           ACEITADODestino  \
# 0                                      NO
# 1                                      NO
# 2                                      NO
# 3                                      NO
# 4                                      NO
# ..                                    ...
# 610  SI / ANTICORROSIVO / ACEITADO LIGERO
# 611  SI / ANTICORROSIVO / ACEITADO LIGERO
# 612                                    NO
# 613                                    NO
# 614                                    NO
#
#                            ACEITADOOrigen BORDESDestino BORDESOrigen  \
# 0                                      NO    LAMINACION          NaN
# 1                                      NO    LAMINACION          NaN
# 2                                      NO    LAMINACION          NaN
# 3                                      NO    LAMINACION          NaN
# 4                                      NO    LAMINACION   LAMINACION
# ..                                    ...           ...          ...
# 610  SI / ANTICORROSIVO / ACEITADO LIGERO    LAMINACION   LAMINACION
# 611  SI / ANTICORROSIVO / ACEITADO LIGERO    LAMINACION   LAMINACION
# 612                                    NO      CORTADOS     CORTADOS
# 613                                    NO      CORTADOS   LAMINACION
# 614                                    NO    LAMINACION   LAMINACION
#
#     CARAINSPECCIONDestino CARAINSPECCIONOrigen     CCLASEPRODTODestino  \
# 0                SUPERIOR             SUPERIOR  M-P-GALVANIZAD-BOB-SKP
# 1                SUPERIOR             SUPERIOR  M-P-GALVANIZAD-BOB-SKP
# 2                SUPERIOR             SUPERIOR  M-P-GALVANIZAD-BOB-SKP
# 3                SUPERIOR             SUPERIOR  M-P-GALVANIZAD-BOB-SKP
# 4                SUPERIOR             SUPERIOR  M-P-GALVANIZAD-BOB-SKP
# ..                    ...                  ...                     ...
# 610              SUPERIOR             SUPERIOR  M-P-GALVANIZAD-BOB-SKP
# 611              SUPERIOR             SUPERIOR  M-P-GALVANIZAD-BOB-SKP
# 612              SUPERIOR             SUPERIOR  M-P-GALVANIZAD-BOB-SKP
# 613              SUPERIOR             SUPERIOR  M-P-GALVANIZAD-BOB-SKP
# 614              SUPERIOR             SUPERIOR  M-P-GALVANIZAD-BOB-SKP
#
#          CCLASEPRODTOOrigen  ... SUPERFICIEOrigen TAMFLORDestino  \
# 0    M-P-GALVANIZAD-FLE-SKP  ...         EXPUESTA         MINIMA
# 1    M-P-GALVANIZAD-FLE-SKP  ...    SEMI-EXPUESTA         MINIMA
# 2    M-P-GALVANIZAD-FLE-SKP  ...    SEMI-EXPUESTA         MINIMA
# 3    M-P-GALVANIZAD-FLE-SKP  ...    SEMI-EXPUESTA         MINIMA
# 4    M-P-GALVANIZAD-BOB-SKP  ...    SEMI-EXPUESTA         MINIMA
# ..                      ...  ...              ...            ...
# 610  M-P-GALVANIZAD-BOB-SKP  ...         EXPUESTA         MINIMA
# 611  M-P-GALVANIZAD-BOB-SKP  ...         EXPUESTA         MINIMA
# 612  M-P-GALVANIZAD-BOB-SKP  ...          INTERNA         MINIMA
# 613  M-P-GALVANIZAD-BOB-SKP  ...          INTERNA         MINIMA
# 614    M-P-GALVANIZAD-BOB-_  ...    SEMI-EXPUESTA        REGULAR
#
#      TAMFLOROrigen TRATSUPERFDestino   TRATSUPERFOrigen  \
# 0           MINIMA          PASIVADO           PASIVADO
# 1           MINIMA          PASIVADO  PASIVADO ACRILICO
# 2           MINIMA          PASIVADO  PASIVADO ACRILICO
# 3           MINIMA          PASIVADO  PASIVADO ACRILICO
# 4           MINIMA          PASIVADO           PASIVADO
# ..             ...               ...                ...
# 610         MINIMA   SIN TRATAMIENTO    SIN TRATAMIENTO
# 611         MINIMA   SIN TRATAMIENTO    SIN TRATAMIENTO
# 612         MINIMA          PASIVADO           PASIVADO
# 613         MINIMA          PASIVADO           PASIVADO
# 614        REGULAR          PASIVADO           PASIVADO
#
#                USOGRALDestino             USOGRALOrigen Reasignacion  \
# 0                LINEA BLANCA              LINEA BLANCA           OK
# 1                LINEA BLANCA                INDUSTRIAL           OK
# 2                LINEA BLANCA                INDUSTRIAL           OK
# 3                LINEA BLANCA                INDUSTRIAL           OK
# 4                LINEA BLANCA                INDUSTRIAL           OK
# ..                        ...                       ...          ...
# 610              LINEA BLANCA              LINEA BLANCA           OK
# 611              LINEA BLANCA              LINEA BLANCA           OK
# 612  COMERCIAL Y CONSTRUCCION  COMERCIAL Y CONSTRUCCION           OK
# 613  COMERCIAL Y CONSTRUCCION  COMERCIAL Y CONSTRUCCION           OK
# 614              LINEA BLANCA              LINEA BLANCA           OK
#
#      Prob. Ok Prob. Rechazado
# 0    1.000000        0.000000
# 1    1.000000        0.000000
# 2    1.000000        0.000000
# 3    1.000000        0.000000
# 4    1.000000        0.000000
# ..        ...             ...
# 610  1.000000        0.000000
# 611  1.000000        0.000000
# 612  1.000000        0.000000
# 613  0.857143        0.142857
# 614  1.000000        0.000000
#
# [615 rows x 43 columns]

# %%
concatenated.to_excel("ResultadoGalvanizadoSKP2021Final.xlsx")

# %%
concatenated.groupby('Reasignacion').size()
# Out:
# Reasignacion
# OK           600
# Rechazado     15
# dtype: int64
