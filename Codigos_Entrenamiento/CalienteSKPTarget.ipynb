# %%
###importaciones
import pandas as pd
import numpy as np
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import category_encoders
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import LabelEncoder 
from sklearn.tree import DecisionTreeClassifier
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.tree import export_graphviz
import graphviz
import joblib

# %%
##lectura del csv y objetos a usar
data=pd.read_csv("CalienteSKP.csv")
le=LabelEncoder()
dt=DecisionTreeClassifier()
data
# Out:
#          Estatus           FECHA_ALTA     IdMaterial  NECESIDAD_ORIGEN  \
# 0      Rechazado  30-06-2016 15:38:15  1A130149GS100        3001129712
# 1      Rechazado  30-06-2016 15:43:47  1A132688GS100        3001129712
# 2      Rechazado  30-06-2016 15:44:04  1A132599GS101        3001138692
# 3      Rechazado  30-06-2016 15:44:13  1A132602GS100        3001138692
# 4      Rechazado  30-06-2016 16:30:38  3A431395QKS00        3001129712
# ...          ...                  ...            ...               ...
# 11365         OK  28-11-2017 15:43:17  3A712803CS400        2000697823
# 11366         OK  09-11-2017 16:27:39  3A707494CS400        2000697823
# 11367         OK  28-11-2017 15:56:13  3A706479CS400        2000697901
# 11368         OK  28-11-2017 15:32:16  3A655679CC401        2000675286
# 11369         OK  16-10-2017 18:16:59  2A509656GM200        2000696092
#
#       ACEROOrigen  NECESIDAD_DESTINO ACERODestino PRO_ORIGEN PRO_DESTINO  \
# 0            6086         3001152310         6086   MP502044    MP527766
# 1            6086         3001152310         6086   MP502044    MP527766
# 2            6086         3001152310         6086   MP502044    MP527766
# 3            6086         3001152310         6086   MP502044    MP527766
# 4            6086         3001152310         6086   MP502044    MP527766
# ...           ...                ...          ...        ...         ...
# 11365      C091AL         2000675286       C091AL   MP533519    MP533519
# 11366      C091AL         2000675286       C091AL   MP533519    MP533519
# 11367      C091AL         2000697823       C091AL   MP533519    MP533519
# 11368      C091AL         2000697823       C091AL   MP533519    MP533519
# 11369        2042         2000696092         2042   MP533774    MP533774
#
#        SAME_PRO  ...          EXTREMOSDestino  \
# 0         False  ...  CORTADOS 98% EN ESPESOR
# 1         False  ...  CORTADOS 98% EN ESPESOR
# 2         False  ...  CORTADOS 98% EN ESPESOR
# 3         False  ...  CORTADOS 98% EN ESPESOR
# 4         False  ...  CORTADOS 98% EN ESPESOR
# ...         ...  ...                      ...
# 11365      True  ...  CORTADOS 98% EN ESPESOR
# 11366      True  ...  CORTADOS 98% EN ESPESOR
# 11367      True  ...  CORTADOS 98% EN ESPESOR
# 11368      True  ...  CORTADOS 98% EN ESPESOR
# 11369      True  ...  CORTADOS 98% EN ESPESOR
#
#                                 NORMADestino  NORTOLANCHODestino  \
# 0                TER \ PER-GA (V 2006 REV 1)  ASTM A 568 / A 635
# 1                TER \ PER-GA (V 2006 REV 1)  ASTM A 568 / A 635
# 2                TER \ PER-GA (V 2006 REV 1)  ASTM A 568 / A 635
# 3                TER \ PER-GA (V 2006 REV 1)  ASTM A 568 / A 635
# 4                TER \ PER-GA (V 2006 REV 1)  ASTM A 568 / A 635
# ...                                      ...                 ...
# 11365  MS 50002 \ LAH240Y320T (V 2014 REV 0)  ASTM A 568 / A 635
# 11366  MS 50002 \ LAH240Y320T (V 2014 REV 0)  ASTM A 568 / A 635
# 11367  MS 50002 \ LAH240Y320T (V 2014 REV 0)  ASTM A 568 / A 635
# 11368  MS 50002 \ LAH240Y320T (V 2014 REV 0)  ASTM A 568 / A 635
# 11369  TER \ A635MOD \ SAW-ZF (V 2015 REV 0)  ASTM A 568 / A 635
#
#          NORTOLESPESORDestino     PLANITUDDestino SOLDADestino  \
# 0      1/2 ASTM A 568 / A 635  TERNIUM CONTROLADA           NO
# 1      1/2 ASTM A 568 / A 635  TERNIUM CONTROLADA           NO
# 2      1/2 ASTM A 568 / A 635  TERNIUM CONTROLADA           NO
# 3      1/2 ASTM A 568 / A 635  TERNIUM CONTROLADA           NO
# 4      1/2 ASTM A 568 / A 635  TERNIUM CONTROLADA           NO
# ...                       ...                 ...          ...
# 11365             PS-5570_LAC  TERNIUM CONTROLADA           NO
# 11366             PS-5570_LAC  TERNIUM CONTROLADA           NO
# 11367             PS-5570_LAC  TERNIUM CONTROLADA           NO
# 11368             PS-5570_LAC  TERNIUM CONTROLADA           NO
# 11369  1/2 ASTM A 568 / A 635  TERNIUM CONTROLADA           NO
#
#       SUPERFICIEDestino              USOGRALDestino Reasignacion Pedido
# 0               INTERNA            TUBOS Y PERFILES           OK      1
# 1               INTERNA            TUBOS Y PERFILES           OK      1
# 2               INTERNA            TUBOS Y PERFILES           OK      1
# 3               INTERNA            TUBOS Y PERFILES           OK      1
# 4               INTERNA            TUBOS Y PERFILES           OK      1
# ...                 ...                         ...          ...    ...
# 11365           INTERNA      AUTOMOTRIZ ESTRUCTURAL           OK      1
# 11366           INTERNA      AUTOMOTRIZ ESTRUCTURAL           OK      1
# 11367           INTERNA      AUTOMOTRIZ ESTRUCTURAL           OK      1
# 11368           INTERNA      AUTOMOTRIZ ESTRUCTURAL           OK      1
# 11369     SEMI-EXPUESTA  AUTOMOTRIZ GRADO COMERCIAL           OK      1
#
# [11370 rows x 34 columns]

# %%
###limpieza de datos
de=['Estatus', 'FECHA_ALTA', 'IdMaterial', 'NECESIDAD_ORIGEN','NECESIDAD_DESTINO', 'PRO_ORIGEN', 'PRO_DESTINO', 'SAME_PRO', 'Pedido','CCLASEPRODTODestino','CCLASEPRODTOOrigen']
datac=data.drop(de,axis=1)
datac
# Out:
#       ACEROOrigen ACERODestino BORDESOrigen  DIAM__INTERNOOrigen  \
# 0            6086         6086   LAMINACION                  711
# 1            6086         6086   LAMINACION                  711
# 2            6086         6086   LAMINACION                  711
# 3            6086         6086   LAMINACION                  711
# 4            6086         6086   LAMINACION                  711
# ...           ...          ...          ...                  ...
# 11365      C091AL       C091AL   LAMINACION                  711
# 11366      C091AL       C091AL   LAMINACION                  711
# 11367      C091AL       C091AL   LAMINACION                  711
# 11368      C091AL       C091AL   LAMINACION                  711
# 11369        2042         2042   LAMINACION                  711
#
#                 EXTREMOSOrigen                            NORMAOrigen  \
# 0      CORTADOS 98% EN ESPESOR            TER \ PER-GA (V 2006 REV 1)
# 1      CORTADOS 98% EN ESPESOR            TER \ PER-GA (V 2006 REV 1)
# 2      CORTADOS 98% EN ESPESOR            TER \ PER-GA (V 2006 REV 1)
# 3      CORTADOS 98% EN ESPESOR            TER \ PER-GA (V 2006 REV 1)
# 4      CORTADOS 98% EN ESPESOR            TER \ PER-GA (V 2006 REV 1)
# ...                        ...                                    ...
# 11365  CORTADOS 98% EN ESPESOR  MS 50002 \ LAH240Y320T (V 2014 REV 0)
# 11366  CORTADOS 98% EN ESPESOR  MS 50002 \ LAH240Y320T (V 2014 REV 0)
# 11367  CORTADOS 98% EN ESPESOR  MS 50002 \ LAH240Y320T (V 2014 REV 0)
# 11368  CORTADOS 98% EN ESPESOR  MS 50002 \ LAH240Y320T (V 2014 REV 0)
# 11369  CORTADOS 98% EN ESPESOR  TER \ A635MOD \ SAW-ZF (V 2015 REV 0)
#
#         NORTOLANCHOOrigen     NORTOLESPESOROrigen      PLANITUDOrigen  \
# 0      ASTM A 568 / A 635      ASTM A 568 / A 635  TERNIUM CONTROLADA
# 1      ASTM A 568 / A 635      ASTM A 568 / A 635  TERNIUM CONTROLADA
# 2      ASTM A 568 / A 635      ASTM A 568 / A 635  TERNIUM CONTROLADA
# 3      ASTM A 568 / A 635      ASTM A 568 / A 635  TERNIUM CONTROLADA
# 4      ASTM A 568 / A 635      ASTM A 568 / A 635  TERNIUM CONTROLADA
# ...                   ...                     ...                 ...
# 11365  ASTM A 568 / A 635             PS-5570_LAC  TERNIUM CONTROLADA
# 11366  ASTM A 568 / A 635             PS-5570_LAC  TERNIUM CONTROLADA
# 11367  ASTM A 568 / A 635             PS-5570_LAC  TERNIUM CONTROLADA
# 11368  ASTM A 568 / A 635             PS-5570_LAC  TERNIUM CONTROLADA
# 11369  ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM CONTROLADA
#
#       SOLDAOrigen  ... DIAM__INTERNODestino          EXTREMOSDestino  \
# 0              NO  ...                  711  CORTADOS 98% EN ESPESOR
# 1              NO  ...                  711  CORTADOS 98% EN ESPESOR
# 2              NO  ...                  711  CORTADOS 98% EN ESPESOR
# 3              NO  ...                  711  CORTADOS 98% EN ESPESOR
# 4              NO  ...                  711  CORTADOS 98% EN ESPESOR
# ...           ...  ...                  ...                      ...
# 11365          NO  ...                  711  CORTADOS 98% EN ESPESOR
# 11366          NO  ...                  711  CORTADOS 98% EN ESPESOR
# 11367          NO  ...                  711  CORTADOS 98% EN ESPESOR
# 11368          NO  ...                  711  CORTADOS 98% EN ESPESOR
# 11369          NO  ...                  711  CORTADOS 98% EN ESPESOR
#
#                                 NORMADestino  NORTOLANCHODestino  \
# 0                TER \ PER-GA (V 2006 REV 1)  ASTM A 568 / A 635
# 1                TER \ PER-GA (V 2006 REV 1)  ASTM A 568 / A 635
# 2                TER \ PER-GA (V 2006 REV 1)  ASTM A 568 / A 635
# 3                TER \ PER-GA (V 2006 REV 1)  ASTM A 568 / A 635
# 4                TER \ PER-GA (V 2006 REV 1)  ASTM A 568 / A 635
# ...                                      ...                 ...
# 11365  MS 50002 \ LAH240Y320T (V 2014 REV 0)  ASTM A 568 / A 635
# 11366  MS 50002 \ LAH240Y320T (V 2014 REV 0)  ASTM A 568 / A 635
# 11367  MS 50002 \ LAH240Y320T (V 2014 REV 0)  ASTM A 568 / A 635
# 11368  MS 50002 \ LAH240Y320T (V 2014 REV 0)  ASTM A 568 / A 635
# 11369  TER \ A635MOD \ SAW-ZF (V 2015 REV 0)  ASTM A 568 / A 635
#
#          NORTOLESPESORDestino     PLANITUDDestino SOLDADestino  \
# 0      1/2 ASTM A 568 / A 635  TERNIUM CONTROLADA           NO
# 1      1/2 ASTM A 568 / A 635  TERNIUM CONTROLADA           NO
# 2      1/2 ASTM A 568 / A 635  TERNIUM CONTROLADA           NO
# 3      1/2 ASTM A 568 / A 635  TERNIUM CONTROLADA           NO
# 4      1/2 ASTM A 568 / A 635  TERNIUM CONTROLADA           NO
# ...                       ...                 ...          ...
# 11365             PS-5570_LAC  TERNIUM CONTROLADA           NO
# 11366             PS-5570_LAC  TERNIUM CONTROLADA           NO
# 11367             PS-5570_LAC  TERNIUM CONTROLADA           NO
# 11368             PS-5570_LAC  TERNIUM CONTROLADA           NO
# 11369  1/2 ASTM A 568 / A 635  TERNIUM CONTROLADA           NO
#
#       SUPERFICIEDestino              USOGRALDestino Reasignacion
# 0               INTERNA            TUBOS Y PERFILES           OK
# 1               INTERNA            TUBOS Y PERFILES           OK
# 2               INTERNA            TUBOS Y PERFILES           OK
# 3               INTERNA            TUBOS Y PERFILES           OK
# 4               INTERNA            TUBOS Y PERFILES           OK
# ...                 ...                         ...          ...
# 11365           INTERNA      AUTOMOTRIZ ESTRUCTURAL           OK
# 11366           INTERNA      AUTOMOTRIZ ESTRUCTURAL           OK
# 11367           INTERNA      AUTOMOTRIZ ESTRUCTURAL           OK
# 11368           INTERNA      AUTOMOTRIZ ESTRUCTURAL           OK
# 11369     SEMI-EXPUESTA  AUTOMOTRIZ GRADO COMERCIAL           OK
#
# [11370 rows x 23 columns]

# %%
main_df=datac
main_df=pd.DataFrame(data=main_df)
full_df=datac
full_df=pd.DataFrame(data=full_df)
print(full_df.head(10))
# Out:
#   ACEROOrigen ACERODestino BORDESOrigen  DIAM__INTERNOOrigen  \
# 0        6086         6086   LAMINACION                  711
# 1        6086         6086   LAMINACION                  711
# 2        6086         6086   LAMINACION                  711
# 3        6086         6086   LAMINACION                  711
# 4        6086         6086   LAMINACION                  711
# 5        6086         6086   LAMINACION                  711
# 6        6086         6086   LAMINACION                  711
# 7        6086         6086   LAMINACION                  711
# 8      C071TM       C071TM   LAMINACION                  508
# 9        7092         7092   LAMINACION                  711
#
#             EXTREMOSOrigen                     NORMAOrigen  \
# 0  CORTADOS 98% EN ESPESOR     TER \ PER-GA (V 2006 REV 1)
# 1  CORTADOS 98% EN ESPESOR     TER \ PER-GA (V 2006 REV 1)
# 2  CORTADOS 98% EN ESPESOR     TER \ PER-GA (V 2006 REV 1)
# 3  CORTADOS 98% EN ESPESOR     TER \ PER-GA (V 2006 REV 1)
# 4  CORTADOS 98% EN ESPESOR     TER \ PER-GA (V 2006 REV 1)
# 5  CORTADOS 98% EN ESPESOR     TER \ PER-GA (V 2006 REV 1)
# 6  CORTADOS 98% EN ESPESOR     TER \ PER-GA (V 2006 REV 1)
# 7  CORTADOS 98% EN ESPESOR     TER \ PER-GA (V 2006 REV 1)
# 8  CORTADOS 98% EN ESPESOR  SAE J403 \ 1008 (V 2001 REV 1)
# 9  CORTADOS 98% EN ESPESOR  SAE J403 \ 1008 (V 2001 REV 1)
#
#     NORTOLANCHOOrigen     NORTOLESPESOROrigen      PLANITUDOrigen SOLDAOrigen  \
# 0  ASTM A 568 / A 635      ASTM A 568 / A 635  TERNIUM CONTROLADA          NO
# 1  ASTM A 568 / A 635      ASTM A 568 / A 635  TERNIUM CONTROLADA          NO
# 2  ASTM A 568 / A 635      ASTM A 568 / A 635  TERNIUM CONTROLADA          NO
# 3  ASTM A 568 / A 635      ASTM A 568 / A 635  TERNIUM CONTROLADA          NO
# 4  ASTM A 568 / A 635      ASTM A 568 / A 635  TERNIUM CONTROLADA          NO
# 5  ASTM A 568 / A 635      ASTM A 568 / A 635  TERNIUM CONTROLADA          NO
# 6  ASTM A 568 / A 635      ASTM A 568 / A 635  TERNIUM CONTROLADA          NO
# 7  ASTM A 568 / A 635      ASTM A 568 / A 635  TERNIUM CONTROLADA          NO
# 8  ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM CONTROLADA          NO
# 9  ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM CONTROLADA          NO
#
#    ... DIAM__INTERNODestino          EXTREMOSDestino  \
# 0  ...                  711  CORTADOS 98% EN ESPESOR
# 1  ...                  711  CORTADOS 98% EN ESPESOR
# 2  ...                  711  CORTADOS 98% EN ESPESOR
# 3  ...                  711  CORTADOS 98% EN ESPESOR
# 4  ...                  711  CORTADOS 98% EN ESPESOR
# 5  ...                  711  CORTADOS 98% EN ESPESOR
# 6  ...                  711  CORTADOS 98% EN ESPESOR
# 7  ...                  711  CORTADOS 98% EN ESPESOR
# 8  ...                  711  CORTADOS 98% EN ESPESOR
# 9  ...                  508  CORTADOS 98% EN ESPESOR
#
#                      NORMADestino  NORTOLANCHODestino    NORTOLESPESORDestino  \
# 0     TER \ PER-GA (V 2006 REV 1)  ASTM A 568 / A 635  1/2 ASTM A 568 / A 635
# 1     TER \ PER-GA (V 2006 REV 1)  ASTM A 568 / A 635  1/2 ASTM A 568 / A 635
# 2     TER \ PER-GA (V 2006 REV 1)  ASTM A 568 / A 635  1/2 ASTM A 568 / A 635
# 3     TER \ PER-GA (V 2006 REV 1)  ASTM A 568 / A 635  1/2 ASTM A 568 / A 635
# 4     TER \ PER-GA (V 2006 REV 1)  ASTM A 568 / A 635  1/2 ASTM A 568 / A 635
# 5     TER \ PER-GA (V 2006 REV 1)  ASTM A 568 / A 635  1/2 ASTM A 568 / A 635
# 6     TER \ PER-GA (V 2006 REV 1)  ASTM A 568 / A 635  1/2 ASTM A 568 / A 635
# 7     TER \ PER-GA (V 2006 REV 1)  ASTM A 568 / A 635  1/2 ASTM A 568 / A 635
# 8  SAE J403 \ 1008 (V 2001 REV 1)  ASTM A 568 / A 635  1/2 ASTM A 568 / A 635
# 9  SAE J403 \ 1008 (V 2001 REV 1)  ASTM A 568 / A 635  1/2 ASTM A 568 / A 635
#
#       PLANITUDDestino SOLDADestino SUPERFICIEDestino     USOGRALDestino  \
# 0  TERNIUM CONTROLADA           NO           INTERNA   TUBOS Y PERFILES
# 1  TERNIUM CONTROLADA           NO           INTERNA   TUBOS Y PERFILES
# 2  TERNIUM CONTROLADA           NO           INTERNA   TUBOS Y PERFILES
# 3  TERNIUM CONTROLADA           NO           INTERNA   TUBOS Y PERFILES
# 4  TERNIUM CONTROLADA           NO           INTERNA   TUBOS Y PERFILES
# 5  TERNIUM CONTROLADA           NO           INTERNA   TUBOS Y PERFILES
# 6  TERNIUM CONTROLADA           NO           INTERNA   TUBOS Y PERFILES
# 7  TERNIUM CONTROLADA           NO           INTERNA   TUBOS Y PERFILES
# 8  TERNIUM CONTROLADA           NO           INTERNA  CALIDAD COMERCIAL
# 9  TERNIUM CONTROLADA           NO           INTERNA  CALIDAD COMERCIAL
#
#   Reasignacion
# 0           OK
# 1           OK
# 2           OK
# 3           OK
# 4           OK
# 5           OK
# 6           OK
# 7           OK
# 8           OK
# 9           OK
#
# [10 rows x 23 columns]

# %%
main_df.columns
# Out:
# Index(['ACEROOrigen', 'ACERODestino', 'BORDESOrigen', 'DIAM__INTERNOOrigen',
#        'EXTREMOSOrigen', 'NORMAOrigen', 'NORTOLANCHOOrigen',
#        'NORTOLESPESOROrigen', 'PLANITUDOrigen', 'SOLDAOrigen',
#        'SUPERFICIEOrigen', 'USOGRALOrigen', 'BORDESDestino',
#        'DIAM__INTERNODestino', 'EXTREMOSDestino', 'NORMADestino',
#        'NORTOLANCHODestino', 'NORTOLESPESORDestino', 'PLANITUDDestino',
#        'SOLDADestino', 'SUPERFICIEDestino', 'USOGRALDestino', 'Reasignacion'],
#       dtype='object')

# %%
encobj=le.fit(main_df['Reasignacion'])

# %%
###codificación de variable objetivo usando LE
main_df.Reasignacion=encobj.transform(main_df['Reasignacion'])
main_df
# Out:
#       ACEROOrigen ACERODestino BORDESOrigen  DIAM__INTERNOOrigen  \
# 0            6086         6086   LAMINACION                  711
# 1            6086         6086   LAMINACION                  711
# 2            6086         6086   LAMINACION                  711
# 3            6086         6086   LAMINACION                  711
# 4            6086         6086   LAMINACION                  711
# ...           ...          ...          ...                  ...
# 11365      C091AL       C091AL   LAMINACION                  711
# 11366      C091AL       C091AL   LAMINACION                  711
# 11367      C091AL       C091AL   LAMINACION                  711
# 11368      C091AL       C091AL   LAMINACION                  711
# 11369        2042         2042   LAMINACION                  711
#
#                 EXTREMOSOrigen                            NORMAOrigen  \
# 0      CORTADOS 98% EN ESPESOR            TER \ PER-GA (V 2006 REV 1)
# 1      CORTADOS 98% EN ESPESOR            TER \ PER-GA (V 2006 REV 1)
# 2      CORTADOS 98% EN ESPESOR            TER \ PER-GA (V 2006 REV 1)
# 3      CORTADOS 98% EN ESPESOR            TER \ PER-GA (V 2006 REV 1)
# 4      CORTADOS 98% EN ESPESOR            TER \ PER-GA (V 2006 REV 1)
# ...                        ...                                    ...
# 11365  CORTADOS 98% EN ESPESOR  MS 50002 \ LAH240Y320T (V 2014 REV 0)
# 11366  CORTADOS 98% EN ESPESOR  MS 50002 \ LAH240Y320T (V 2014 REV 0)
# 11367  CORTADOS 98% EN ESPESOR  MS 50002 \ LAH240Y320T (V 2014 REV 0)
# 11368  CORTADOS 98% EN ESPESOR  MS 50002 \ LAH240Y320T (V 2014 REV 0)
# 11369  CORTADOS 98% EN ESPESOR  TER \ A635MOD \ SAW-ZF (V 2015 REV 0)
#
#         NORTOLANCHOOrigen     NORTOLESPESOROrigen      PLANITUDOrigen  \
# 0      ASTM A 568 / A 635      ASTM A 568 / A 635  TERNIUM CONTROLADA
# 1      ASTM A 568 / A 635      ASTM A 568 / A 635  TERNIUM CONTROLADA
# 2      ASTM A 568 / A 635      ASTM A 568 / A 635  TERNIUM CONTROLADA
# 3      ASTM A 568 / A 635      ASTM A 568 / A 635  TERNIUM CONTROLADA
# 4      ASTM A 568 / A 635      ASTM A 568 / A 635  TERNIUM CONTROLADA
# ...                   ...                     ...                 ...
# 11365  ASTM A 568 / A 635             PS-5570_LAC  TERNIUM CONTROLADA
# 11366  ASTM A 568 / A 635             PS-5570_LAC  TERNIUM CONTROLADA
# 11367  ASTM A 568 / A 635             PS-5570_LAC  TERNIUM CONTROLADA
# 11368  ASTM A 568 / A 635             PS-5570_LAC  TERNIUM CONTROLADA
# 11369  ASTM A 568 / A 635  1/2 ASTM A 568 / A 635  TERNIUM CONTROLADA
#
#       SOLDAOrigen  ... DIAM__INTERNODestino          EXTREMOSDestino  \
# 0              NO  ...                  711  CORTADOS 98% EN ESPESOR
# 1              NO  ...                  711  CORTADOS 98% EN ESPESOR
# 2              NO  ...                  711  CORTADOS 98% EN ESPESOR
# 3              NO  ...                  711  CORTADOS 98% EN ESPESOR
# 4              NO  ...                  711  CORTADOS 98% EN ESPESOR
# ...           ...  ...                  ...                      ...
# 11365          NO  ...                  711  CORTADOS 98% EN ESPESOR
# 11366          NO  ...                  711  CORTADOS 98% EN ESPESOR
# 11367          NO  ...                  711  CORTADOS 98% EN ESPESOR
# 11368          NO  ...                  711  CORTADOS 98% EN ESPESOR
# 11369          NO  ...                  711  CORTADOS 98% EN ESPESOR
#
#                                 NORMADestino  NORTOLANCHODestino  \
# 0                TER \ PER-GA (V 2006 REV 1)  ASTM A 568 / A 635
# 1                TER \ PER-GA (V 2006 REV 1)  ASTM A 568 / A 635
# 2                TER \ PER-GA (V 2006 REV 1)  ASTM A 568 / A 635
# 3                TER \ PER-GA (V 2006 REV 1)  ASTM A 568 / A 635
# 4                TER \ PER-GA (V 2006 REV 1)  ASTM A 568 / A 635
# ...                                      ...                 ...
# 11365  MS 50002 \ LAH240Y320T (V 2014 REV 0)  ASTM A 568 / A 635
# 11366  MS 50002 \ LAH240Y320T (V 2014 REV 0)  ASTM A 568 / A 635
# 11367  MS 50002 \ LAH240Y320T (V 2014 REV 0)  ASTM A 568 / A 635
# 11368  MS 50002 \ LAH240Y320T (V 2014 REV 0)  ASTM A 568 / A 635
# 11369  TER \ A635MOD \ SAW-ZF (V 2015 REV 0)  ASTM A 568 / A 635
#
#          NORTOLESPESORDestino     PLANITUDDestino SOLDADestino  \
# 0      1/2 ASTM A 568 / A 635  TERNIUM CONTROLADA           NO
# 1      1/2 ASTM A 568 / A 635  TERNIUM CONTROLADA           NO
# 2      1/2 ASTM A 568 / A 635  TERNIUM CONTROLADA           NO
# 3      1/2 ASTM A 568 / A 635  TERNIUM CONTROLADA           NO
# 4      1/2 ASTM A 568 / A 635  TERNIUM CONTROLADA           NO
# ...                       ...                 ...          ...
# 11365             PS-5570_LAC  TERNIUM CONTROLADA           NO
# 11366             PS-5570_LAC  TERNIUM CONTROLADA           NO
# 11367             PS-5570_LAC  TERNIUM CONTROLADA           NO
# 11368             PS-5570_LAC  TERNIUM CONTROLADA           NO
# 11369  1/2 ASTM A 568 / A 635  TERNIUM CONTROLADA           NO
#
#       SUPERFICIEDestino              USOGRALDestino Reasignacion
# 0               INTERNA            TUBOS Y PERFILES            0
# 1               INTERNA            TUBOS Y PERFILES            0
# 2               INTERNA            TUBOS Y PERFILES            0
# 3               INTERNA            TUBOS Y PERFILES            0
# 4               INTERNA            TUBOS Y PERFILES            0
# ...                 ...                         ...          ...
# 11365           INTERNA      AUTOMOTRIZ ESTRUCTURAL            0
# 11366           INTERNA      AUTOMOTRIZ ESTRUCTURAL            0
# 11367           INTERNA      AUTOMOTRIZ ESTRUCTURAL            0
# 11368           INTERNA      AUTOMOTRIZ ESTRUCTURAL            0
# 11369     SEMI-EXPUESTA  AUTOMOTRIZ GRADO COMERCIAL            0
#
# [11370 rows x 23 columns]

# %%
joblib.dump(encobj,'EncodificacionObjetivo.pkl')
# Out:
# ['EncodificacionObjetivo.pkl']

# %%
###Variable objetivo
target_df = pd.DataFrame(main_df, columns=['Reasignacion'])
print(target_df.sample(10))
# Out:
#        Reasignacion
# 1233              1
# 8303              0
# 10244             0
# 5384              0
# 7796              0
# 6510              0
# 2794              0
# 11164             0
# 9534              0
# 10936             0

# %%
##creación de dataset ecnodificado
main_df=main_df.drop(['Reasignacion'],axis=1)

# %%
####encodifiación de atributos usando target
main_df.columns = main_df.columns.str.strip()
target_df.columns = target_df.columns.str.strip()
enc=category_encoders.target_encoder.TargetEncoder(verbose=0,cols=['ACEROOrigen', 'ACERODestino', 'BORDESOrigen', 'DIAM__INTERNOOrigen',
       'EXTREMOSOrigen', 'NORMAOrigen', 'NORTOLANCHOOrigen',
       'NORTOLESPESOROrigen', 'PLANITUDOrigen', 'SOLDAOrigen',
       'SUPERFICIEOrigen', 'USOGRALOrigen', 'BORDESDestino',
       'DIAM__INTERNODestino', 'EXTREMOSDestino', 'NORMADestino',
       'NORTOLANCHODestino', 'NORTOLESPESORDestino', 'PLANITUDDestino',
       'SOLDADestino', 'SUPERFICIEDestino', 'USOGRALDestino'],drop_invariant=False, return_df=True, handle_unknown='value',handle_missing='value',min_samples_leaf=1,smoothing=1.0).fit(main_df,target_df)

# %%
joblib.dump(enc,'TargetCalienteSKP.pkl')
# Out:
# ['TargetCalienteSKP.pkl']

# %%
codi=enc.transform(main_df)
codi
# Out:
#        ACEROOrigen  ACERODestino  BORDESOrigen  DIAM__INTERNOOrigen  \
# 0         0.041783      0.280546      0.066931             0.047229
# 1         0.041783      0.280546      0.066931             0.047229
# 2         0.041783      0.280546      0.066931             0.047229
# 3         0.041783      0.280546      0.066931             0.047229
# 4         0.041783      0.280546      0.066931             0.047229
# ...            ...           ...           ...                  ...
# 11365     0.111096      0.199984      0.066931             0.047229
# 11366     0.111096      0.199984      0.066931             0.047229
# 11367     0.111096      0.199984      0.066931             0.047229
# 11368     0.111096      0.199984      0.066931             0.047229
# 11369     0.066931      0.066931      0.066931             0.047229
#
#        EXTREMOSOrigen  NORMAOrigen  NORTOLANCHOOrigen  NORTOLESPESOROrigen  \
# 0            0.066931     0.027248           0.067856             0.035273
# 1            0.066931     0.027248           0.067856             0.035273
# 2            0.066931     0.027248           0.067856             0.035273
# 3            0.066931     0.027248           0.067856             0.035273
# 4            0.066931     0.027248           0.067856             0.035273
# ...               ...          ...                ...                  ...
# 11365        0.066931     0.001204           0.067856             0.001204
# 11366        0.066931     0.001204           0.067856             0.001204
# 11367        0.066931     0.001204           0.067856             0.001204
# 11368        0.066931     0.001204           0.067856             0.001204
# 11369        0.066931     0.066931           0.067856             0.068677
#
#        PLANITUDOrigen  SOLDAOrigen  ...  BORDESDestino  DIAM__INTERNODestino  \
# 0            0.066931     0.061838  ...       0.066931              0.098164
# 1            0.066931     0.061838  ...       0.066931              0.098164
# 2            0.066931     0.061838  ...       0.066931              0.098164
# 3            0.066931     0.061838  ...       0.066931              0.098164
# 4            0.066931     0.061838  ...       0.066931              0.098164
# ...               ...          ...  ...            ...                   ...
# 11365        0.066931     0.061838  ...       0.066931              0.098164
# 11366        0.066931     0.061838  ...       0.066931              0.098164
# 11367        0.066931     0.061838  ...       0.066931              0.098164
# 11368        0.066931     0.061838  ...       0.066931              0.098164
# 11369        0.066931     0.061838  ...       0.066931              0.098164
#
#        EXTREMOSDestino  NORMADestino  NORTOLANCHODestino  \
# 0             0.066931      0.275725             0.07293
# 1             0.066931      0.275725             0.07293
# 2             0.066931      0.275725             0.07293
# 3             0.066931      0.275725             0.07293
# 4             0.066931      0.275725             0.07293
# ...                ...           ...                 ...
# 11365         0.066931      0.001204             0.07293
# 11366         0.066931      0.001204             0.07293
# 11367         0.066931      0.001204             0.07293
# 11368         0.066931      0.001204             0.07293
# 11369         0.066931      0.066931             0.07293
#
#        NORTOLESPESORDestino  PLANITUDDestino  SOLDADestino  SUPERFICIEDestino  \
# 0                  0.062724         0.066931      0.092405           0.073659
# 1                  0.062724         0.066931      0.092405           0.073659
# 2                  0.062724         0.066931      0.092405           0.073659
# 3                  0.062724         0.066931      0.092405           0.073659
# 4                  0.062724         0.066931      0.092405           0.073659
# ...                     ...              ...           ...                ...
# 11365              0.001204         0.066931      0.092405           0.073659
# 11366              0.001204         0.066931      0.092405           0.073659
# 11367              0.001204         0.066931      0.092405           0.073659
# 11368              0.001204         0.066931      0.092405           0.073659
# 11369              0.062724         0.066931      0.092405           0.038550
#
#        USOGRALDestino
# 0            0.264202
# 1            0.264202
# 2            0.264202
# 3            0.264202
# 4            0.264202
# ...               ...
# 11365        0.001204
# 11366        0.001204
# 11367        0.001204
# 11368        0.001204
# 11369        0.222170
#
# [11370 rows x 22 columns]

# %%
###declaración de variable x (atributos)
X=codi
X
# Out:
#        ACEROOrigen  ACERODestino  BORDESOrigen  DIAM__INTERNOOrigen  \
# 0         0.041783      0.280546      0.066931             0.047229
# 1         0.041783      0.280546      0.066931             0.047229
# 2         0.041783      0.280546      0.066931             0.047229
# 3         0.041783      0.280546      0.066931             0.047229
# 4         0.041783      0.280546      0.066931             0.047229
# ...            ...           ...           ...                  ...
# 11365     0.111096      0.199984      0.066931             0.047229
# 11366     0.111096      0.199984      0.066931             0.047229
# 11367     0.111096      0.199984      0.066931             0.047229
# 11368     0.111096      0.199984      0.066931             0.047229
# 11369     0.066931      0.066931      0.066931             0.047229
#
#        EXTREMOSOrigen  NORMAOrigen  NORTOLANCHOOrigen  NORTOLESPESOROrigen  \
# 0            0.066931     0.027248           0.067856             0.035273
# 1            0.066931     0.027248           0.067856             0.035273
# 2            0.066931     0.027248           0.067856             0.035273
# 3            0.066931     0.027248           0.067856             0.035273
# 4            0.066931     0.027248           0.067856             0.035273
# ...               ...          ...                ...                  ...
# 11365        0.066931     0.001204           0.067856             0.001204
# 11366        0.066931     0.001204           0.067856             0.001204
# 11367        0.066931     0.001204           0.067856             0.001204
# 11368        0.066931     0.001204           0.067856             0.001204
# 11369        0.066931     0.066931           0.067856             0.068677
#
#        PLANITUDOrigen  SOLDAOrigen  ...  BORDESDestino  DIAM__INTERNODestino  \
# 0            0.066931     0.061838  ...       0.066931              0.098164
# 1            0.066931     0.061838  ...       0.066931              0.098164
# 2            0.066931     0.061838  ...       0.066931              0.098164
# 3            0.066931     0.061838  ...       0.066931              0.098164
# 4            0.066931     0.061838  ...       0.066931              0.098164
# ...               ...          ...  ...            ...                   ...
# 11365        0.066931     0.061838  ...       0.066931              0.098164
# 11366        0.066931     0.061838  ...       0.066931              0.098164
# 11367        0.066931     0.061838  ...       0.066931              0.098164
# 11368        0.066931     0.061838  ...       0.066931              0.098164
# 11369        0.066931     0.061838  ...       0.066931              0.098164
#
#        EXTREMOSDestino  NORMADestino  NORTOLANCHODestino  \
# 0             0.066931      0.275725             0.07293
# 1             0.066931      0.275725             0.07293
# 2             0.066931      0.275725             0.07293
# 3             0.066931      0.275725             0.07293
# 4             0.066931      0.275725             0.07293
# ...                ...           ...                 ...
# 11365         0.066931      0.001204             0.07293
# 11366         0.066931      0.001204             0.07293
# 11367         0.066931      0.001204             0.07293
# 11368         0.066931      0.001204             0.07293
# 11369         0.066931      0.066931             0.07293
#
#        NORTOLESPESORDestino  PLANITUDDestino  SOLDADestino  SUPERFICIEDestino  \
# 0                  0.062724         0.066931      0.092405           0.073659
# 1                  0.062724         0.066931      0.092405           0.073659
# 2                  0.062724         0.066931      0.092405           0.073659
# 3                  0.062724         0.066931      0.092405           0.073659
# 4                  0.062724         0.066931      0.092405           0.073659
# ...                     ...              ...           ...                ...
# 11365              0.001204         0.066931      0.092405           0.073659
# 11366              0.001204         0.066931      0.092405           0.073659
# 11367              0.001204         0.066931      0.092405           0.073659
# 11368              0.001204         0.066931      0.092405           0.073659
# 11369              0.062724         0.066931      0.092405           0.038550
#
#        USOGRALDestino
# 0            0.264202
# 1            0.264202
# 2            0.264202
# 3            0.264202
# 4            0.264202
# ...               ...
# 11365        0.001204
# 11366        0.001204
# 11367        0.001204
# 11368        0.001204
# 11369        0.222170
#
# [11370 rows x 22 columns]

# %%
###declaración de y (objetivo)
y=target_df
y
# Out:
#        Reasignacion
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 11365             0
# 11366             0
# 11367             0
# 11368             0
# 11369             0
#
# [11370 rows x 1 columns]

# %%
##división de datos 
X_train,X_test,y_train,y_test=train_test_split(X,y)

# %%
##entrenamiento
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
###prueba score
dt.score(X_test,y_test)
# Out:
# 0.9475905733380232

# %%
joblib.dump(dt,'ModeloCalienteSKP.pkl')
# Out:
# ['ModeloCalienteSKP.pkl']

# %%
nombres=['OK','RECHAZADO']

# %%
##exportación y render
dot_data=export_graphviz(dt,feature_names= X.columns, class_names=nombres, impurity=False, filled=True)
graph=graphviz.Source(dot_data)
graph.render('ModeloCalienteSKP')
# Out:
# 'ModeloCalienteSKP.pdf'
