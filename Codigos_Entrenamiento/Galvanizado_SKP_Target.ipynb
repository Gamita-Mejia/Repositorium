# %%
###importaciones
import pandas as pd
import numpy as np
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import category_encoders
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import LabelEncoder 
from sklearn.tree import DecisionTreeClassifier
import seaborn as sns
import matplotlib.pyplot as plt
import joblib

# %%
##lectura del csv y objetos a usar
data=pd.read_csv('GalvanizadoSKP.csv', encoding='latin-1')
le=LabelEncoder()
dt=DecisionTreeClassifier()
data
# Out:
#      Estatus           FECHA_ALTA     IdMaterial  NECESIDAD_ORIGEN  \
# 0         OK  03-10-2017 09:40:17  3A620728UG201        3001326454
# 1         OK  28-03-2017 12:10:52  3A590301VG501        3001369615
# 2         OK  28-03-2017 12:07:21  3A590304VG502        3001369615
# 3         OK  03-10-2017 09:38:00  3A657304UG200        3001455166
# 4         OK  24-06-2016 11:50:04  2A317129VG500        3001058345
# ...      ...                  ...            ...               ...
# 3222      OK  10-06-2017 04:42:52  3A637194UG201        3001370945
# 3223      OK  12-05-2017 10:49:18  9A098841PGL00        3001397115
# 3224      OK  15-08-2017 00:23:38  9A115637PGL00        2000679122
# 3225      OK  15-08-2017 00:20:08  9A115638PGL00        2000679122
# 3226      OK  25-10-2017 19:07:30  2A502938UG200        2000685288
#
#       NECESIDAD_DESTINO PRO_ORIGEN PRO_DESTINO      CCLASEPRODTOOrigen  \
# 0            3001572264   MP517654    MP531053  M-P-GALVANIZAD-BOB-SKP
# 1            3000990035   MP517727    MP521338  M-P-GALVANIZAD-BOB-SKP
# 2            3000990035   MP517727    MP521338  M-P-GALVANIZAD-BOB-SKP
# 3            3001572264   MP517654    MP531053  M-P-GALVANIZAD-BOB-SKP
# 4            3001168230   MP517717    MP517779  M-P-GALVANIZAD-BOB-SKP
# ...                 ...        ...         ...                     ...
# 3222         3001455674   MP532965    MP532965  M-P-GALVANIZAD-BOB-SKP
# 3223         3001397115   MP533067    MP533067  M-P-GALVANIZAD-BOB-SKP
# 3224         3001513280   MP533715    MP533715  M-P-GALVANIZAD-BOB-SKP
# 3225         3001513280   MP533715    MP533715  M-P-GALVANIZAD-BOB-SKP
# 3226         2000686613   MP533879    MP533879  M-P-GALVANIZAD-BOB-SKP
#
#      ACABSUPERFRECOrigen                        ACEITADOOrigen  ...  \
# 0                   MATE                                    NO  ...
# 1                   MATE  SI / ANTICORROSIVO / ACEITADO LIGERO  ...
# 2                   MATE  SI / ANTICORROSIVO / ACEITADO LIGERO  ...
# 3                   MATE                                    NO  ...
# 4                   MATE                                    NO  ...
# ...                  ...                                   ...  ...
# 3222                MATE                                    NO  ...
# 3223           BRILLANTE        SI / ANTICORIT / 0.5-1.0 GR/M2  ...
# 3224                MATE        SI / ANTICORIT / 0.5-1.0 GR/M2  ...
# 3225                MATE        SI / ANTICORIT / 0.5-1.0 GR/M2  ...
# 3226                MATE  SI / ANTICORROSIVO / ACEITADO LIGERO  ...
#
#      NORTOLESPESORDestino         PLANITUDDestino  RECUBRIMIENTODestino  \
# 0              ASTM A 924   NIVEL 3 / 29 UI / 4MM                   G90
# 1          1/2 ASTM A 924   NIVEL 4 / 39 UI / 6MM              HD70G70G
# 2          1/2 ASTM A 924   NIVEL 4 / 39 UI / 6MM              HD70G70G
# 3              ASTM A 924   NIVEL 3 / 29 UI / 4MM                   G90
# 4          1/2 ASTM A 924   NIVEL 1 / 15 UI / 3MM                   G40
# ...                   ...                     ...                   ...
# 3222       1/2 ASTM A 924   NIVEL 1 / 15 UI / 3MM                   G60
# 3223              PS-5570  NIVEL 6 / 100 UI / 8MM                 60/60
# 3224             EN 10143  NIVEL 6 / 100 UI / 8MM                 Z 140
# 3225             EN 10143  NIVEL 6 / 100 UI / 8MM                 Z 140
# 3226       1/2 ASTM A 924   NIVEL 3 / 29 UI / 4MM                  UL90
#
#      SELLODestino SUPERFICIEDestino TAMFLORDestino TRATSUPERFDestino  \
# 0              NO           INTERNA         MINIMA          PASIVADO
# 1              NO     SEMI-EXPUESTA         MINIMA   SIN TRATAMIENTO
# 2              NO     SEMI-EXPUESTA         MINIMA   SIN TRATAMIENTO
# 3              NO           INTERNA         MINIMA          PASIVADO
# 4              NO           INTERNA         MINIMA          PASIVADO
# ...           ...               ...            ...               ...
# 3222           NO     SEMI-EXPUESTA         MINIMA     PASIVADO ROHS
# 3223           NO       NO EXPUESTA    MINIMA FLOR   SIN TRATAMIENTO
# 3224           NO       NO EXPUESTA    MINIMA FLOR   SIN TRATAMIENTO
# 3225           NO       NO EXPUESTA    MINIMA FLOR   SIN TRATAMIENTO
# 3226           NO     SEMI-EXPUESTA         MINIMA   SIN TRATAMIENTO
#
#                 USOGRALDestino Reasignacion Pedido
# 0     COMERCIAL Y CONSTRUCCION           OK      1
# 1                   AUTOMOTRIZ           OK      1
# 2                   AUTOMOTRIZ           OK      1
# 3     COMERCIAL Y CONSTRUCCION           OK      1
# 4                 LINEA BLANCA           OK      1
# ...                        ...          ...    ...
# 3222                INDUSTRIAL           OK      1
# 3223                AUTOMOTRIZ           OK      1
# 3224                AUTOMOTRIZ           OK      1
# 3225                AUTOMOTRIZ           OK      1
# 3226                INDUSTRIAL           OK      1
#
# [3227 rows x 45 columns]

# %%
###limpieza de datos
de=['Estatus', 'FECHA_ALTA', 'IdMaterial', 'NECESIDAD_ORIGEN','NECESIDAD_DESTINO', 'PRO_ORIGEN', 'PRO_DESTINO', 'Pedido']
datac=data.drop(de,axis=1)
datac
# Out:
#           CCLASEPRODTOOrigen ACABSUPERFRECOrigen  \
# 0     M-P-GALVANIZAD-BOB-SKP                MATE
# 1     M-P-GALVANIZAD-BOB-SKP                MATE
# 2     M-P-GALVANIZAD-BOB-SKP                MATE
# 3     M-P-GALVANIZAD-BOB-SKP                MATE
# 4     M-P-GALVANIZAD-BOB-SKP                MATE
# ...                      ...                 ...
# 3222  M-P-GALVANIZAD-BOB-SKP                MATE
# 3223  M-P-GALVANIZAD-BOB-SKP           BRILLANTE
# 3224  M-P-GALVANIZAD-BOB-SKP                MATE
# 3225  M-P-GALVANIZAD-BOB-SKP                MATE
# 3226  M-P-GALVANIZAD-BOB-SKP                MATE
#
#                             ACEITADOOrigen BORDESOrigen CARAINSPECCIONOrigen  \
# 0                                       NO     CORTADOS             SUPERIOR
# 1     SI / ANTICORROSIVO / ACEITADO LIGERO   LAMINACIÓN             SUPERIOR
# 2     SI / ANTICORROSIVO / ACEITADO LIGERO   LAMINACIÓN             SUPERIOR
# 3                                       NO     CORTADOS             SUPERIOR
# 4                                       NO   LAMINACIÓN             SUPERIOR
# ...                                    ...          ...                  ...
# 3222                                    NO   LAMINACIÓN             SUPERIOR
# 3223        SI / ANTICORIT / 0.5-1.0 GR/M2     CORTADOS             SUPERIOR
# 3224        SI / ANTICORIT / 0.5-1.0 GR/M2     CORTADOS             SUPERIOR
# 3225        SI / ANTICORIT / 0.5-1.0 GR/M2     CORTADOS             SUPERIOR
# 3226  SI / ANTICORROSIVO / ACEITADO LIGERO     CORTADOS             SUPERIOR
#
#       DIAM__INTERNOOrigen            EXTREMOSOrigen  \
# 0                     610   CORTADOS 98% EN ESPESOR
# 1                     508   CORTADOS 98% EN ESPESOR
# 2                     508   CORTADOS 98% EN ESPESOR
# 3                     610   CORTADOS 98% EN ESPESOR
# 4                     508   CORTADOS 98% EN ESPESOR
# ...                   ...                       ...
# 3222                  508   CORTADOS 98% EN ESPESOR
# 3223                  610  CORTADOS 100% EN ESPESOR
# 3224                  610  CORTADOS 100% EN ESPESOR
# 3225                  610  CORTADOS 100% EN ESPESOR
# 3226                  610   CORTADOS 98% EN ESPESOR
#
#                                 NORMAOrigen NORRECUBRIMIENOrigen  \
# 0     ASTM A 653 \ CS TIPO B (V 2008 REV 0)           ASTM A 653
# 1           GMW2M-ST-S \ CR3 (V 2008 REV 1)                 GMW8
# 2           GMW2M-ST-S \ CR3 (V 2008 REV 1)                 GMW8
# 3     ASTM A 653 \ CS TIPO B (V 2008 REV 0)           ASTM A 653
# 4     ASTM A 653 \ CS TIPO B (V 2008 REV 0)           ASTM A 653
# ...                                     ...                  ...
# 3222  ASTM A 653 \ FS TIPO B (V 2008 REV 0)           ASTM A 653
# 3223  MS.50002 \ LAC240Y320T (V 2014 REV D)             MS.50002
# 3224     EN 10346 \ HX420LAD (V 2009 REV 0)             EN 10346
# 3225     EN 10346 \ HX420LAD (V 2009 REV 0)             EN 10346
# 3226  ASTM A 653 \ CS TIPO B (V 2008 REV 0)                   UL
#
#      NORTOLANCHOOrigen  ... NORTOLANCHODestino NORTOLESPESORDestino  \
# 0           ASTM A 924  ...         ASTM A 924           ASTM A 924
# 1           ASTM A 924  ...         ASTM A 924       1/2 ASTM A 924
# 2           ASTM A 924  ...         ASTM A 924       1/2 ASTM A 924
# 3           ASTM A 924  ...         ASTM A 924           ASTM A 924
# 4           ASTM A 924  ...         ASTM A 924       1/2 ASTM A 924
# ...                ...  ...                ...                  ...
# 3222        ASTM A 924  ...         ASTM A 924       1/2 ASTM A 924
# 3223           PS-5570  ...            PS-5570              PS-5570
# 3224          EN 10143  ...           EN 10143             EN 10143
# 3225          EN 10143  ...           EN 10143             EN 10143
# 3226        ASTM A 924  ...         ASTM A 924       1/2 ASTM A 924
#
#              PLANITUDDestino RECUBRIMIENTODestino SELLODestino  \
# 0      NIVEL 3 / 29 UI / 4MM                  G90           NO
# 1      NIVEL 4 / 39 UI / 6MM             HD70G70G           NO
# 2      NIVEL 4 / 39 UI / 6MM             HD70G70G           NO
# 3      NIVEL 3 / 29 UI / 4MM                  G90           NO
# 4      NIVEL 1 / 15 UI / 3MM                  G40           NO
# ...                      ...                  ...          ...
# 3222   NIVEL 1 / 15 UI / 3MM                  G60           NO
# 3223  NIVEL 6 / 100 UI / 8MM                60/60           NO
# 3224  NIVEL 6 / 100 UI / 8MM                Z 140           NO
# 3225  NIVEL 6 / 100 UI / 8MM                Z 140           NO
# 3226   NIVEL 3 / 29 UI / 4MM                 UL90           NO
#
#      SUPERFICIEDestino TAMFLORDestino TRATSUPERFDestino  \
# 0              INTERNA         MINIMA          PASIVADO
# 1        SEMI-EXPUESTA         MINIMA   SIN TRATAMIENTO
# 2        SEMI-EXPUESTA         MINIMA   SIN TRATAMIENTO
# 3              INTERNA         MINIMA          PASIVADO
# 4              INTERNA         MINIMA          PASIVADO
# ...                ...            ...               ...
# 3222     SEMI-EXPUESTA         MINIMA     PASIVADO ROHS
# 3223       NO EXPUESTA    MINIMA FLOR   SIN TRATAMIENTO
# 3224       NO EXPUESTA    MINIMA FLOR   SIN TRATAMIENTO
# 3225       NO EXPUESTA    MINIMA FLOR   SIN TRATAMIENTO
# 3226     SEMI-EXPUESTA         MINIMA   SIN TRATAMIENTO
#
#                 USOGRALDestino Reasignacion
# 0     COMERCIAL Y CONSTRUCCION           OK
# 1                   AUTOMOTRIZ           OK
# 2                   AUTOMOTRIZ           OK
# 3     COMERCIAL Y CONSTRUCCION           OK
# 4                 LINEA BLANCA           OK
# ...                        ...          ...
# 3222                INDUSTRIAL           OK
# 3223                AUTOMOTRIZ           OK
# 3224                AUTOMOTRIZ           OK
# 3225                AUTOMOTRIZ           OK
# 3226                INDUSTRIAL           OK
#
# [3227 rows x 37 columns]

# %%
datac.columns
# Out:
# Index(['CCLASEPRODTOOrigen', 'ACABSUPERFRECOrigen', 'ACEITADOOrigen',
#        'BORDESOrigen', 'CARAINSPECCIONOrigen', 'DIAM__INTERNOOrigen',
#        'EXTREMOSOrigen', 'NORMAOrigen', 'NORRECUBRIMIENOrigen',
#        'NORTOLANCHOOrigen', 'NORTOLESPESOROrigen', 'PLANITUDOrigen',
#        'RECUBRIMIENTOOrigen', 'SELLOOrigen', 'SUPERFICIEOrigen',
#        'TAMFLOROrigen', 'TRATSUPERFOrigen', 'USOGRALOrigen',
#        'CCLASEPRODTODestino', 'ACABSUPERFRECDestino', 'ACEITADODestino',
#        'BORDESDestino', 'CARAINSPECCIONDestino', 'DIAM__INTERNODestino',
#        'EXTREMOSDestino', 'NORMADestino', 'NORRECUBRIMIENDestino',
#        'NORTOLANCHODestino', 'NORTOLESPESORDestino', 'PLANITUDDestino',
#        'RECUBRIMIENTODestino', 'SELLODestino', 'SUPERFICIEDestino',
#        'TAMFLORDestino', 'TRATSUPERFDestino', 'USOGRALDestino',
#        'Reasignacion'],
#       dtype='object')

# %%
main_df=datac
main_df=pd.DataFrame(data=main_df)
full_df=datac
full_df=pd.DataFrame(data=full_df)
print(full_df.head(10))
# Out:
#        CCLASEPRODTOOrigen ACABSUPERFRECOrigen  \
# 0  M-P-GALVANIZAD-BOB-SKP                MATE
# 1  M-P-GALVANIZAD-BOB-SKP                MATE
# 2  M-P-GALVANIZAD-BOB-SKP                MATE
# 3  M-P-GALVANIZAD-BOB-SKP                MATE
# 4  M-P-GALVANIZAD-BOB-SKP                MATE
# 5  M-P-GALVANIZAD-BOB-SKP                MATE
# 6  M-P-GALVANIZAD-BOB-SKP                MATE
# 7  M-P-GALVANIZAD-BOB-SKP                MATE
# 8  M-P-GALVANIZAD-BOB-SKP                MATE
# 9  M-P-GALVANIZAD-BOB-SKP                MATE
#
#                          ACEITADOOrigen BORDESOrigen CARAINSPECCIONOrigen  \
# 0                                    NO     CORTADOS             SUPERIOR
# 1  SI / ANTICORROSIVO / ACEITADO LIGERO   LAMINACIÓN             SUPERIOR
# 2  SI / ANTICORROSIVO / ACEITADO LIGERO   LAMINACIÓN             SUPERIOR
# 3                                    NO     CORTADOS             SUPERIOR
# 4                                    NO   LAMINACIÓN             SUPERIOR
# 5  SI / ANTICORROSIVO / ACEITADO LIGERO   LAMINACIÓN             SUPERIOR
# 6  SI / ANTICORROSIVO / ACEITADO LIGERO   LAMINACIÓN             SUPERIOR
# 7                                    NO   LAMINACIÓN             SUPERIOR
# 8  SI / ANTICORROSIVO / ACEITADO LIGERO   LAMINACIÓN             SUPERIOR
# 9                                    NO     CORTADOS             SUPERIOR
#
#    DIAM__INTERNOOrigen           EXTREMOSOrigen  \
# 0                  610  CORTADOS 98% EN ESPESOR
# 1                  508  CORTADOS 98% EN ESPESOR
# 2                  508  CORTADOS 98% EN ESPESOR
# 3                  610  CORTADOS 98% EN ESPESOR
# 4                  508  CORTADOS 98% EN ESPESOR
# 5                  508  CORTADOS 98% EN ESPESOR
# 6                  508  CORTADOS 98% EN ESPESOR
# 7                  508  CORTADOS 98% EN ESPESOR
# 8                  508  CORTADOS 98% EN ESPESOR
# 9                  610  CORTADOS 98% EN ESPESOR
#
#                              NORMAOrigen NORRECUBRIMIENOrigen  \
# 0  ASTM A 653 \ CS TIPO B (V 2008 REV 0)           ASTM A 653
# 1        GMW2M-ST-S \ CR3 (V 2008 REV 1)                 GMW8
# 2        GMW2M-ST-S \ CR3 (V 2008 REV 1)                 GMW8
# 3  ASTM A 653 \ CS TIPO B (V 2008 REV 0)           ASTM A 653
# 4  ASTM A 653 \ CS TIPO B (V 2008 REV 0)           ASTM A 653
# 5        GMW2M-ST-S \ CR3 (V 2008 REV 1)                 GMW8
# 6        GMW2M-ST-S \ CR3 (V 2008 REV 1)                 GMW8
# 7  ASTM A 653 \ CS TIPO B (V 2008 REV 0)           ASTM A 653
# 8     TER \ GLV EDDS \ LB (V 2012 REV 1)                  TER
# 9  ASTM A 653 \ CS TIPO B (V 2008 REV 0)           ASTM A 653
#
#       NORTOLANCHOOrigen  ... NORTOLANCHODestino NORTOLESPESORDestino  \
# 0            ASTM A 924  ...         ASTM A 924           ASTM A 924
# 1            ASTM A 924  ...         ASTM A 924       1/2 ASTM A 924
# 2            ASTM A 924  ...         ASTM A 924       1/2 ASTM A 924
# 3            ASTM A 924  ...         ASTM A 924           ASTM A 924
# 4            ASTM A 924  ...         ASTM A 924       1/2 ASTM A 924
# 5            ASTM A 924  ...         ASTM A 924       1/2 ASTM A 924
# 6            ASTM A 924  ...         ASTM A 924       1/2 ASTM A 924
# 7            ASTM A 924  ...         ASTM A 924       1/2 ASTM A 924
# 8  TERNIUM -0.0/+3.0 MM  ...         ASTM A 924       1/2 ASTM A 924
# 9            ASTM A 924  ...         ASTM A 924           ASTM A 924
#
#          PLANITUDDestino RECUBRIMIENTODestino SELLODestino SUPERFICIEDestino  \
# 0  NIVEL 3 / 29 UI / 4MM                  G90           NO           INTERNA
# 1  NIVEL 4 / 39 UI / 6MM             HD70G70G           NO     SEMI-EXPUESTA
# 2  NIVEL 4 / 39 UI / 6MM             HD70G70G           NO     SEMI-EXPUESTA
# 3  NIVEL 3 / 29 UI / 4MM                  G90           NO           INTERNA
# 4  NIVEL 1 / 15 UI / 3MM                  G40           NO           INTERNA
# 5  NIVEL 4 / 39 UI / 6MM             HD70G70G           NO     SEMI-EXPUESTA
# 6  NIVEL 4 / 39 UI / 6MM             HD70G70G           NO     SEMI-EXPUESTA
# 7  NIVEL 1 / 15 UI / 3MM                  G40           NO           INTERNA
# 8  NIVEL 1 / 15 UI / 3MM                  G40           NO          EXPUESTA
# 9  NIVEL 3 / 29 UI / 4MM                  G90           NO           INTERNA
#
#   TAMFLORDestino TRATSUPERFDestino            USOGRALDestino Reasignacion
# 0         MINIMA          PASIVADO  COMERCIAL Y CONSTRUCCION           OK
# 1         MINIMA   SIN TRATAMIENTO                AUTOMOTRIZ           OK
# 2         MINIMA   SIN TRATAMIENTO                AUTOMOTRIZ           OK
# 3         MINIMA          PASIVADO  COMERCIAL Y CONSTRUCCION           OK
# 4         MINIMA          PASIVADO              LINEA BLANCA           OK
# 5         MINIMA   SIN TRATAMIENTO                AUTOMOTRIZ           OK
# 6         MINIMA   SIN TRATAMIENTO                AUTOMOTRIZ           OK
# 7         MINIMA          PASIVADO              LINEA BLANCA           OK
# 8         MINIMA   SIN TRATAMIENTO              LINEA BLANCA           OK
# 9         MINIMA          PASIVADO  COMERCIAL Y CONSTRUCCION           OK
#
# [10 rows x 37 columns]

# %%
###codificación de variable objetivo usando LE
main_df.Reasignacion=le.fit_transform(datac['Reasignacion'])
main_df
# Out:
#           CCLASEPRODTOOrigen ACABSUPERFRECOrigen  \
# 0     M-P-GALVANIZAD-BOB-SKP                MATE
# 1     M-P-GALVANIZAD-BOB-SKP                MATE
# 2     M-P-GALVANIZAD-BOB-SKP                MATE
# 3     M-P-GALVANIZAD-BOB-SKP                MATE
# 4     M-P-GALVANIZAD-BOB-SKP                MATE
# ...                      ...                 ...
# 3222  M-P-GALVANIZAD-BOB-SKP                MATE
# 3223  M-P-GALVANIZAD-BOB-SKP           BRILLANTE
# 3224  M-P-GALVANIZAD-BOB-SKP                MATE
# 3225  M-P-GALVANIZAD-BOB-SKP                MATE
# 3226  M-P-GALVANIZAD-BOB-SKP                MATE
#
#                             ACEITADOOrigen BORDESOrigen CARAINSPECCIONOrigen  \
# 0                                       NO     CORTADOS             SUPERIOR
# 1     SI / ANTICORROSIVO / ACEITADO LIGERO   LAMINACIÓN             SUPERIOR
# 2     SI / ANTICORROSIVO / ACEITADO LIGERO   LAMINACIÓN             SUPERIOR
# 3                                       NO     CORTADOS             SUPERIOR
# 4                                       NO   LAMINACIÓN             SUPERIOR
# ...                                    ...          ...                  ...
# 3222                                    NO   LAMINACIÓN             SUPERIOR
# 3223        SI / ANTICORIT / 0.5-1.0 GR/M2     CORTADOS             SUPERIOR
# 3224        SI / ANTICORIT / 0.5-1.0 GR/M2     CORTADOS             SUPERIOR
# 3225        SI / ANTICORIT / 0.5-1.0 GR/M2     CORTADOS             SUPERIOR
# 3226  SI / ANTICORROSIVO / ACEITADO LIGERO     CORTADOS             SUPERIOR
#
#       DIAM__INTERNOOrigen            EXTREMOSOrigen  \
# 0                     610   CORTADOS 98% EN ESPESOR
# 1                     508   CORTADOS 98% EN ESPESOR
# 2                     508   CORTADOS 98% EN ESPESOR
# 3                     610   CORTADOS 98% EN ESPESOR
# 4                     508   CORTADOS 98% EN ESPESOR
# ...                   ...                       ...
# 3222                  508   CORTADOS 98% EN ESPESOR
# 3223                  610  CORTADOS 100% EN ESPESOR
# 3224                  610  CORTADOS 100% EN ESPESOR
# 3225                  610  CORTADOS 100% EN ESPESOR
# 3226                  610   CORTADOS 98% EN ESPESOR
#
#                                 NORMAOrigen NORRECUBRIMIENOrigen  \
# 0     ASTM A 653 \ CS TIPO B (V 2008 REV 0)           ASTM A 653
# 1           GMW2M-ST-S \ CR3 (V 2008 REV 1)                 GMW8
# 2           GMW2M-ST-S \ CR3 (V 2008 REV 1)                 GMW8
# 3     ASTM A 653 \ CS TIPO B (V 2008 REV 0)           ASTM A 653
# 4     ASTM A 653 \ CS TIPO B (V 2008 REV 0)           ASTM A 653
# ...                                     ...                  ...
# 3222  ASTM A 653 \ FS TIPO B (V 2008 REV 0)           ASTM A 653
# 3223  MS.50002 \ LAC240Y320T (V 2014 REV D)             MS.50002
# 3224     EN 10346 \ HX420LAD (V 2009 REV 0)             EN 10346
# 3225     EN 10346 \ HX420LAD (V 2009 REV 0)             EN 10346
# 3226  ASTM A 653 \ CS TIPO B (V 2008 REV 0)                   UL
#
#      NORTOLANCHOOrigen  ... NORTOLANCHODestino NORTOLESPESORDestino  \
# 0           ASTM A 924  ...         ASTM A 924           ASTM A 924
# 1           ASTM A 924  ...         ASTM A 924       1/2 ASTM A 924
# 2           ASTM A 924  ...         ASTM A 924       1/2 ASTM A 924
# 3           ASTM A 924  ...         ASTM A 924           ASTM A 924
# 4           ASTM A 924  ...         ASTM A 924       1/2 ASTM A 924
# ...                ...  ...                ...                  ...
# 3222        ASTM A 924  ...         ASTM A 924       1/2 ASTM A 924
# 3223           PS-5570  ...            PS-5570              PS-5570
# 3224          EN 10143  ...           EN 10143             EN 10143
# 3225          EN 10143  ...           EN 10143             EN 10143
# 3226        ASTM A 924  ...         ASTM A 924       1/2 ASTM A 924
#
#              PLANITUDDestino RECUBRIMIENTODestino SELLODestino  \
# 0      NIVEL 3 / 29 UI / 4MM                  G90           NO
# 1      NIVEL 4 / 39 UI / 6MM             HD70G70G           NO
# 2      NIVEL 4 / 39 UI / 6MM             HD70G70G           NO
# 3      NIVEL 3 / 29 UI / 4MM                  G90           NO
# 4      NIVEL 1 / 15 UI / 3MM                  G40           NO
# ...                      ...                  ...          ...
# 3222   NIVEL 1 / 15 UI / 3MM                  G60           NO
# 3223  NIVEL 6 / 100 UI / 8MM                60/60           NO
# 3224  NIVEL 6 / 100 UI / 8MM                Z 140           NO
# 3225  NIVEL 6 / 100 UI / 8MM                Z 140           NO
# 3226   NIVEL 3 / 29 UI / 4MM                 UL90           NO
#
#      SUPERFICIEDestino TAMFLORDestino TRATSUPERFDestino  \
# 0              INTERNA         MINIMA          PASIVADO
# 1        SEMI-EXPUESTA         MINIMA   SIN TRATAMIENTO
# 2        SEMI-EXPUESTA         MINIMA   SIN TRATAMIENTO
# 3              INTERNA         MINIMA          PASIVADO
# 4              INTERNA         MINIMA          PASIVADO
# ...                ...            ...               ...
# 3222     SEMI-EXPUESTA         MINIMA     PASIVADO ROHS
# 3223       NO EXPUESTA    MINIMA FLOR   SIN TRATAMIENTO
# 3224       NO EXPUESTA    MINIMA FLOR   SIN TRATAMIENTO
# 3225       NO EXPUESTA    MINIMA FLOR   SIN TRATAMIENTO
# 3226     SEMI-EXPUESTA         MINIMA   SIN TRATAMIENTO
#
#                 USOGRALDestino Reasignacion
# 0     COMERCIAL Y CONSTRUCCION            0
# 1                   AUTOMOTRIZ            0
# 2                   AUTOMOTRIZ            0
# 3     COMERCIAL Y CONSTRUCCION            0
# 4                 LINEA BLANCA            0
# ...                        ...          ...
# 3222                INDUSTRIAL            0
# 3223                AUTOMOTRIZ            0
# 3224                AUTOMOTRIZ            0
# 3225                AUTOMOTRIZ            0
# 3226                INDUSTRIAL            0
#
# [3227 rows x 37 columns]

# %%
###Variable objetivo
target_df = pd.DataFrame(main_df, columns=['Reasignacion'])
print(target_df.sample(10))
# Out:
#       Reasignacion
# 279              1
# 2972             0
# 2180             0
# 2305             0
# 1943             0
# 877              0
# 2723             0
# 2449             0
# 504              0
# 866              0

# %%
main_df=main_df.drop(['Reasignacion'],axis=1)

# %%
####encodifiación de atributos usando target
main_df.columns = main_df.columns.str.strip()
target_df.columns = target_df.columns.str.strip()
enc=category_encoders.target_encoder.TargetEncoder(verbose=0,cols=['CCLASEPRODTOOrigen', 'ACABSUPERFRECOrigen', 
       'ACEITADOOrigen','BORDESOrigen', 'CARAINSPECCIONOrigen', 'DIAM__INTERNOOrigen',
       'EXTREMOSOrigen', 'NORMAOrigen', 'NORRECUBRIMIENOrigen',
       'NORTOLANCHOOrigen', 'NORTOLESPESOROrigen', 'PLANITUDOrigen',
       'RECUBRIMIENTOOrigen', 'SELLOOrigen', 'SUPERFICIEOrigen',
       'TAMFLOROrigen', 'TRATSUPERFOrigen', 'USOGRALOrigen',
       'CCLASEPRODTODestino', 'ACABSUPERFRECDestino', 'ACEITADODestino',
       'BORDESDestino', 'CARAINSPECCIONDestino', 'DIAM__INTERNODestino',
       'EXTREMOSDestino', 'NORMADestino', 'NORRECUBRIMIENDestino',
       'NORTOLANCHODestino', 'NORTOLESPESORDestino', 'PLANITUDDestino',
       'RECUBRIMIENTODestino', 'SELLODestino', 'SUPERFICIEDestino',
       'TAMFLORDestino', 'TRATSUPERFDestino', 'USOGRALDestino'],drop_invariant=False, return_df=True, handle_unknown='value',handle_missing='value',min_samples_leaf=1,smoothing=1.0).fit(main_df,target_df)

# %%
joblib.dump(enc,'TargetGalvanizado_SKP.pkl')
# Out:
# ['TargetGalvanizado_SKP.pkl']

# %%
codi=enc.transform(main_df)
codi
# Out:
#       CCLASEPRODTOOrigen  ACABSUPERFRECOrigen  ACEITADOOrigen  BORDESOrigen  \
# 0               0.084599             0.085580        0.049689      0.085161
# 1               0.084599             0.085580        0.097279      0.084421
# 2               0.084599             0.085580        0.097279      0.084421
# 3               0.084599             0.085580        0.049689      0.085161
# 4               0.084599             0.085580        0.049689      0.084421
# ...                  ...                  ...             ...           ...
# 3222            0.084599             0.085580        0.049689      0.084421
# 3223            0.084599             0.000077        0.098196      0.085161
# 3224            0.084599             0.085580        0.098196      0.085161
# 3225            0.084599             0.085580        0.098196      0.085161
# 3226            0.084599             0.085580        0.097279      0.085161
#
#       CARAINSPECCIONOrigen  DIAM__INTERNOOrigen  EXTREMOSOrigen  NORMAOrigen  \
# 0                 0.084599             0.070485        0.080238     0.098340
# 1                 0.084599             0.090125        0.080238     0.045249
# 2                 0.084599             0.090125        0.080238     0.045249
# 3                 0.084599             0.070485        0.080238     0.098340
# 4                 0.084599             0.090125        0.080238     0.098340
# ...                    ...                  ...             ...          ...
# 3222              0.084599             0.090125        0.080238     0.037773
# 3223              0.084599             0.070485        0.106542     0.000209
# 3224              0.084599             0.070485        0.106542     0.555398
# 3225              0.084599             0.070485        0.106542     0.555398
# 3226              0.084599             0.070485        0.080238     0.098340
#
#       NORRECUBRIMIENOrigen  NORTOLANCHOOrigen  ...  NORRECUBRIMIENDestino  \
# 0                 0.072243       7.965595e-02  ...               0.073881
# 1                 0.076280       7.965595e-02  ...               0.077253
# 2                 0.076280       7.965595e-02  ...               0.077253
# 3                 0.072243       7.965595e-02  ...               0.073881
# 4                 0.072243       7.965595e-02  ...               0.073881
# ...                    ...                ...  ...                    ...
# 3222              0.072243       7.965595e-02  ...               0.073881
# 3223              0.000010       5.197892e-07  ...               0.333250
# 3224              0.555398       4.999487e-01  ...               0.199986
# 3225              0.555398       4.999487e-01  ...               0.199986
# 3226              0.107438       7.965595e-02  ...               0.096026
#
#       NORTOLANCHODestino  NORTOLESPESORDestino  PLANITUDDestino  \
# 0               0.084446              0.240000         0.063653
# 1               0.084446              0.085366         0.074231
# 2               0.084446              0.085366         0.074231
# 3               0.084446              0.240000         0.063653
# 4               0.084446              0.085366         0.107365
# ...                  ...                   ...              ...
# 3222            0.084446              0.085366         0.107365
# 3223            0.249997              0.249997         0.169492
# 3224            0.181814              0.181814         0.169492
# 3225            0.181814              0.181814         0.169492
# 3226            0.084446              0.085366         0.063653
#
#       RECUBRIMIENTODestino  SELLODestino  SUPERFICIEDestino  TAMFLORDestino  \
# 0                 0.051515      0.084599           0.091837        0.083556
# 1                 0.077519      0.084599           0.078136        0.083556
# 2                 0.077519      0.084599           0.078136        0.083556
# 3                 0.051515      0.084599           0.091837        0.083556
# 4                 0.090737      0.084599           0.091837        0.083556
# ...                    ...           ...                ...             ...
# 3222              0.163743      0.084599           0.078136        0.083556
# 3223              0.374735      0.084599           0.082474        0.075472
# 3224              0.022752      0.084599           0.082474        0.075472
# 3225              0.022752      0.084599           0.082474        0.075472
# 3226              0.107477      0.084599           0.078136        0.083556
#
#       TRATSUPERFDestino  USOGRALDestino
# 0          6.654676e-02        0.051724
# 1          1.080173e-01        0.074478
# 2          1.080173e-01        0.074478
# 3          6.654676e-02        0.051724
# 4          6.654676e-02        0.081121
# ...                 ...             ...
# 3222       1.502775e-16        0.102349
# 3223       1.080173e-01        0.074478
# 3224       1.080173e-01        0.074478
# 3225       1.080173e-01        0.074478
# 3226       1.080173e-01        0.102349
#
# [3227 rows x 36 columns]

# %%
###declaración de variable x (atributos)
X=codi
X
# Out:
#       CCLASEPRODTOOrigen  ACABSUPERFRECOrigen  ACEITADOOrigen  BORDESOrigen  \
# 0               0.084599             0.085580        0.049689      0.085161
# 1               0.084599             0.085580        0.097279      0.084421
# 2               0.084599             0.085580        0.097279      0.084421
# 3               0.084599             0.085580        0.049689      0.085161
# 4               0.084599             0.085580        0.049689      0.084421
# ...                  ...                  ...             ...           ...
# 3222            0.084599             0.085580        0.049689      0.084421
# 3223            0.084599             0.000077        0.098196      0.085161
# 3224            0.084599             0.085580        0.098196      0.085161
# 3225            0.084599             0.085580        0.098196      0.085161
# 3226            0.084599             0.085580        0.097279      0.085161
#
#       CARAINSPECCIONOrigen  DIAM__INTERNOOrigen  EXTREMOSOrigen  NORMAOrigen  \
# 0                 0.084599             0.070485        0.080238     0.098340
# 1                 0.084599             0.090125        0.080238     0.045249
# 2                 0.084599             0.090125        0.080238     0.045249
# 3                 0.084599             0.070485        0.080238     0.098340
# 4                 0.084599             0.090125        0.080238     0.098340
# ...                    ...                  ...             ...          ...
# 3222              0.084599             0.090125        0.080238     0.037773
# 3223              0.084599             0.070485        0.106542     0.000209
# 3224              0.084599             0.070485        0.106542     0.555398
# 3225              0.084599             0.070485        0.106542     0.555398
# 3226              0.084599             0.070485        0.080238     0.098340
#
#       NORRECUBRIMIENOrigen  NORTOLANCHOOrigen  ...  NORRECUBRIMIENDestino  \
# 0                 0.072243       7.965595e-02  ...               0.073881
# 1                 0.076280       7.965595e-02  ...               0.077253
# 2                 0.076280       7.965595e-02  ...               0.077253
# 3                 0.072243       7.965595e-02  ...               0.073881
# 4                 0.072243       7.965595e-02  ...               0.073881
# ...                    ...                ...  ...                    ...
# 3222              0.072243       7.965595e-02  ...               0.073881
# 3223              0.000010       5.197892e-07  ...               0.333250
# 3224              0.555398       4.999487e-01  ...               0.199986
# 3225              0.555398       4.999487e-01  ...               0.199986
# 3226              0.107438       7.965595e-02  ...               0.096026
#
#       NORTOLANCHODestino  NORTOLESPESORDestino  PLANITUDDestino  \
# 0               0.084446              0.240000         0.063653
# 1               0.084446              0.085366         0.074231
# 2               0.084446              0.085366         0.074231
# 3               0.084446              0.240000         0.063653
# 4               0.084446              0.085366         0.107365
# ...                  ...                   ...              ...
# 3222            0.084446              0.085366         0.107365
# 3223            0.249997              0.249997         0.169492
# 3224            0.181814              0.181814         0.169492
# 3225            0.181814              0.181814         0.169492
# 3226            0.084446              0.085366         0.063653
#
#       RECUBRIMIENTODestino  SELLODestino  SUPERFICIEDestino  TAMFLORDestino  \
# 0                 0.051515      0.084599           0.091837        0.083556
# 1                 0.077519      0.084599           0.078136        0.083556
# 2                 0.077519      0.084599           0.078136        0.083556
# 3                 0.051515      0.084599           0.091837        0.083556
# 4                 0.090737      0.084599           0.091837        0.083556
# ...                    ...           ...                ...             ...
# 3222              0.163743      0.084599           0.078136        0.083556
# 3223              0.374735      0.084599           0.082474        0.075472
# 3224              0.022752      0.084599           0.082474        0.075472
# 3225              0.022752      0.084599           0.082474        0.075472
# 3226              0.107477      0.084599           0.078136        0.083556
#
#       TRATSUPERFDestino  USOGRALDestino
# 0          6.654676e-02        0.051724
# 1          1.080173e-01        0.074478
# 2          1.080173e-01        0.074478
# 3          6.654676e-02        0.051724
# 4          6.654676e-02        0.081121
# ...                 ...             ...
# 3222       1.502775e-16        0.102349
# 3223       1.080173e-01        0.074478
# 3224       1.080173e-01        0.074478
# 3225       1.080173e-01        0.074478
# 3226       1.080173e-01        0.102349
#
# [3227 rows x 36 columns]

# %%
###declaración de y (objetivo)
y=target_df
y
# Out:
#       Reasignacion
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 3222             0
# 3223             0
# 3224             0
# 3225             0
# 3226             0
#
# [3227 rows x 1 columns]

# %%
##división de datos 
X_train,X_test,y_train,y_test=train_test_split(X,y)

# %%
##entrenamiento
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
###prueba score
print('Presición evaluación: {0:.6f}'.format(dt.score(X_test,y_test)))
# Out:
# Presición evaluación: 0.915737

# %%
# precisión del modelo en datos de entrenamiento.
print("Precisión entrenamiento: {0: .6f}".format(dt.score(X_train,y_train)))
# Out:
# Precisión entrenamiento:  0.954545

# %%
joblib.dump(dt,'ModeloGalvanizadoSKP.pkl')
# Out:
# ['ModeloGalvanizadoSKP.pkl']

# %%
nombres=['OK','RECHAZADO']

# %%
##exportación y render
dot_data=export_graphviz(dt,feature_names= X.columns, class_names=nombres, impurity=False, filled=True)
graph=graphviz.Source(dot_data)
graph.render('ModeloGalvanizadoSKP')
# Out:
# 'ModeloCalienteTar.pdf'
