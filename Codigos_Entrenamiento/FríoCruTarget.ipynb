# %%
###importaciones
import pandas as pd
import numpy as np
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import category_encoders
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import LabelEncoder 
from sklearn.tree import DecisionTreeClassifier
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.tree import export_graphviz
import graphviz
import joblib

# %%
##lectura del csv y objetos a usar
data=pd.read_csv("FrioCru.csv")
le=LabelEncoder()
dt=DecisionTreeClassifier()
data
# Out:
#       Estatus           FECHA_ALTA     IdMaterial  NECESIDAD_ORIGEN  \
# 0          OK  04-12-2015 16:33:46  3A397285CTD00        3000931180
# 1          OK  15-09-2017 12:39:12  3A679729PDT00        3001527416
# 2          OK  25-09-2017 22:42:32  3A686394CS300        3001473793
# 3          OK  08-08-2017 12:16:55  3A667174CM300        3001544574
# 4          OK  04-08-2017 16:15:53  3A666439CM300        3001523759
# ...       ...                  ...            ...               ...
# 64634      OK  30-12-2016 15:18:35  2A416967GM200        3001320265
# 64635      OK  21-06-2017 11:14:24  3A639317CM300        3001455189
# 64636      OK  08-09-2017 21:05:39  3A643180CM300        3001344984
# 64637      OK  04-03-2016 14:44:08  2A316692CTD00        3000959764
# 64638      OK  24-06-2017 17:31:24  3A637744CM300        3001461768
#
#       ACEROOrigen C_ACEROOrigen  NECESIDAD_DESTINO ACERODestino  \
# 0          UBCTIS            IF         3000995979       UBCIMS
# 1          UBCIMS            IF         3001477521       UBCIMS
# 2          UBCIMS            IF         3001575868       UBCIMS
# 3          UBCIMS            IF         3001549129       UBCIMS
# 4          UBCIMS            IF         3001547888       UBCIMS
# ...           ...           ...                ...          ...
# 64634        7061            CS         3001105911       APM50M
# 64635      ACE517            CS         3001499271       APM50M
# 64636      ACE523            CS         3001568185       UBCIMS
# 64637      C091TM            SS         3001068899         6066
# 64638      ACE514            CS         3001489103       UBCIMS
#
#       C_ACERODestino PRO_ORIGEN  ...          EXTREMOSDestino  \
# 0                 IF   MP501141  ...  CORTADOS 98% EN ESPESOR
# 1                 IF   MP501141  ...  CORTADOS 98% EN ESPESOR
# 2                 IF   MP501141  ...  CORTADOS 98% EN ESPESOR
# 3                 IF   MP501141  ...  CORTADOS 98% EN ESPESOR
# 4                 IF   MP501141  ...  CORTADOS 98% EN ESPESOR
# ...              ...        ...  ...                      ...
# 64634             HS   MP517074  ...  CORTADOS 98% EN ESPESOR
# 64635             HS   MP509028  ...  CORTADOS 98% EN ESPESOR
# 64636             IF   MP532767  ...  CORTADOS 98% EN ESPESOR
# 64637             CS   MP518488  ...  CORTADOS 98% EN ESPESOR
# 64638             IF   MP507715  ...  CORTADOS 98% EN ESPESOR
#
#                          NORMADestino NORTOLANCHODestino NORTOLESPESORDestino  \
# 0       TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568       1/2 ASTM A 568
# 1       TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568       1/2 ASTM A 568
# 2       TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568       1/2 ASTM A 568
# 3       TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568       1/2 ASTM A 568
# 4       TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568       1/2 ASTM A 568
# ...                               ...                ...                  ...
# 64634  TER \ GA050 GAL (V 2011 REV 1)         ASTM A 568       1/2 ASTM A 568
# 64635  TER \ GA050 GAL (V 2011 REV 1)         ASTM A 568       1/2 ASTM A 568
# 64636   TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568       1/2 ASTM A 568
# 64637   TER \ 1006 GAL (V 2011 REV 1)    TER \ COMERCIAL       1/2 ASTM A 568
# 64638   TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568       1/2 ASTM A 568
#
#         PLANITUDDestino SOLDADestino SUPERFICIEDestino    USOGRALDestino  \
# 0      TERNIUM ESTANDAR           NO     SEMI-EXPUESTA  GALV. INDUSTRIAL
# 1      TERNIUM ESTANDAR           NO     SEMI-EXPUESTA  GALV. INDUSTRIAL
# 2      TERNIUM ESTANDAR           NO     SEMI-EXPUESTA  GALV. INDUSTRIAL
# 3      TERNIUM ESTANDAR           NO     SEMI-EXPUESTA  GALV. INDUSTRIAL
# 4      TERNIUM ESTANDAR           NO     SEMI-EXPUESTA  GALV. INDUSTRIAL
# ...                 ...          ...               ...               ...
# 64634  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA       GALVANIZADO
# 64635  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA       GALVANIZADO
# 64636  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA  GALV. INDUSTRIAL
# 64637  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA       GALVANIZADO
# 64638  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA  GALV. INDUSTRIAL
#
#       Reasignacion Pedido
# 0               OK      1
# 1               OK      1
# 2               OK      1
# 3               OK      1
# 4               OK      1
# ...            ...    ...
# 64634    Rechazado      1
# 64635    Rechazado      1
# 64636    Rechazado      1
# 64637    Rechazado      1
# 64638    Rechazado      1
#
# [64639 rows x 37 columns]

# %%
###limpieza de datos
de=['Estatus', 'FECHA_ALTA', 'IdMaterial', 'NECESIDAD_ORIGEN','NECESIDAD_DESTINO', 'PRO_ORIGEN', 'PRO_DESTINO', 'Pedido','C_ACERODestino','C_ACEROOrigen','CCLASEPRODTODestino','CCLASEPRODTOOrigen']
datac=data.drop(de,axis=1)
datac
# Out:
#       ACEROOrigen ACERODestino ACABSUPEROrigen BORDESOrigen  \
# 0          UBCTIS       UBCIMS            MATE   LAMINACION
# 1          UBCIMS       UBCIMS            MATE   LAMINACION
# 2          UBCIMS       UBCIMS            MATE   LAMINACION
# 3          UBCIMS       UBCIMS            MATE   LAMINACION
# 4          UBCIMS       UBCIMS            MATE   LAMINACION
# ...           ...          ...             ...          ...
# 64634        7061       APM50M            MATE   LAMINACION
# 64635      ACE517       APM50M            MATE   LAMINACION
# 64636      ACE523       UBCIMS            MATE   LAMINACION
# 64637      C091TM         6066            MATE   LAMINACION
# 64638      ACE514       UBCIMS            MATE   LAMINACION
#
#        DIAM__INTERNOOrigen           EXTREMOSOrigen  \
# 0                      508  CORTADOS 98% EN ESPESOR
# 1                      508  CORTADOS 98% EN ESPESOR
# 2                      508  CORTADOS 98% EN ESPESOR
# 3                      508  CORTADOS 98% EN ESPESOR
# 4                      508  CORTADOS 98% EN ESPESOR
# ...                    ...                      ...
# 64634                  508  CORTADOS 98% EN ESPESOR
# 64635                  508  CORTADOS 98% EN ESPESOR
# 64636                  508  CORTADOS 98% EN ESPESOR
# 64637                  508  CORTADOS 98% EN ESPESOR
# 64638                  508  CORTADOS 98% EN ESPESOR
#
#                                   NORMAOrigen NORTOLANCHOOrigen  \
# 0               TER \ EDDS GAL (V 2011 REV 1)        ASTM A 568
# 1               TER \ EDDS GAL (V 2011 REV 1)        ASTM A 568
# 2               TER \ EDDS GAL (V 2011 REV 1)        ASTM A 568
# 3               TER \ EDDS GAL (V 2011 REV 1)        ASTM A 568
# 4               TER \ EDDS GAL (V 2011 REV 1)        ASTM A 568
# ...                                       ...               ...
# 64634           TER \ 1006 GAL (V 2011 REV 1)        ASTM A 568
# 64635           TER \ 50LCTGLV (V 2011 REV 1)        ASTM A 568
# 64636   TER \ EDDS IFTIS \ GAL (V 2016 REV 1)        ASTM A 568
# 64637       TER \ GA040 GAL SS (V 2011 REV 1)        ASTM A 568
# 64638  TER \ GMW2MSTS EDDS GAL (V 2012 REV 1)        ASTM A 568
#
#       NORTOLESPESOROrigen    PLANITUDOrigen  ... DIAM__INTERNODestino  \
# 0          1/2 ASTM A 568  TERNIUM ESTANDAR  ...                  508
# 1          1/2 ASTM A 568  TERNIUM ESTANDAR  ...                  508
# 2          1/2 ASTM A 568  TERNIUM ESTANDAR  ...                  508
# 3          1/2 ASTM A 568  TERNIUM ESTANDAR  ...                  508
# 4          1/2 ASTM A 568  TERNIUM ESTANDAR  ...                  508
# ...                   ...               ...  ...                  ...
# 64634      1/2 ASTM A 568  TERNIUM ESTANDAR  ...                  508
# 64635      1/2 ASTM A 568  TERNIUM ESTANDAR  ...                  508
# 64636      1/2 ASTM A 568  TERNIUM ESTANDAR  ...                  508
# 64637      1/2 ASTM A 568  TERNIUM ESTANDAR  ...                  508
# 64638        GM_W3224_LAF  TERNIUM ESTANDAR  ...                  508
#
#                EXTREMOSDestino                    NORMADestino  \
# 0      CORTADOS 98% EN ESPESOR   TER \ EDDS GAL (V 2011 REV 1)
# 1      CORTADOS 98% EN ESPESOR   TER \ EDDS GAL (V 2011 REV 1)
# 2      CORTADOS 98% EN ESPESOR   TER \ EDDS GAL (V 2011 REV 1)
# 3      CORTADOS 98% EN ESPESOR   TER \ EDDS GAL (V 2011 REV 1)
# 4      CORTADOS 98% EN ESPESOR   TER \ EDDS GAL (V 2011 REV 1)
# ...                        ...                             ...
# 64634  CORTADOS 98% EN ESPESOR  TER \ GA050 GAL (V 2011 REV 1)
# 64635  CORTADOS 98% EN ESPESOR  TER \ GA050 GAL (V 2011 REV 1)
# 64636  CORTADOS 98% EN ESPESOR   TER \ EDDS GAL (V 2011 REV 1)
# 64637  CORTADOS 98% EN ESPESOR   TER \ 1006 GAL (V 2011 REV 1)
# 64638  CORTADOS 98% EN ESPESOR   TER \ EDDS GAL (V 2011 REV 1)
#
#       NORTOLANCHODestino NORTOLESPESORDestino   PLANITUDDestino SOLDADestino  \
# 0             ASTM A 568       1/2 ASTM A 568  TERNIUM ESTANDAR           NO
# 1             ASTM A 568       1/2 ASTM A 568  TERNIUM ESTANDAR           NO
# 2             ASTM A 568       1/2 ASTM A 568  TERNIUM ESTANDAR           NO
# 3             ASTM A 568       1/2 ASTM A 568  TERNIUM ESTANDAR           NO
# 4             ASTM A 568       1/2 ASTM A 568  TERNIUM ESTANDAR           NO
# ...                  ...                  ...               ...          ...
# 64634         ASTM A 568       1/2 ASTM A 568  TERNIUM ESTANDAR           NO
# 64635         ASTM A 568       1/2 ASTM A 568  TERNIUM ESTANDAR           NO
# 64636         ASTM A 568       1/2 ASTM A 568  TERNIUM ESTANDAR           NO
# 64637    TER \ COMERCIAL       1/2 ASTM A 568  TERNIUM ESTANDAR           NO
# 64638         ASTM A 568       1/2 ASTM A 568  TERNIUM ESTANDAR           NO
#
#       SUPERFICIEDestino    USOGRALDestino Reasignacion
# 0         SEMI-EXPUESTA  GALV. INDUSTRIAL           OK
# 1         SEMI-EXPUESTA  GALV. INDUSTRIAL           OK
# 2         SEMI-EXPUESTA  GALV. INDUSTRIAL           OK
# 3         SEMI-EXPUESTA  GALV. INDUSTRIAL           OK
# 4         SEMI-EXPUESTA  GALV. INDUSTRIAL           OK
# ...                 ...               ...          ...
# 64634     SEMI-EXPUESTA       GALVANIZADO    Rechazado
# 64635     SEMI-EXPUESTA       GALVANIZADO    Rechazado
# 64636     SEMI-EXPUESTA  GALV. INDUSTRIAL    Rechazado
# 64637     SEMI-EXPUESTA       GALVANIZADO    Rechazado
# 64638     SEMI-EXPUESTA  GALV. INDUSTRIAL    Rechazado
#
# [64639 rows x 25 columns]

# %%
main_df=datac
main_df=pd.DataFrame(data=main_df)
full_df=datac
full_df=pd.DataFrame(data=full_df)
print(full_df.head(10))
# Out:
#   ACEROOrigen ACERODestino ACABSUPEROrigen BORDESOrigen  DIAM__INTERNOOrigen  \
# 0      UBCTIS       UBCIMS            MATE   LAMINACION                  508
# 1      UBCIMS       UBCIMS            MATE   LAMINACION                  508
# 2      UBCIMS       UBCIMS            MATE   LAMINACION                  508
# 3      UBCIMS       UBCIMS            MATE   LAMINACION                  508
# 4      UBCIMS       UBCIMS            MATE   LAMINACION                  508
# 5      ACE523       ACE523            MATE   LAMINACION                  508
# 6      UBCIMS       UBCIMS            MATE   LAMINACION                  508
# 7      UBCIMS       UBCIMS            MATE   LAMINACION                  508
# 8      UBCTIS       UBCTIS            MATE   LAMINACION                  508
# 9      UBCTIS       UBCTIS            MATE   LAMINACION                  508
#
#             EXTREMOSOrigen                    NORMAOrigen NORTOLANCHOOrigen  \
# 0  CORTADOS 98% EN ESPESOR  TER \ EDDS GAL (V 2011 REV 1)        ASTM A 568
# 1  CORTADOS 98% EN ESPESOR  TER \ EDDS GAL (V 2011 REV 1)        ASTM A 568
# 2  CORTADOS 98% EN ESPESOR  TER \ EDDS GAL (V 2011 REV 1)        ASTM A 568
# 3  CORTADOS 98% EN ESPESOR  TER \ EDDS GAL (V 2011 REV 1)        ASTM A 568
# 4  CORTADOS 98% EN ESPESOR  TER \ EDDS GAL (V 2011 REV 1)        ASTM A 568
# 5  CORTADOS 98% EN ESPESOR  TER \ EDDS GAL (V 2011 REV 1)        ASTM A 568
# 6  CORTADOS 98% EN ESPESOR  TER \ EDDS GAL (V 2011 REV 1)        ASTM A 568
# 7  CORTADOS 98% EN ESPESOR  TER \ EDDS GAL (V 2011 REV 1)        ASTM A 568
# 8  CORTADOS 98% EN ESPESOR  TER \ EDDS GAL (V 2011 REV 1)        ASTM A 568
# 9  CORTADOS 98% EN ESPESOR  TER \ EDDS GAL (V 2011 REV 1)        ASTM A 568
#
#   NORTOLESPESOROrigen    PLANITUDOrigen  ... DIAM__INTERNODestino  \
# 0      1/2 ASTM A 568  TERNIUM ESTANDAR  ...                  508
# 1      1/2 ASTM A 568  TERNIUM ESTANDAR  ...                  508
# 2      1/2 ASTM A 568  TERNIUM ESTANDAR  ...                  508
# 3      1/2 ASTM A 568  TERNIUM ESTANDAR  ...                  508
# 4      1/2 ASTM A 568  TERNIUM ESTANDAR  ...                  508
# 5      1/2 ASTM A 568  TERNIUM ESTANDAR  ...                  508
# 6      1/2 ASTM A 568  TERNIUM ESTANDAR  ...                  508
# 7      1/2 ASTM A 568  TERNIUM ESTANDAR  ...                  508
# 8      1/2 ASTM A 568  TERNIUM ESTANDAR  ...                  508
# 9      1/2 ASTM A 568  TERNIUM ESTANDAR  ...                  508
#
#            EXTREMOSDestino                   NORMADestino NORTOLANCHODestino  \
# 0  CORTADOS 98% EN ESPESOR  TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568
# 1  CORTADOS 98% EN ESPESOR  TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568
# 2  CORTADOS 98% EN ESPESOR  TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568
# 3  CORTADOS 98% EN ESPESOR  TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568
# 4  CORTADOS 98% EN ESPESOR  TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568
# 5  CORTADOS 98% EN ESPESOR  TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568
# 6  CORTADOS 98% EN ESPESOR  TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568
# 7  CORTADOS 98% EN ESPESOR  TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568
# 8  CORTADOS 98% EN ESPESOR  TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568
# 9  CORTADOS 98% EN ESPESOR  TER \ EDDS GAL (V 2011 REV 1)         ASTM A 568
#
#   NORTOLESPESORDestino   PLANITUDDestino SOLDADestino SUPERFICIEDestino  \
# 0       1/2 ASTM A 568  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA
# 1       1/2 ASTM A 568  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA
# 2       1/2 ASTM A 568  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA
# 3       1/2 ASTM A 568  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA
# 4       1/2 ASTM A 568  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA
# 5       1/2 ASTM A 568  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA
# 6       1/2 ASTM A 568  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA
# 7       1/2 ASTM A 568  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA
# 8       1/2 ASTM A 568  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA
# 9       1/2 ASTM A 568  TERNIUM ESTANDAR           NO     SEMI-EXPUESTA
#
#      USOGRALDestino Reasignacion
# 0  GALV. INDUSTRIAL           OK
# 1  GALV. INDUSTRIAL           OK
# 2  GALV. INDUSTRIAL           OK
# 3  GALV. INDUSTRIAL           OK
# 4  GALV. INDUSTRIAL           OK
# 5  GALV. INDUSTRIAL           OK
# 6  GALV. INDUSTRIAL           OK
# 7  GALV. INDUSTRIAL           OK
# 8  GALV. INDUSTRIAL           OK
# 9  GALV. INDUSTRIAL           OK
#
# [10 rows x 25 columns]

# %%
main_df.columns
# Out:
# Index(['ACEROOrigen', 'ACERODestino', 'ACABSUPEROrigen', 'BORDESOrigen',
#        'DIAM__INTERNOOrigen', 'EXTREMOSOrigen', 'NORMAOrigen',
#        'NORTOLANCHOOrigen', 'NORTOLESPESOROrigen', 'PLANITUDOrigen',
#        'SOLDAOrigen', 'SUPERFICIEOrigen', 'USOGRALOrigen', 'ACABSUPERDestino',
#        'BORDESDestino', 'DIAM__INTERNODestino', 'EXTREMOSDestino',
#        'NORMADestino', 'NORTOLANCHODestino', 'NORTOLESPESORDestino',
#        'PLANITUDDestino', 'SOLDADestino', 'SUPERFICIEDestino',
#        'USOGRALDestino', 'Reasignacion'],
#       dtype='object')

# %%
###codificación de variable objetivo usando LE
main_df.Reasignacion=le.fit_transform(main_df['Reasignacion'])
main_df
# Out:
#       ACEROOrigen ACERODestino ACABSUPEROrigen BORDESOrigen  \
# 0          UBCTIS       UBCIMS            MATE   LAMINACION
# 1          UBCIMS       UBCIMS            MATE   LAMINACION
# 2          UBCIMS       UBCIMS            MATE   LAMINACION
# 3          UBCIMS       UBCIMS            MATE   LAMINACION
# 4          UBCIMS       UBCIMS            MATE   LAMINACION
# ...           ...          ...             ...          ...
# 64634        7061       APM50M            MATE   LAMINACION
# 64635      ACE517       APM50M            MATE   LAMINACION
# 64636      ACE523       UBCIMS            MATE   LAMINACION
# 64637      C091TM         6066            MATE   LAMINACION
# 64638      ACE514       UBCIMS            MATE   LAMINACION
#
#        DIAM__INTERNOOrigen           EXTREMOSOrigen  \
# 0                      508  CORTADOS 98% EN ESPESOR
# 1                      508  CORTADOS 98% EN ESPESOR
# 2                      508  CORTADOS 98% EN ESPESOR
# 3                      508  CORTADOS 98% EN ESPESOR
# 4                      508  CORTADOS 98% EN ESPESOR
# ...                    ...                      ...
# 64634                  508  CORTADOS 98% EN ESPESOR
# 64635                  508  CORTADOS 98% EN ESPESOR
# 64636                  508  CORTADOS 98% EN ESPESOR
# 64637                  508  CORTADOS 98% EN ESPESOR
# 64638                  508  CORTADOS 98% EN ESPESOR
#
#                                   NORMAOrigen NORTOLANCHOOrigen  \
# 0               TER \ EDDS GAL (V 2011 REV 1)        ASTM A 568
# 1               TER \ EDDS GAL (V 2011 REV 1)        ASTM A 568
# 2               TER \ EDDS GAL (V 2011 REV 1)        ASTM A 568
# 3               TER \ EDDS GAL (V 2011 REV 1)        ASTM A 568
# 4               TER \ EDDS GAL (V 2011 REV 1)        ASTM A 568
# ...                                       ...               ...
# 64634           TER \ 1006 GAL (V 2011 REV 1)        ASTM A 568
# 64635           TER \ 50LCTGLV (V 2011 REV 1)        ASTM A 568
# 64636   TER \ EDDS IFTIS \ GAL (V 2016 REV 1)        ASTM A 568
# 64637       TER \ GA040 GAL SS (V 2011 REV 1)        ASTM A 568
# 64638  TER \ GMW2MSTS EDDS GAL (V 2012 REV 1)        ASTM A 568
#
#       NORTOLESPESOROrigen    PLANITUDOrigen  ... DIAM__INTERNODestino  \
# 0          1/2 ASTM A 568  TERNIUM ESTANDAR  ...                  508
# 1          1/2 ASTM A 568  TERNIUM ESTANDAR  ...                  508
# 2          1/2 ASTM A 568  TERNIUM ESTANDAR  ...                  508
# 3          1/2 ASTM A 568  TERNIUM ESTANDAR  ...                  508
# 4          1/2 ASTM A 568  TERNIUM ESTANDAR  ...                  508
# ...                   ...               ...  ...                  ...
# 64634      1/2 ASTM A 568  TERNIUM ESTANDAR  ...                  508
# 64635      1/2 ASTM A 568  TERNIUM ESTANDAR  ...                  508
# 64636      1/2 ASTM A 568  TERNIUM ESTANDAR  ...                  508
# 64637      1/2 ASTM A 568  TERNIUM ESTANDAR  ...                  508
# 64638        GM_W3224_LAF  TERNIUM ESTANDAR  ...                  508
#
#                EXTREMOSDestino                    NORMADestino  \
# 0      CORTADOS 98% EN ESPESOR   TER \ EDDS GAL (V 2011 REV 1)
# 1      CORTADOS 98% EN ESPESOR   TER \ EDDS GAL (V 2011 REV 1)
# 2      CORTADOS 98% EN ESPESOR   TER \ EDDS GAL (V 2011 REV 1)
# 3      CORTADOS 98% EN ESPESOR   TER \ EDDS GAL (V 2011 REV 1)
# 4      CORTADOS 98% EN ESPESOR   TER \ EDDS GAL (V 2011 REV 1)
# ...                        ...                             ...
# 64634  CORTADOS 98% EN ESPESOR  TER \ GA050 GAL (V 2011 REV 1)
# 64635  CORTADOS 98% EN ESPESOR  TER \ GA050 GAL (V 2011 REV 1)
# 64636  CORTADOS 98% EN ESPESOR   TER \ EDDS GAL (V 2011 REV 1)
# 64637  CORTADOS 98% EN ESPESOR   TER \ 1006 GAL (V 2011 REV 1)
# 64638  CORTADOS 98% EN ESPESOR   TER \ EDDS GAL (V 2011 REV 1)
#
#       NORTOLANCHODestino NORTOLESPESORDestino   PLANITUDDestino SOLDADestino  \
# 0             ASTM A 568       1/2 ASTM A 568  TERNIUM ESTANDAR           NO
# 1             ASTM A 568       1/2 ASTM A 568  TERNIUM ESTANDAR           NO
# 2             ASTM A 568       1/2 ASTM A 568  TERNIUM ESTANDAR           NO
# 3             ASTM A 568       1/2 ASTM A 568  TERNIUM ESTANDAR           NO
# 4             ASTM A 568       1/2 ASTM A 568  TERNIUM ESTANDAR           NO
# ...                  ...                  ...               ...          ...
# 64634         ASTM A 568       1/2 ASTM A 568  TERNIUM ESTANDAR           NO
# 64635         ASTM A 568       1/2 ASTM A 568  TERNIUM ESTANDAR           NO
# 64636         ASTM A 568       1/2 ASTM A 568  TERNIUM ESTANDAR           NO
# 64637    TER \ COMERCIAL       1/2 ASTM A 568  TERNIUM ESTANDAR           NO
# 64638         ASTM A 568       1/2 ASTM A 568  TERNIUM ESTANDAR           NO
#
#       SUPERFICIEDestino    USOGRALDestino Reasignacion
# 0         SEMI-EXPUESTA  GALV. INDUSTRIAL            0
# 1         SEMI-EXPUESTA  GALV. INDUSTRIAL            0
# 2         SEMI-EXPUESTA  GALV. INDUSTRIAL            0
# 3         SEMI-EXPUESTA  GALV. INDUSTRIAL            0
# 4         SEMI-EXPUESTA  GALV. INDUSTRIAL            0
# ...                 ...               ...          ...
# 64634     SEMI-EXPUESTA       GALVANIZADO            1
# 64635     SEMI-EXPUESTA       GALVANIZADO            1
# 64636     SEMI-EXPUESTA  GALV. INDUSTRIAL            1
# 64637     SEMI-EXPUESTA       GALVANIZADO            1
# 64638     SEMI-EXPUESTA  GALV. INDUSTRIAL            1
#
# [64639 rows x 25 columns]

# %%
###Variable objetivo
target_df = pd.DataFrame(main_df, columns=['Reasignacion'])
print(target_df.sample(10))
# Out:
#        Reasignacion
# 32637             0
# 42896             0
# 6324              0
# 32268             0
# 53001             0
# 13224             0
# 54318             0
# 24522             0
# 57136             0
# 39530             0

# %%
main_df=main_df.drop(['Reasignacion'],axis=1)

# %%
####encodifiación de atributos usando target
main_df.columns = main_df.columns.str.strip()
target_df.columns = target_df.columns.str.strip()
enc=category_encoders.target_encoder.TargetEncoder(verbose=0,cols=['ACEROOrigen', 'ACERODestino', 'ACABSUPEROrigen', 'BORDESOrigen',
       'DIAM__INTERNOOrigen', 'EXTREMOSOrigen', 'NORMAOrigen',
       'NORTOLANCHOOrigen', 'NORTOLESPESOROrigen', 'PLANITUDOrigen',
       'SOLDAOrigen', 'SUPERFICIEOrigen', 'USOGRALOrigen', 'ACABSUPERDestino',
       'BORDESDestino', 'DIAM__INTERNODestino', 'EXTREMOSDestino',
       'NORMADestino', 'NORTOLANCHODestino', 'NORTOLESPESORDestino',
       'PLANITUDDestino', 'SOLDADestino', 'SUPERFICIEDestino',
       'USOGRALDestino'],drop_invariant=False, return_df=True, handle_unknown='value',handle_missing='value',min_samples_leaf=1,smoothing=1.0).fit(main_df,target_df)

# %%
joblib.dump(enc,'TargetFríoCru.pkl')
# Out:
# ['TargetFríoCru.pkl']

# %%
codi=enc.transform(main_df)
codi
# Out:
#        ACEROOrigen  ACERODestino  ACABSUPEROrigen  BORDESOrigen  \
# 0         0.099305      0.027823         0.045514      0.045514
# 1         0.110690      0.027823         0.045514      0.045514
# 2         0.110690      0.027823         0.045514      0.045514
# 3         0.110690      0.027823         0.045514      0.045514
# 4         0.110690      0.027823         0.045514      0.045514
# ...            ...           ...              ...           ...
# 64634     0.022147      0.072250         0.045514      0.045514
# 64635     0.400000      0.072250         0.045514      0.045514
# 64636     0.112871      0.027823         0.045514      0.045514
# 64637     0.531250      0.047949         0.045514      0.045514
# 64638     0.166667      0.027823         0.045514      0.045514
#
#        DIAM__INTERNOOrigen  EXTREMOSOrigen  NORMAOrigen  NORTOLANCHOOrigen  \
# 0                 0.046988        0.045514     0.079080           0.049928
# 1                 0.046988        0.045514     0.079080           0.049928
# 2                 0.046988        0.045514     0.079080           0.049928
# 3                 0.046988        0.045514     0.079080           0.049928
# 4                 0.046988        0.045514     0.079080           0.049928
# ...                    ...             ...          ...                ...
# 64634             0.046988        0.045514     0.016884           0.049928
# 64635             0.046988        0.045514     0.095238           0.049928
# 64636             0.046988        0.045514     0.353933           0.049928
# 64637             0.046988        0.045514     0.338403           0.049928
# 64638             0.046988        0.045514     0.111227           0.049928
#
#        NORTOLESPESOROrigen  PLANITUDOrigen  ...  BORDESDestino  \
# 0                 0.045636        0.045514  ...       0.045514
# 1                 0.045636        0.045514  ...       0.045514
# 2                 0.045636        0.045514  ...       0.045514
# 3                 0.045636        0.045514  ...       0.045514
# 4                 0.045636        0.045514  ...       0.045514
# ...                    ...             ...  ...            ...
# 64634             0.045636        0.045514  ...       0.045514
# 64635             0.045636        0.045514  ...       0.045514
# 64636             0.045636        0.045514  ...       0.045514
# 64637             0.045636        0.045514  ...       0.045514
# 64638             0.113383        0.045514  ...       0.045514
#
#        DIAM__INTERNODestino  EXTREMOSDestino  NORMADestino  \
# 0                  0.047553         0.045514      0.094495
# 1                  0.047553         0.045514      0.094495
# 2                  0.047553         0.045514      0.094495
# 3                  0.047553         0.045514      0.094495
# 4                  0.047553         0.045514      0.094495
# ...                     ...              ...           ...
# 64634              0.047553         0.045514      0.064458
# 64635              0.047553         0.045514      0.064458
# 64636              0.047553         0.045514      0.094495
# 64637              0.047553         0.045514      0.040125
# 64638              0.047553         0.045514      0.094495
#
#        NORTOLANCHODestino  NORTOLESPESORDestino  PLANITUDDestino  \
# 0                0.048494              0.046595         0.045514
# 1                0.048494              0.046595         0.045514
# 2                0.048494              0.046595         0.045514
# 3                0.048494              0.046595         0.045514
# 4                0.048494              0.046595         0.045514
# ...                   ...                   ...              ...
# 64634            0.048494              0.046595         0.045514
# 64635            0.048494              0.046595         0.045514
# 64636            0.048494              0.046595         0.045514
# 64637            0.041673              0.046595         0.045514
# 64638            0.048494              0.046595         0.045514
#
#        SOLDADestino  SUPERFICIEDestino  USOGRALDestino
# 0          0.045514            0.04257        0.057276
# 1          0.045514            0.04257        0.057276
# 2          0.045514            0.04257        0.057276
# 3          0.045514            0.04257        0.057276
# 4          0.045514            0.04257        0.057276
# ...             ...                ...             ...
# 64634      0.045514            0.04257        0.041447
# 64635      0.045514            0.04257        0.041447
# 64636      0.045514            0.04257        0.057276
# 64637      0.045514            0.04257        0.041447
# 64638      0.045514            0.04257        0.057276
#
# [64639 rows x 24 columns]

# %%
###declaración de variable x (atributos)
X=codi
X
# Out:
#        ACEROOrigen  ACERODestino  ACABSUPEROrigen  BORDESOrigen  \
# 0         0.099305      0.027823         0.045514      0.045514
# 1         0.110690      0.027823         0.045514      0.045514
# 2         0.110690      0.027823         0.045514      0.045514
# 3         0.110690      0.027823         0.045514      0.045514
# 4         0.110690      0.027823         0.045514      0.045514
# ...            ...           ...              ...           ...
# 64634     0.022147      0.072250         0.045514      0.045514
# 64635     0.400000      0.072250         0.045514      0.045514
# 64636     0.112871      0.027823         0.045514      0.045514
# 64637     0.531250      0.047949         0.045514      0.045514
# 64638     0.166667      0.027823         0.045514      0.045514
#
#        DIAM__INTERNOOrigen  EXTREMOSOrigen  NORMAOrigen  NORTOLANCHOOrigen  \
# 0                 0.046988        0.045514     0.079080           0.049928
# 1                 0.046988        0.045514     0.079080           0.049928
# 2                 0.046988        0.045514     0.079080           0.049928
# 3                 0.046988        0.045514     0.079080           0.049928
# 4                 0.046988        0.045514     0.079080           0.049928
# ...                    ...             ...          ...                ...
# 64634             0.046988        0.045514     0.016884           0.049928
# 64635             0.046988        0.045514     0.095238           0.049928
# 64636             0.046988        0.045514     0.353933           0.049928
# 64637             0.046988        0.045514     0.338403           0.049928
# 64638             0.046988        0.045514     0.111227           0.049928
#
#        NORTOLESPESOROrigen  PLANITUDOrigen  ...  BORDESDestino  \
# 0                 0.045636        0.045514  ...       0.045514
# 1                 0.045636        0.045514  ...       0.045514
# 2                 0.045636        0.045514  ...       0.045514
# 3                 0.045636        0.045514  ...       0.045514
# 4                 0.045636        0.045514  ...       0.045514
# ...                    ...             ...  ...            ...
# 64634             0.045636        0.045514  ...       0.045514
# 64635             0.045636        0.045514  ...       0.045514
# 64636             0.045636        0.045514  ...       0.045514
# 64637             0.045636        0.045514  ...       0.045514
# 64638             0.113383        0.045514  ...       0.045514
#
#        DIAM__INTERNODestino  EXTREMOSDestino  NORMADestino  \
# 0                  0.047553         0.045514      0.094495
# 1                  0.047553         0.045514      0.094495
# 2                  0.047553         0.045514      0.094495
# 3                  0.047553         0.045514      0.094495
# 4                  0.047553         0.045514      0.094495
# ...                     ...              ...           ...
# 64634              0.047553         0.045514      0.064458
# 64635              0.047553         0.045514      0.064458
# 64636              0.047553         0.045514      0.094495
# 64637              0.047553         0.045514      0.040125
# 64638              0.047553         0.045514      0.094495
#
#        NORTOLANCHODestino  NORTOLESPESORDestino  PLANITUDDestino  \
# 0                0.048494              0.046595         0.045514
# 1                0.048494              0.046595         0.045514
# 2                0.048494              0.046595         0.045514
# 3                0.048494              0.046595         0.045514
# 4                0.048494              0.046595         0.045514
# ...                   ...                   ...              ...
# 64634            0.048494              0.046595         0.045514
# 64635            0.048494              0.046595         0.045514
# 64636            0.048494              0.046595         0.045514
# 64637            0.041673              0.046595         0.045514
# 64638            0.048494              0.046595         0.045514
#
#        SOLDADestino  SUPERFICIEDestino  USOGRALDestino
# 0          0.045514            0.04257        0.057276
# 1          0.045514            0.04257        0.057276
# 2          0.045514            0.04257        0.057276
# 3          0.045514            0.04257        0.057276
# 4          0.045514            0.04257        0.057276
# ...             ...                ...             ...
# 64634      0.045514            0.04257        0.041447
# 64635      0.045514            0.04257        0.041447
# 64636      0.045514            0.04257        0.057276
# 64637      0.045514            0.04257        0.041447
# 64638      0.045514            0.04257        0.057276
#
# [64639 rows x 24 columns]

# %%
###declaración de y (objetivo)
y=target_df
y
# Out:
#        Reasignacion
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 64634             1
# 64635             1
# 64636             1
# 64637             1
# 64638             1
#
# [64639 rows x 1 columns]

# %%
##división de datos 
X_train,X_test,y_train,y_test=train_test_split(X,y)

# %%
##entrenamiento
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
###prueba score
dt.score(X_test,y_test)
# Out:
# 0.9675742574257425

# %%
joblib.dump(dt,'ModeloFríoCru.pkl')
# Out:
# ['ModeloFríoCru.pkl']

# %%
nombres=['OK','RECHAZADO']

# %%
##exportación y render
dot_data=export_graphviz(dt,feature_names= X.columns, class_names=nombres, impurity=False, filled=True)
graph=graphviz.Source(dot_data)
graph.render('ModeloFríoCru')
# Out:
# 'ModeloFríoCru.pdf'
