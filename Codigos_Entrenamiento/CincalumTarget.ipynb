# %%
###importaciones
import pandas as pd
import numpy as np
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import category_encoders
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import LabelEncoder 
from sklearn.tree import DecisionTreeClassifier
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.tree import export_graphviz
import graphviz
import joblib

# %%
##lectura del csv y objetos a usar
data=pd.read_csv('Cincalum.csv')
le=LabelEncoder()
dt=DecisionTreeClassifier()
data
# Out:
#         Estatus           FECHA_ALTA     IdMaterial  NECESIDAD_ORIGEN  \
# 0     Rechazado  16-10-2017 15:58:27  3A689963JG303        2000692047
# 1     Rechazado  16-10-2017 15:59:28  3A689961JG303        2000692047
# 2     Rechazado  16-10-2017 15:59:48  3A689961JG301        2000692047
# 3     Rechazado  16-10-2017 16:00:00  3A689961JG300        2000692047
# 4     Rechazado  16-10-2017 15:58:17  3A689963JG304        2000692047
# ...         ...                  ...            ...               ...
# 4438         OK  19-10-2017 18:27:35  3A581208JG302        3001442447
# 4439         OK  19-10-2017 18:25:28  3A581208JG304        3001442447
# 4440         OK  19-10-2017 18:27:34  3A581208JG302        3001442447
# 4441         OK  28-09-2017 03:29:52  3A615828JC300        1000848902
# 4442         OK  19-10-2017 18:25:39  3A581208JG303        3001442447
#
#       NECESIDAD_DESTINO PRO_ORIGEN PRO_DESTINO  CCLASEPRODTOOrigen  \
# 0            2000696207   MP517148    MP517137  M-P-CINCALUM-BOB-_
# 1            2000696207   MP517148    MP517137  M-P-CINCALUM-BOB-_
# 2            2000696207   MP517148    MP517137  M-P-CINCALUM-BOB-_
# 3            2000696207   MP517148    MP517137  M-P-CINCALUM-BOB-_
# 4            2000696207   MP517148    MP517137  M-P-CINCALUM-BOB-_
# ...                 ...        ...         ...                 ...
# 4438         1000968206   MP523221    MP523221  M-P-CINCALUM-BOB-_
# 4439         1000942158   MP523221    MP523221  M-P-CINCALUM-BOB-_
# 4440         1000968206   MP523221    MP523221  M-P-CINCALUM-BOB-_
# 4441         1000950333   MP523221    MP523221  M-P-CINCALUM-BOB-_
# 4442         1000942158   MP523221    MP523221  M-P-CINCALUM-BOB-_
#
#      ACEROOrigen ACABSUPERFRECOrigen  ... NORTOLESPESORDestino  \
# 0         C071TM                MATE  ...      TERNIUM CALIBRE
# 1         C071TM                MATE  ...      TERNIUM CALIBRE
# 2         C071TM                MATE  ...      TERNIUM CALIBRE
# 3         C071TM                MATE  ...      TERNIUM CALIBRE
# 4         C071TM                MATE  ...      TERNIUM CALIBRE
# ...          ...                 ...  ...                  ...
# 4438      C121TM                MATE  ...       1/2 ASTM A 924
# 4439      C121TM                MATE  ...       1/2 ASTM A 924
# 4440      C121TM                MATE  ...       1/2 ASTM A 924
# 4441      C121TM                MATE  ...       1/2 ASTM A 924
# 4442      C121TM                MATE  ...       1/2 ASTM A 924
#
#             PLANITUDDestino RECUBRIMIENTODestino  SELLODestino  \
# 0     NIVEL 3 / 29 UI / 4MM                 AZ50            NO
# 1     NIVEL 3 / 29 UI / 4MM                 AZ50            NO
# 2     NIVEL 3 / 29 UI / 4MM                 AZ50            NO
# 3     NIVEL 3 / 29 UI / 4MM                 AZ50            NO
# 4     NIVEL 3 / 29 UI / 4MM                 AZ50            NO
# ...                     ...                  ...           ...
# 4438  NIVEL 3 / 29 UI / 4MM                 AZ55            NO
# 4439  NIVEL 3 / 29 UI / 4MM                 AZ55            NO
# 4440  NIVEL 3 / 29 UI / 4MM                 AZ55            NO
# 4441  NIVEL 3 / 29 UI / 4MM                 AZ55            NO
# 4442  NIVEL 3 / 29 UI / 4MM                 AZ55            NO
#
#      SUPERFICIEDestino TAMFLORDestino          TRATSUPERFDestino  \
# 0              INTERNA        REGULAR                   PASIVADO
# 1              INTERNA        REGULAR                   PASIVADO
# 2              INTERNA        REGULAR                   PASIVADO
# 3              INTERNA        REGULAR                   PASIVADO
# 4              INTERNA        REGULAR                   PASIVADO
# ...                ...            ...                        ...
# 4438     SEMI-EXPUESTA        REGULAR  PASIVADO ACRILICO ROOFING
# 4439     SEMI-EXPUESTA        REGULAR  PASIVADO ACRILICO ROOFING
# 4440     SEMI-EXPUESTA        REGULAR  PASIVADO ACRILICO ROOFING
# 4441     SEMI-EXPUESTA        REGULAR  PASIVADO ACRILICO ROOFING
# 4442     SEMI-EXPUESTA        REGULAR  PASIVADO ACRILICO ROOFING
#
#                 USOGRALDestino Reasignacion Pedido
# 0     COMERCIAL Y CONSTRUCCION           OK      1
# 1     COMERCIAL Y CONSTRUCCION           OK      1
# 2     COMERCIAL Y CONSTRUCCION           OK      1
# 3     COMERCIAL Y CONSTRUCCION           OK      1
# 4     COMERCIAL Y CONSTRUCCION           OK      1
# ...                        ...          ...    ...
# 4438  COMERCIAL Y CONSTRUCCION           OK      1
# 4439  COMERCIAL Y CONSTRUCCION           OK      1
# 4440  COMERCIAL Y CONSTRUCCION           OK      1
# 4441  COMERCIAL Y CONSTRUCCION           OK      1
# 4442  COMERCIAL Y CONSTRUCCION           OK      1
#
# [4443 rows x 47 columns]

# %%
###limpieza de datos
de=['Estatus', 'FECHA_ALTA', 'IdMaterial', 'NECESIDAD_ORIGEN','NECESIDAD_DESTINO', 'PRO_ORIGEN', 'PRO_DESTINO', 'Pedido','ACEROOrigen','ACERODestino']
datac=data.drop(de,axis=1)
datac
# Out:
#       CCLASEPRODTOOrigen ACABSUPERFRECOrigen ACEITADOOrigen BORDESOrigen  \
# 0     M-P-CINCALUM-BOB-_                MATE             NO   LAMINACION
# 1     M-P-CINCALUM-BOB-_                MATE             NO   LAMINACION
# 2     M-P-CINCALUM-BOB-_                MATE             NO   LAMINACION
# 3     M-P-CINCALUM-BOB-_                MATE             NO   LAMINACION
# 4     M-P-CINCALUM-BOB-_                MATE             NO   LAMINACION
# ...                  ...                 ...            ...          ...
# 4438  M-P-CINCALUM-BOB-_                MATE             NO   LAMINACION
# 4439  M-P-CINCALUM-BOB-_                MATE             NO   LAMINACION
# 4440  M-P-CINCALUM-BOB-_                MATE             NO   LAMINACION
# 4441  M-P-CINCALUM-BOB-_                MATE             NO   LAMINACION
# 4442  M-P-CINCALUM-BOB-_                MATE             NO   LAMINACION
#
#      CARAINSPECCIONOrigen  DIAM__INTERNOOrigen           EXTREMOSOrigen  \
# 0                SUPERIOR                  508  CORTADOS 98% EN ESPESOR
# 1                SUPERIOR                  508  CORTADOS 98% EN ESPESOR
# 2                SUPERIOR                  508  CORTADOS 98% EN ESPESOR
# 3                SUPERIOR                  508  CORTADOS 98% EN ESPESOR
# 4                SUPERIOR                  508  CORTADOS 98% EN ESPESOR
# ...                   ...                  ...                      ...
# 4438             SUPERIOR                  508  CORTADOS 98% EN ESPESOR
# 4439             SUPERIOR                  508  CORTADOS 98% EN ESPESOR
# 4440             SUPERIOR                  508  CORTADOS 98% EN ESPESOR
# 4441             SUPERIOR                  508  CORTADOS 98% EN ESPESOR
# 4442             SUPERIOR                  508  CORTADOS 98% EN ESPESOR
#
#                                     NORMAOrigen NORRECUBRIMIENOrigen  \
# 0             ASTM A 792 \ SS 33 (V 2008 REV 0)           ASTM A 792
# 1             ASTM A 792 \ SS 33 (V 2008 REV 0)           ASTM A 792
# 2             ASTM A 792 \ SS 33 (V 2008 REV 0)           ASTM A 792
# 3             ASTM A 792 \ SS 33 (V 2008 REV 0)           ASTM A 792
# 4             ASTM A 792 \ SS 33 (V 2008 REV 0)           ASTM A 792
# ...                                         ...                  ...
# 4438  ASTM A 792 \ SS 50 CLASE 2 (V 2008 REV 0)           ASTM A 792
# 4439  ASTM A 792 \ SS 50 CLASE 2 (V 2008 REV 0)           ASTM A 792
# 4440  ASTM A 792 \ SS 50 CLASE 2 (V 2008 REV 0)           ASTM A 792
# 4441  ASTM A 792 \ SS 50 CLASE 2 (V 2008 REV 0)           ASTM A 792
# 4442  ASTM A 792 \ SS 50 CLASE 2 (V 2008 REV 0)           ASTM A 792
#
#      NORTOLANCHOOrigen  ... NORTOLANCHODestino NORTOLESPESORDestino  \
# 0           ASTM A 924  ...         ASTM A 924      TERNIUM CALIBRE
# 1           ASTM A 924  ...         ASTM A 924      TERNIUM CALIBRE
# 2           ASTM A 924  ...         ASTM A 924      TERNIUM CALIBRE
# 3           ASTM A 924  ...         ASTM A 924      TERNIUM CALIBRE
# 4           ASTM A 924  ...         ASTM A 924      TERNIUM CALIBRE
# ...                ...  ...                ...                  ...
# 4438        ASTM A 924  ...         ASTM A 924       1/2 ASTM A 924
# 4439        ASTM A 924  ...         ASTM A 924       1/2 ASTM A 924
# 4440        ASTM A 924  ...         ASTM A 924       1/2 ASTM A 924
# 4441        ASTM A 924  ...         ASTM A 924       1/2 ASTM A 924
# 4442        ASTM A 924  ...         ASTM A 924       1/2 ASTM A 924
#
#             PLANITUDDestino RECUBRIMIENTODestino SELLODestino  \
# 0     NIVEL 3 / 29 UI / 4MM                 AZ50           NO
# 1     NIVEL 3 / 29 UI / 4MM                 AZ50           NO
# 2     NIVEL 3 / 29 UI / 4MM                 AZ50           NO
# 3     NIVEL 3 / 29 UI / 4MM                 AZ50           NO
# 4     NIVEL 3 / 29 UI / 4MM                 AZ50           NO
# ...                     ...                  ...          ...
# 4438  NIVEL 3 / 29 UI / 4MM                 AZ55           NO
# 4439  NIVEL 3 / 29 UI / 4MM                 AZ55           NO
# 4440  NIVEL 3 / 29 UI / 4MM                 AZ55           NO
# 4441  NIVEL 3 / 29 UI / 4MM                 AZ55           NO
# 4442  NIVEL 3 / 29 UI / 4MM                 AZ55           NO
#
#      SUPERFICIEDestino TAMFLORDestino          TRATSUPERFDestino  \
# 0              INTERNA        REGULAR                   PASIVADO
# 1              INTERNA        REGULAR                   PASIVADO
# 2              INTERNA        REGULAR                   PASIVADO
# 3              INTERNA        REGULAR                   PASIVADO
# 4              INTERNA        REGULAR                   PASIVADO
# ...                ...            ...                        ...
# 4438     SEMI-EXPUESTA        REGULAR  PASIVADO ACRILICO ROOFING
# 4439     SEMI-EXPUESTA        REGULAR  PASIVADO ACRILICO ROOFING
# 4440     SEMI-EXPUESTA        REGULAR  PASIVADO ACRILICO ROOFING
# 4441     SEMI-EXPUESTA        REGULAR  PASIVADO ACRILICO ROOFING
# 4442     SEMI-EXPUESTA        REGULAR  PASIVADO ACRILICO ROOFING
#
#                 USOGRALDestino Reasignacion
# 0     COMERCIAL Y CONSTRUCCION           OK
# 1     COMERCIAL Y CONSTRUCCION           OK
# 2     COMERCIAL Y CONSTRUCCION           OK
# 3     COMERCIAL Y CONSTRUCCION           OK
# 4     COMERCIAL Y CONSTRUCCION           OK
# ...                        ...          ...
# 4438  COMERCIAL Y CONSTRUCCION           OK
# 4439  COMERCIAL Y CONSTRUCCION           OK
# 4440  COMERCIAL Y CONSTRUCCION           OK
# 4441  COMERCIAL Y CONSTRUCCION           OK
# 4442  COMERCIAL Y CONSTRUCCION           OK
#
# [4443 rows x 37 columns]

# %%
main_df=datac
main_df=pd.DataFrame(data=main_df)
full_df=datac
full_df=pd.DataFrame(data=full_df)
print(full_df.head(10))
# Out:
#    CCLASEPRODTOOrigen ACABSUPERFRECOrigen ACEITADOOrigen BORDESOrigen  \
# 0  M-P-CINCALUM-BOB-_                MATE             NO   LAMINACION
# 1  M-P-CINCALUM-BOB-_                MATE             NO   LAMINACION
# 2  M-P-CINCALUM-BOB-_                MATE             NO   LAMINACION
# 3  M-P-CINCALUM-BOB-_                MATE             NO   LAMINACION
# 4  M-P-CINCALUM-BOB-_                MATE             NO   LAMINACION
# 5  M-P-CINCALUM-BOB-_                MATE             NO   LAMINACION
# 6  M-P-CINCALUM-BOB-_                MATE             NO   LAMINACION
# 7  M-P-CINCALUM-BOB-_                MATE             NO   LAMINACION
# 8  M-P-CINCALUM-BOB-_                MATE             NO   LAMINACION
# 9  M-P-CINCALUM-BOB-_                MATE             NO   LAMINACION
#
#   CARAINSPECCIONOrigen  DIAM__INTERNOOrigen           EXTREMOSOrigen  \
# 0             SUPERIOR                  508  CORTADOS 98% EN ESPESOR
# 1             SUPERIOR                  508  CORTADOS 98% EN ESPESOR
# 2             SUPERIOR                  508  CORTADOS 98% EN ESPESOR
# 3             SUPERIOR                  508  CORTADOS 98% EN ESPESOR
# 4             SUPERIOR                  508  CORTADOS 98% EN ESPESOR
# 5             SUPERIOR                  508  CORTADOS 98% EN ESPESOR
# 6             SUPERIOR                  508  CORTADOS 98% EN ESPESOR
# 7             SUPERIOR                  508  CORTADOS 98% EN ESPESOR
# 8             SUPERIOR                  508  CORTADOS 98% EN ESPESOR
# 9             SUPERIOR                  508  CORTADOS 98% EN ESPESOR
#
#                          NORMAOrigen NORRECUBRIMIENOrigen NORTOLANCHOOrigen  \
# 0  ASTM A 792 \ SS 33 (V 2008 REV 0)           ASTM A 792        ASTM A 924
# 1  ASTM A 792 \ SS 33 (V 2008 REV 0)           ASTM A 792        ASTM A 924
# 2  ASTM A 792 \ SS 33 (V 2008 REV 0)           ASTM A 792        ASTM A 924
# 3  ASTM A 792 \ SS 33 (V 2008 REV 0)           ASTM A 792        ASTM A 924
# 4  ASTM A 792 \ SS 33 (V 2008 REV 0)           ASTM A 792        ASTM A 924
# 5  ASTM A 792 \ SS 33 (V 2008 REV 0)           ASTM A 792        ASTM A 924
# 6  ASTM A 792 \ SS 33 (V 2008 REV 0)           ASTM A 792        ASTM A 924
# 7  ASTM A 792 \ SS 33 (V 2008 REV 0)           ASTM A 792        ASTM A 924
# 8  ASTM A 792 \ SS 33 (V 2008 REV 0)           ASTM A 792        ASTM A 924
# 9  ASTM A 792 \ SS 33 (V 2008 REV 0)           ASTM A 792        ASTM A 924
#
#    ... NORTOLANCHODestino NORTOLESPESORDestino        PLANITUDDestino  \
# 0  ...         ASTM A 924      TERNIUM CALIBRE  NIVEL 3 / 29 UI / 4MM
# 1  ...         ASTM A 924      TERNIUM CALIBRE  NIVEL 3 / 29 UI / 4MM
# 2  ...         ASTM A 924      TERNIUM CALIBRE  NIVEL 3 / 29 UI / 4MM
# 3  ...         ASTM A 924      TERNIUM CALIBRE  NIVEL 3 / 29 UI / 4MM
# 4  ...         ASTM A 924      TERNIUM CALIBRE  NIVEL 3 / 29 UI / 4MM
# 5  ...         ASTM A 924      TERNIUM CALIBRE  NIVEL 3 / 29 UI / 4MM
# 6  ...         ASTM A 924      TERNIUM CALIBRE  NIVEL 3 / 29 UI / 4MM
# 7  ...         ASTM A 924      TERNIUM CALIBRE  NIVEL 3 / 29 UI / 4MM
# 8  ...         ASTM A 924      TERNIUM CALIBRE  NIVEL 3 / 29 UI / 4MM
# 9  ...         ASTM A 924      TERNIUM CALIBRE  NIVEL 3 / 29 UI / 4MM
#
#   RECUBRIMIENTODestino SELLODestino SUPERFICIEDestino TAMFLORDestino  \
# 0                 AZ50           NO           INTERNA        REGULAR
# 1                 AZ50           NO           INTERNA        REGULAR
# 2                 AZ50           NO           INTERNA        REGULAR
# 3                 AZ50           NO           INTERNA        REGULAR
# 4                 AZ50           NO           INTERNA        REGULAR
# 5                 AZ50           NO           INTERNA        REGULAR
# 6                 AZ50           NO           INTERNA        REGULAR
# 7                 AZ50           NO           INTERNA        REGULAR
# 8                 AZ50           NO           INTERNA        REGULAR
# 9                 AZ50           NO           INTERNA        REGULAR
#
#   TRATSUPERFDestino            USOGRALDestino Reasignacion
# 0          PASIVADO  COMERCIAL Y CONSTRUCCION           OK
# 1          PASIVADO  COMERCIAL Y CONSTRUCCION           OK
# 2          PASIVADO  COMERCIAL Y CONSTRUCCION           OK
# 3          PASIVADO  COMERCIAL Y CONSTRUCCION           OK
# 4          PASIVADO  COMERCIAL Y CONSTRUCCION           OK
# 5          PASIVADO  COMERCIAL Y CONSTRUCCION           OK
# 6          PASIVADO  COMERCIAL Y CONSTRUCCION           OK
# 7          PASIVADO  COMERCIAL Y CONSTRUCCION           OK
# 8          PASIVADO  COMERCIAL Y CONSTRUCCION           OK
# 9          PASIVADO  COMERCIAL Y CONSTRUCCION           OK
#
# [10 rows x 37 columns]

# %%
main_df.columns
# Out:
# Index(['CCLASEPRODTOOrigen', 'ACABSUPERFRECOrigen', 'ACEITADOOrigen',
#        'BORDESOrigen', 'CARAINSPECCIONOrigen', 'DIAM__INTERNOOrigen',
#        'EXTREMOSOrigen', 'NORMAOrigen', 'NORRECUBRIMIENOrigen',
#        'NORTOLANCHOOrigen', 'NORTOLESPESOROrigen', 'PLANITUDOrigen',
#        'RECUBRIMIENTOOrigen', 'SELLOOrigen', 'SUPERFICIEOrigen',
#        'TAMFLOROrigen', 'TRATSUPERFOrigen', 'USOGRALOrigen',
#        'CCLASEPRODTODestino', 'ACABSUPERFRECDestino', 'ACEITADODestino',
#        'BORDESDestino', 'CARAINSPECCIONDestino', 'DIAM__INTERNODestino',
#        'EXTREMOSDestino', 'NORMADestino', 'NORRECUBRIMIENDestino',
#        'NORTOLANCHODestino', 'NORTOLESPESORDestino', 'PLANITUDDestino',
#        'RECUBRIMIENTODestino', 'SELLODestino', 'SUPERFICIEDestino',
#        'TAMFLORDestino', 'TRATSUPERFDestino', 'USOGRALDestino',
#        'Reasignacion'],
#       dtype='object')

# %%
###codificación de variable objetivo usando LE
main_df.Reasignacion=le.fit_transform(main_df['Reasignacion'])
main_df
# Out:
#       CCLASEPRODTOOrigen ACABSUPERFRECOrigen ACEITADOOrigen BORDESOrigen  \
# 0     M-P-CINCALUM-BOB-_                MATE             NO   LAMINACION
# 1     M-P-CINCALUM-BOB-_                MATE             NO   LAMINACION
# 2     M-P-CINCALUM-BOB-_                MATE             NO   LAMINACION
# 3     M-P-CINCALUM-BOB-_                MATE             NO   LAMINACION
# 4     M-P-CINCALUM-BOB-_                MATE             NO   LAMINACION
# ...                  ...                 ...            ...          ...
# 4438  M-P-CINCALUM-BOB-_                MATE             NO   LAMINACION
# 4439  M-P-CINCALUM-BOB-_                MATE             NO   LAMINACION
# 4440  M-P-CINCALUM-BOB-_                MATE             NO   LAMINACION
# 4441  M-P-CINCALUM-BOB-_                MATE             NO   LAMINACION
# 4442  M-P-CINCALUM-BOB-_                MATE             NO   LAMINACION
#
#      CARAINSPECCIONOrigen  DIAM__INTERNOOrigen           EXTREMOSOrigen  \
# 0                SUPERIOR                  508  CORTADOS 98% EN ESPESOR
# 1                SUPERIOR                  508  CORTADOS 98% EN ESPESOR
# 2                SUPERIOR                  508  CORTADOS 98% EN ESPESOR
# 3                SUPERIOR                  508  CORTADOS 98% EN ESPESOR
# 4                SUPERIOR                  508  CORTADOS 98% EN ESPESOR
# ...                   ...                  ...                      ...
# 4438             SUPERIOR                  508  CORTADOS 98% EN ESPESOR
# 4439             SUPERIOR                  508  CORTADOS 98% EN ESPESOR
# 4440             SUPERIOR                  508  CORTADOS 98% EN ESPESOR
# 4441             SUPERIOR                  508  CORTADOS 98% EN ESPESOR
# 4442             SUPERIOR                  508  CORTADOS 98% EN ESPESOR
#
#                                     NORMAOrigen NORRECUBRIMIENOrigen  \
# 0             ASTM A 792 \ SS 33 (V 2008 REV 0)           ASTM A 792
# 1             ASTM A 792 \ SS 33 (V 2008 REV 0)           ASTM A 792
# 2             ASTM A 792 \ SS 33 (V 2008 REV 0)           ASTM A 792
# 3             ASTM A 792 \ SS 33 (V 2008 REV 0)           ASTM A 792
# 4             ASTM A 792 \ SS 33 (V 2008 REV 0)           ASTM A 792
# ...                                         ...                  ...
# 4438  ASTM A 792 \ SS 50 CLASE 2 (V 2008 REV 0)           ASTM A 792
# 4439  ASTM A 792 \ SS 50 CLASE 2 (V 2008 REV 0)           ASTM A 792
# 4440  ASTM A 792 \ SS 50 CLASE 2 (V 2008 REV 0)           ASTM A 792
# 4441  ASTM A 792 \ SS 50 CLASE 2 (V 2008 REV 0)           ASTM A 792
# 4442  ASTM A 792 \ SS 50 CLASE 2 (V 2008 REV 0)           ASTM A 792
#
#      NORTOLANCHOOrigen  ... NORTOLANCHODestino NORTOLESPESORDestino  \
# 0           ASTM A 924  ...         ASTM A 924      TERNIUM CALIBRE
# 1           ASTM A 924  ...         ASTM A 924      TERNIUM CALIBRE
# 2           ASTM A 924  ...         ASTM A 924      TERNIUM CALIBRE
# 3           ASTM A 924  ...         ASTM A 924      TERNIUM CALIBRE
# 4           ASTM A 924  ...         ASTM A 924      TERNIUM CALIBRE
# ...                ...  ...                ...                  ...
# 4438        ASTM A 924  ...         ASTM A 924       1/2 ASTM A 924
# 4439        ASTM A 924  ...         ASTM A 924       1/2 ASTM A 924
# 4440        ASTM A 924  ...         ASTM A 924       1/2 ASTM A 924
# 4441        ASTM A 924  ...         ASTM A 924       1/2 ASTM A 924
# 4442        ASTM A 924  ...         ASTM A 924       1/2 ASTM A 924
#
#             PLANITUDDestino RECUBRIMIENTODestino SELLODestino  \
# 0     NIVEL 3 / 29 UI / 4MM                 AZ50           NO
# 1     NIVEL 3 / 29 UI / 4MM                 AZ50           NO
# 2     NIVEL 3 / 29 UI / 4MM                 AZ50           NO
# 3     NIVEL 3 / 29 UI / 4MM                 AZ50           NO
# 4     NIVEL 3 / 29 UI / 4MM                 AZ50           NO
# ...                     ...                  ...          ...
# 4438  NIVEL 3 / 29 UI / 4MM                 AZ55           NO
# 4439  NIVEL 3 / 29 UI / 4MM                 AZ55           NO
# 4440  NIVEL 3 / 29 UI / 4MM                 AZ55           NO
# 4441  NIVEL 3 / 29 UI / 4MM                 AZ55           NO
# 4442  NIVEL 3 / 29 UI / 4MM                 AZ55           NO
#
#      SUPERFICIEDestino TAMFLORDestino          TRATSUPERFDestino  \
# 0              INTERNA        REGULAR                   PASIVADO
# 1              INTERNA        REGULAR                   PASIVADO
# 2              INTERNA        REGULAR                   PASIVADO
# 3              INTERNA        REGULAR                   PASIVADO
# 4              INTERNA        REGULAR                   PASIVADO
# ...                ...            ...                        ...
# 4438     SEMI-EXPUESTA        REGULAR  PASIVADO ACRILICO ROOFING
# 4439     SEMI-EXPUESTA        REGULAR  PASIVADO ACRILICO ROOFING
# 4440     SEMI-EXPUESTA        REGULAR  PASIVADO ACRILICO ROOFING
# 4441     SEMI-EXPUESTA        REGULAR  PASIVADO ACRILICO ROOFING
# 4442     SEMI-EXPUESTA        REGULAR  PASIVADO ACRILICO ROOFING
#
#                 USOGRALDestino Reasignacion
# 0     COMERCIAL Y CONSTRUCCION            0
# 1     COMERCIAL Y CONSTRUCCION            0
# 2     COMERCIAL Y CONSTRUCCION            0
# 3     COMERCIAL Y CONSTRUCCION            0
# 4     COMERCIAL Y CONSTRUCCION            0
# ...                        ...          ...
# 4438  COMERCIAL Y CONSTRUCCION            0
# 4439  COMERCIAL Y CONSTRUCCION            0
# 4440  COMERCIAL Y CONSTRUCCION            0
# 4441  COMERCIAL Y CONSTRUCCION            0
# 4442  COMERCIAL Y CONSTRUCCION            0
#
# [4443 rows x 37 columns]

# %%
###Variable objetivo
target_df = pd.DataFrame(main_df, columns=['Reasignacion'])
print(target_df.sample(10))
# Out:
#       Reasignacion
# 2389             0
# 1655             0
# 2942             0
# 627              0
# 1419             0
# 4274             0
# 3456             0
# 287              1
# 1275             0
# 4400             0

# %%
main_df=main_df.drop(['Reasignacion'],axis=1)

# %%
####encodifiación de atributos usando target
main_df.columns = main_df.columns.str.strip()
target_df.columns = target_df.columns.str.strip()
enc=category_encoders.target_encoder.TargetEncoder(verbose=0,cols=['CCLASEPRODTOOrigen', 'ACABSUPERFRECOrigen',
       'ACEITADOOrigen', 'BORDESOrigen', 'CARAINSPECCIONOrigen',
       'DIAM__INTERNOOrigen', 'EXTREMOSOrigen', 'NORMAOrigen',
       'NORRECUBRIMIENOrigen', 'NORTOLANCHOOrigen', 'NORTOLESPESOROrigen',
       'PLANITUDOrigen', 'RECUBRIMIENTOOrigen', 'SELLOOrigen',
       'SUPERFICIEOrigen', 'TAMFLOROrigen', 'TRATSUPERFOrigen',
       'USOGRALOrigen', 'CCLASEPRODTODestino', 'ACABSUPERFRECDestino',
       'ACEITADODestino', 'BORDESDestino',
       'CARAINSPECCIONDestino', 'DIAM__INTERNODestino', 'EXTREMOSDestino',
       'NORMADestino', 'NORRECUBRIMIENDestino', 'NORTOLANCHODestino',
       'NORTOLESPESORDestino', 'PLANITUDDestino', 'RECUBRIMIENTODestino',
       'SELLODestino', 'SUPERFICIEDestino', 'TAMFLORDestino',
       'TRATSUPERFDestino', 'USOGRALDestino'],drop_invariant=False, return_df=True, handle_unknown='value', handle_missing='value',min_samples_leaf=1,smoothing=1.0).fit(main_df,target_df)

# %%
joblib.dump(enc,'TargetCincalum.pkl')
# Out:
# ['TargetCincalum.pkl']

# %%
codi=enc.transform(main_df)
codi
# Out:
#       CCLASEPRODTOOrigen  ACABSUPERFRECOrigen  ACEITADOOrigen  BORDESOrigen  \
# 0               0.101508             0.101508        0.101508      0.101508
# 1               0.101508             0.101508        0.101508      0.101508
# 2               0.101508             0.101508        0.101508      0.101508
# 3               0.101508             0.101508        0.101508      0.101508
# 4               0.101508             0.101508        0.101508      0.101508
# ...                  ...                  ...             ...           ...
# 4438            0.101508             0.101508        0.101508      0.101508
# 4439            0.101508             0.101508        0.101508      0.101508
# 4440            0.101508             0.101508        0.101508      0.101508
# 4441            0.101508             0.101508        0.101508      0.101508
# 4442            0.101508             0.101508        0.101508      0.101508
#
#       CARAINSPECCIONOrigen  DIAM__INTERNOOrigen  EXTREMOSOrigen   NORMAOrigen  \
# 0                 0.101508             0.101508        0.101508  3.119869e-02
# 1                 0.101508             0.101508        0.101508  3.119869e-02
# 2                 0.101508             0.101508        0.101508  3.119869e-02
# 3                 0.101508             0.101508        0.101508  3.119869e-02
# 4                 0.101508             0.101508        0.101508  3.119869e-02
# ...                    ...                  ...             ...           ...
# 4438              0.101508             0.101508        0.101508  1.142322e-08
# 4439              0.101508             0.101508        0.101508  1.142322e-08
# 4440              0.101508             0.101508        0.101508  1.142322e-08
# 4441              0.101508             0.101508        0.101508  1.142322e-08
# 4442              0.101508             0.101508        0.101508  1.142322e-08
#
#       NORRECUBRIMIENOrigen  NORTOLANCHOOrigen  ...  NORRECUBRIMIENDestino  \
# 0                 0.067925           0.067039  ...               0.101829
# 1                 0.067925           0.067039  ...               0.101829
# 2                 0.067925           0.067039  ...               0.101829
# 3                 0.067925           0.067039  ...               0.101829
# 4                 0.067925           0.067039  ...               0.101829
# ...                    ...                ...  ...                    ...
# 4438              0.067925           0.067039  ...               0.101829
# 4439              0.067925           0.067039  ...               0.101829
# 4440              0.067925           0.067039  ...               0.101829
# 4441              0.067925           0.067039  ...               0.101829
# 4442              0.067925           0.067039  ...               0.101829
#
#       NORTOLANCHODestino  NORTOLESPESORDestino  PLANITUDDestino  \
# 0               0.101714              0.105819         0.107308
# 1               0.101714              0.105819         0.107308
# 2               0.101714              0.105819         0.107308
# 3               0.101714              0.105819         0.107308
# 4               0.101714              0.105819         0.107308
# ...                  ...                   ...              ...
# 4438            0.101714              0.000000         0.107308
# 4439            0.101714              0.000000         0.107308
# 4440            0.101714              0.000000         0.107308
# 4441            0.101714              0.000000         0.107308
# 4442            0.101714              0.000000         0.107308
#
#       RECUBRIMIENTODestino  SELLODestino  SUPERFICIEDestino  TAMFLORDestino  \
# 0                 0.104398      0.101622           0.102804        0.101508
# 1                 0.104398      0.101622           0.102804        0.101508
# 2                 0.104398      0.101622           0.102804        0.101508
# 3                 0.104398      0.101622           0.102804        0.101508
# 4                 0.104398      0.101622           0.102804        0.101508
# ...                    ...           ...                ...             ...
# 4438              0.000000      0.101622           0.000000        0.101508
# 4439              0.000000      0.101622           0.000000        0.101508
# 4440              0.000000      0.101622           0.000000        0.101508
# 4441              0.000000      0.101622           0.000000        0.101508
# 4442              0.000000      0.101622           0.000000        0.101508
#
#       TRATSUPERFDestino  USOGRALDestino
# 0              0.105128        0.102175
# 1              0.105128        0.102175
# 2              0.105128        0.102175
# 3              0.105128        0.102175
# 4              0.105128        0.102175
# ...                 ...             ...
# 4438           0.000000        0.102175
# 4439           0.000000        0.102175
# 4440           0.000000        0.102175
# 4441           0.000000        0.102175
# 4442           0.000000        0.102175
#
# [4443 rows x 36 columns]

# %%
###declaración de variable x (atributos)
X=codi
X
# Out:
#       CCLASEPRODTOOrigen  ACABSUPERFRECOrigen  ACEITADOOrigen  BORDESOrigen  \
# 0               0.101508             0.101508        0.101508      0.101508
# 1               0.101508             0.101508        0.101508      0.101508
# 2               0.101508             0.101508        0.101508      0.101508
# 3               0.101508             0.101508        0.101508      0.101508
# 4               0.101508             0.101508        0.101508      0.101508
# ...                  ...                  ...             ...           ...
# 4438            0.101508             0.101508        0.101508      0.101508
# 4439            0.101508             0.101508        0.101508      0.101508
# 4440            0.101508             0.101508        0.101508      0.101508
# 4441            0.101508             0.101508        0.101508      0.101508
# 4442            0.101508             0.101508        0.101508      0.101508
#
#       CARAINSPECCIONOrigen  DIAM__INTERNOOrigen  EXTREMOSOrigen   NORMAOrigen  \
# 0                 0.101508             0.101508        0.101508  3.119869e-02
# 1                 0.101508             0.101508        0.101508  3.119869e-02
# 2                 0.101508             0.101508        0.101508  3.119869e-02
# 3                 0.101508             0.101508        0.101508  3.119869e-02
# 4                 0.101508             0.101508        0.101508  3.119869e-02
# ...                    ...                  ...             ...           ...
# 4438              0.101508             0.101508        0.101508  1.142322e-08
# 4439              0.101508             0.101508        0.101508  1.142322e-08
# 4440              0.101508             0.101508        0.101508  1.142322e-08
# 4441              0.101508             0.101508        0.101508  1.142322e-08
# 4442              0.101508             0.101508        0.101508  1.142322e-08
#
#       NORRECUBRIMIENOrigen  NORTOLANCHOOrigen  ...  NORRECUBRIMIENDestino  \
# 0                 0.067925           0.067039  ...               0.101829
# 1                 0.067925           0.067039  ...               0.101829
# 2                 0.067925           0.067039  ...               0.101829
# 3                 0.067925           0.067039  ...               0.101829
# 4                 0.067925           0.067039  ...               0.101829
# ...                    ...                ...  ...                    ...
# 4438              0.067925           0.067039  ...               0.101829
# 4439              0.067925           0.067039  ...               0.101829
# 4440              0.067925           0.067039  ...               0.101829
# 4441              0.067925           0.067039  ...               0.101829
# 4442              0.067925           0.067039  ...               0.101829
#
#       NORTOLANCHODestino  NORTOLESPESORDestino  PLANITUDDestino  \
# 0               0.101714              0.105819         0.107308
# 1               0.101714              0.105819         0.107308
# 2               0.101714              0.105819         0.107308
# 3               0.101714              0.105819         0.107308
# 4               0.101714              0.105819         0.107308
# ...                  ...                   ...              ...
# 4438            0.101714              0.000000         0.107308
# 4439            0.101714              0.000000         0.107308
# 4440            0.101714              0.000000         0.107308
# 4441            0.101714              0.000000         0.107308
# 4442            0.101714              0.000000         0.107308
#
#       RECUBRIMIENTODestino  SELLODestino  SUPERFICIEDestino  TAMFLORDestino  \
# 0                 0.104398      0.101622           0.102804        0.101508
# 1                 0.104398      0.101622           0.102804        0.101508
# 2                 0.104398      0.101622           0.102804        0.101508
# 3                 0.104398      0.101622           0.102804        0.101508
# 4                 0.104398      0.101622           0.102804        0.101508
# ...                    ...           ...                ...             ...
# 4438              0.000000      0.101622           0.000000        0.101508
# 4439              0.000000      0.101622           0.000000        0.101508
# 4440              0.000000      0.101622           0.000000        0.101508
# 4441              0.000000      0.101622           0.000000        0.101508
# 4442              0.000000      0.101622           0.000000        0.101508
#
#       TRATSUPERFDestino  USOGRALDestino
# 0              0.105128        0.102175
# 1              0.105128        0.102175
# 2              0.105128        0.102175
# 3              0.105128        0.102175
# 4              0.105128        0.102175
# ...                 ...             ...
# 4438           0.000000        0.102175
# 4439           0.000000        0.102175
# 4440           0.000000        0.102175
# 4441           0.000000        0.102175
# 4442           0.000000        0.102175
#
# [4443 rows x 36 columns]

# %%
###declaración de y (objetivo)
y=target_df
y
# Out:
#       Reasignacion
# 0                0
# 1                0
# 2                0
# 3                0
# 4                0
# ...            ...
# 4438             0
# 4439             0
# 4440             0
# 4441             0
# 4442             0
#
# [4443 rows x 1 columns]

# %%
##división de datos 
X_train,X_test,y_train,y_test=train_test_split(X,y)

# %%
##entrenamiento
dt.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
###prueba score
dt.score(X_test,y_test)
# Out:
# 0.9207920792079208

# %%
joblib.dump(dt,'ModeloCincalum.pkl')
# Out:
# ['ModeloCincalum.pkl']

# %%
nombres=['OK','RECHAZADO']

# %%
##exportación y render
dot_data=export_graphviz(dt,feature_names= X.columns, class_names=nombres, impurity=False, filled=True)
graph=graphviz.Source(dot_data)
graph.render('ModeloCincalum')
# Out:
# 'ModeloCincalum.pdf'
